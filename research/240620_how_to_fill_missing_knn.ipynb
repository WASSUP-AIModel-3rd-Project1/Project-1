# %% [markdown]
# **결측치 채우는 방법**
# - 만약 년도/도시를 기준으로 하면 test set에서 데이터 전처리를 진행할 때 test set의 데이터를 참고하게 될 수 밖에 없음
#     - 각 년도/도시/라벨/인종/성별 별로 하나의 데이터 씩 밖에 없기 때문
# - 년도와 다르게 도시는 가까운 도시를 정의할 방법이 필요
#     - 혹은 U.S. Total의 값을 적용하는 방법이 있음
# - 도시간 거리를 정의한다면
#     - 각 (인종,성별,도시,연도) tuple 별로 각 라벨에서의 데이터 값에 대해서 sppt에서의 거리와 label value에서의 거리 사이에 비교
#     - sppt 에서의 metric
#         - 각각의 차원에서의 거리를 규정한 뒤, 각 차원에서의 거리를 euclidean
#         - 기타 방법이 가능할 수 있으나 데이터의 양을 봤을 때 쉽지 않을 듯
#         - 인종, 성별 : all, both 와의 거리는 다른 집단과의 거리보다 짧게
#         - 도시 : 도시에 대한 geo_strata 정보를 기준으로 metric 정의
#             - geo_strata의 feature : region, poverty, population, popDensity, segration
#             - 추가적으로 feature를 더한다면 : 내륙/해안/접경, 위도경도
#             - geo_strata의 값이 연도 별로 달라지는 지 확인
#         - 연도 : 차이
#
# - 각 label 별로 예측 학습을 진행하여 전처리에 이용할 수도 있음
#     - race-sex에 따른 차이에 경향성이 유사한 것들끼리 묶어서 하는 것 가능하면 의미 있을지도
#     - category 혹은 sub category 별로 변화 사이에서 correlation을 보는 등
#     - 혹은 특정 label에 대해서 학습을 진행한 뒤, 다른 label에 그대로 적용

# %%
import numpy as np 
import pandas as pd 
import matplotlib as mpl
import matplotlib.pyplot as plt 
import missingno as msno
import seaborn as sns 
import os

# %%
import matplotlib_inline.backend_inline

matplotlib_inline.backend_inline.set_matplotlib_formats("png2x")
# 테마 설정: "default", "classic", "dark_background", "fivethirtyeight", "seaborn"
mpl.style.use("fivethirtyeight")
# 이미지가 레이아웃 안으로 들어오도록 함
mpl.rcParams.update({"figure.constrained_layout.use": True})

# %%
import matplotlib.font_manager as fm
font_list = fm.findSystemFonts(fontpaths=None, fontext='ttf')
[fm.FontProperties(fname=font).get_name() for font in font_list if 'D2C' in font]
plt.rc('font', family='D2Coding')
mpl.rcParams['axes.unicode_minus'] = False

# %%
DATASET_DIR = '/home/doeun/code/AI/ESTSOFT2024/workspace/dataset/'
load_dir = 'america_big_cities_health_inventory'
file_name = 'BigCitiesHealth.csv'
RSLT_DIR = '/home/doeun/code/AI/ESTSOFT2024/workspace/1.project1_structured/BCHI/processed/'
pvtb_dir = RSLT_DIR + 'pvtb/'

# %% [markdown]
# ## FUNCTIONS

# %% [markdown]
# - preprocess

# %%
def count_key_opt(data:pd.DataFrame,key,opt):
    rslt = dict()
    labels = data[key].unique()
    form = data[opt].value_counts().sort_values(ascending=False)
    form.iloc[:] = 0

    for feat in labels:
        cond = data[key]==feat
        val = form.copy()
        temp = data.loc[cond,opt].value_counts()
        val.loc[temp.index] = temp
        rslt[feat] = val

    return pd.DataFrame(rslt).T

# %%
import functools

def cond_check_dict(data=pd.DataFrame,val_dict=dict):
    cond_list=[
        data[col] == val
        for col, val in val_dict.items()
    ]
    return functools.reduce(lambda x,y: x & y, cond_list)

# %% [markdown]
# - plot

# %%
import re

def choose_split_point(word_len,space,ths):
    # 윗 줄에 space 만큼 공백이 있고, 한 줄의 길이가 ths로 제한 되어있을 때
    # 어떤 지점에서 단어를 끊어줄지 정하기
    # |-------ths-------|
    # |-space-|---------|-space-|------| : word
    #         |-------ths-------|
    print(word_len,space,ths)
    if word_len < ths + space :
        if abs(word_len/2 -ths) <= abs(word_len/2-space) :
            return word_len-ths
        else :
            return word_len - space if word_len < 2 * space else space
    else :
        return ths if word_len - (ths + space) < 0.3 * ths else space

def minimize_seq_idx_np(domain:np.array,func):
    vfunc = np.vectorize(func)
    temp = np.argsort(vfunc(domain))
    return temp[0]

def modify_strlen_ths(last,new,ths=16):
    front = len(last)
    space = ths - (1+front)
    if len(new) < space :
        rslt = [last + ' ' + new]
    else :
        if len(new) < ths:
            rslt = [last, new]
        else:
            cut = choose_split_point(len(new),space-1,ths-1)
            new_h, new_e = new[:cut]+'-', new[cut:]
            if cut < ths-1 :
                rslt = modify_strlen_ths(last+' '+new_h,new_e)
            else :
                rslt = [last] + modify_strlen_ths(new_h,new_e) 
    return rslt

def str_cutter(sentnc, ths = 16):
    words= sentnc.split(' ')
    rslt, pnt = [''], 0
    while pnt < len(words):
        last = '' if len(rslt)==0 else rslt[-1]
        next_ele = modify_strlen_ths(last,words[pnt],ths)
        rslt = rslt[:-1] + next_ele
        pnt += 1
    return '\n'.join(rslt)[1:]
#알고리즘 때문에 맨 앞에 빈칸 하나 들어가게 되는 이슈 있음

print(str_cutter('Racial Segregation Indices | Racial Segregation, White and Hispanic', 13))
# Out:
# Racial
# Segregation
# Indices |
# Racial
# Segregation,
# White and
# Hispanic

# %%
def choose_plot_grid(n:int,r_max=8,c_max=17,res_ths=2):
    #ver2
    r_min = np.ceil(n/c_max)
    sppt = np.arange(r_min,r_max+1) #need error process
    col_nums = np.ceil(n/sppt)
    res = col_nums * sppt -n
    min_idx = np.where((res==np.min(res)) | (res <= res_ths))[0]
    row_cand, col_cand = sppt[min_idx], col_nums[min_idx]
    if len(min_idx) > 1 :
        res = np.abs(row_cand-col_cand)
        i = np.where(res==np.min(res))[0][0]
    else : i = 0
    return int(row_cand[i]), int(col_cand[i])


def pair_plot_feat_hue(fig,axes,data:dict,pair_plot,axis_share=False,hue_label_dict=None, **kwargs):
    #ver2
    if (fig is None) or (axes is None) :
        num_r, num_c = choose_plot_grid(len(data))
        fig, axes = plt.subplots(num_r,num_c,figsize=(21,17),sharex=axis_share,sharey=axis_share)
    for n,key in enumerate(data.keys()):
        ax = axes.flatten()[n]
        plt.setp(ax.get_xticklabels(),ha = 'left',rotation = 90)
        if n >= len(data) : continue
        pair_plot(x=data[key][0], y = data[key][1],ax =ax, **kwargs)
        feat_name = str(key) 
        if hue_label_dict: color = 'b' if hue_label_dict[feat_name] else 'k'
        else : color = 'k'
        ax.set_xlabel(str_cutter(feat_name,20),loc='left',fontsize = 8.3,color=color)
    return fig,axes

# %%
choose_plot_grid(5)
# Out:
# (2, 3)

# %% [markdown]
# # Define metic on a support $X$
#
# - 숫자들 간에는 차의 절대값으로 하면 됨
# - categorical의 경우
#     - geo : ordinal이라 볼 수 있지만 binary
#     - race, sex : nominal이지만 중간값(all or both) 존재

# %%
raw_file_path = os.path.join(DATASET_DIR,load_dir,file_name)
df_raw = pd.read_csv(raw_file_path)

df_raw
# Out:
# /tmp/ipykernel_206470/1273264358.py:2: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_raw = pd.read_csv(raw_file_path)
#                              metric_item_label             metric_cat_label  \
# 0                            All Cancer Deaths    Chronic Health Conditions
# 1                            All Cancer Deaths    Chronic Health Conditions
# 2                            All Cancer Deaths    Chronic Health Conditions
# 3                            All Cancer Deaths    Chronic Health Conditions
# 4                            All Cancer Deaths    Chronic Health Conditions
# ...                                        ...                          ...
# 189974  Racial Segregation, White and Hispanic  Social and Economic Factors
# 189975  Racial Segregation, White and Hispanic  Social and Economic Factors
# 189976  Racial Segregation, White and Hispanic  Social and Economic Factors
# 189977  Racial Segregation, White and Hispanic  Social and Economic Factors
# 189978  Racial Segregation, White and Hispanic  Social and Economic Factors
#
#                metric_subcat_label  \
# 0                           Cancer
# 1                           Cancer
# 2                           Cancer
# 3                           Cancer
# 4                           Cancer
# ...                            ...
# 189974  Racial Segregation Indices
# 189975  Racial Segregation Indices
# 189976  Racial Segregation Indices
# 189977  Racial Segregation Indices
# 189978  Racial Segregation Indices
#
#                                metric_item_label_subtitle  \
# 0       Deaths from all types of cancer (per 100,000 p...
# 1       Deaths from all types of cancer (per 100,000 p...
# 2       Deaths from all types of cancer (per 100,000 p...
# 3       Deaths from all types of cancer (per 100,000 p...
# 4       Deaths from all types of cancer (per 100,000 p...
# ...                                                   ...
# 189974  Residential segregation of white non-Hispanic ...
# 189975  Residential segregation of white non-Hispanic ...
# 189976  Residential segregation of white non-Hispanic ...
# 189977  Residential segregation of white non-Hispanic ...
# 189978  Residential segregation of white non-Hispanic ...
#
#        metric_cat_item_yaxis_label  \
# 0                      Per 100,000
# 1                      Per 100,000
# 2                      Per 100,000
# 3                      Per 100,000
# 4                      Per 100,000
# ...                            ...
# 189974             Lower is better
# 189975             Lower is better
# 189976             Lower is better
# 189977             Lower is better
# 189978             Lower is better
#
#                               metric_source_desc_label_fn  \
# 0       National Vital Statistics System (NVSS), Cente...
# 1       National Vital Statistics System (NVSS), Cente...
# 2       National Vital Statistics System (NVSS), Cente...
# 3       National Vital Statistics System (NVSS), Cente...
# 4       National Vital Statistics System (NVSS), Cente...
# ...                                                   ...
# 189974      American Community Survey, U.S. Census Bureau
# 189975      American Community Survey, U.S. Census Bureau
# 189976      American Community Survey, U.S. Census Bureau
# 189977      American Community Survey, U.S. Census Bureau
# 189978      American Community Survey, U.S. Census Bureau
#
#                     metric_source_desc_label_url_fn geo_label_city  \
# 0           https://www.cdc.gov/nchs/nvss/index.htm      Cleveland
# 1           https://www.cdc.gov/nchs/nvss/index.htm        Oakland
# 2           https://www.cdc.gov/nchs/nvss/index.htm  San Francisco
# 3           https://www.cdc.gov/nchs/nvss/index.htm     Long Beach
# 4           https://www.cdc.gov/nchs/nvss/index.htm      Cleveland
# ...                                             ...            ...
# 189974  https://www.census.gov/programs-surveys/acs        Chicago
# 189975  https://www.census.gov/programs-surveys/acs      Charlotte
# 189976  https://www.census.gov/programs-surveys/acs         Boston
# 189977  https://www.census.gov/programs-surveys/acs      Baltimore
# 189978  https://www.census.gov/programs-surveys/acs         Austin
#
#        geo_label_state geo_label_citystate  ...  value_90_ci_low  \
# 0                   OH       Cleveland, OH  ...              NaN
# 1                   CA         Oakland, CA  ...              NaN
# 2                   CA   San Francisco, CA  ...              NaN
# 3                   CA      Long Beach, CA  ...              NaN
# 4                   OH       Cleveland, OH  ...              NaN
# ...                ...                 ...  ...              ...
# 189974              IL         Chicago, IL  ...              NaN
# 189975              NC       Charlotte, NC  ...              NaN
# 189976              MA          Boston, MA  ...              NaN
# 189977              MD       Baltimore, MD  ...              NaN
# 189978              TX          Austin, TX  ...              NaN
#
#         value_90_ci_high  geo_strata_region            geo_strata_poverty  \
# 0                    NaN            Midwest    Poorest cities (18%+ poor)
# 1                    NaN               West  Less poor cities (<18% poor)
# 2                    NaN               West  Less poor cities (<18% poor)
# 3                    NaN               West  Less poor cities (<18% poor)
# 4                    NaN            Midwest    Poorest cities (18%+ poor)
# ...                  ...                ...                           ...
# 189974               NaN            Midwest  Less poor cities (<18% poor)
# 189975               NaN              South  Less poor cities (<18% poor)
# 189976               NaN          Northeast  Less poor cities (<18% poor)
# 189977               NaN              South    Poorest cities (18%+ poor)
# 189978               NaN              South  Less poor cities (<18% poor)
#
#          geo_strata_Population                  geo_strata_PopDensity  \
# 0       Smaller (<1.3 million)    Lower pop. density (<10k per sq mi)
# 1       Smaller (<1.3 million)    Lower pop. density (<10k per sq mi)
# 2       Smaller (<1.3 million)  Highest pop. density (>10k per sq mi)
# 3       Smaller (<1.3 million)                 Smaller (<1.3 million)
# 4       Smaller (<1.3 million)    Lower pop. density (<10k per sq mi)
# ...                        ...                                    ...
# 189974  Largest (>1.3 million)  Highest pop. density (>10k per sq mi)
# 189975  Smaller (<1.3 million)    Lower pop. density (<10k per sq mi)
# 189976  Smaller (<1.3 million)  Highest pop. density (>10k per sq mi)
# 189977  Smaller (<1.3 million)    Lower pop. density (<10k per sq mi)
# 189978  Smaller (<1.3 million)    Lower pop. density (<10k per sq mi)
#
#           geo_strata_Segregation strata_race_label strata_sex_label  \
# 0       Highly Segregated (50%+)             Black           Female
# 1         Less Segregated (<50%)          Hispanic             Male
# 2         Less Segregated (<50%)               All           Female
# 3       Highly Segregated (50%+)          Hispanic           Female
# 4       Highly Segregated (50%+)             Black             Male
# ...                          ...               ...              ...
# 189974  Highly Segregated (50%+)               All             Both
# 189975    Less Segregated (<50%)               All             Both
# 189976  Highly Segregated (50%+)               All             Both
# 189977  Highly Segregated (50%+)               All             Both
# 189978    Less Segregated (<50%)               All             Both
#
#         strata_race_sex_label
# 0                Black Female
# 1               Hispanic Male
# 2                         NaN
# 3             Hispanic Female
# 4                  Black Male
# ...                       ...
# 189974                    NaN
# 189975                    NaN
# 189976                    NaN
# 189977                    NaN
# 189978                    NaN
#
# [189979 rows x 31 columns]

# %%
cond_US = cond_check_dict(df_raw,{"geo_label_city":"U.S. Total"})
df_city = df_raw[~cond_US]

df_city
# Out:
#                              metric_item_label             metric_cat_label  \
# 0                            All Cancer Deaths    Chronic Health Conditions
# 1                            All Cancer Deaths    Chronic Health Conditions
# 2                            All Cancer Deaths    Chronic Health Conditions
# 3                            All Cancer Deaths    Chronic Health Conditions
# 4                            All Cancer Deaths    Chronic Health Conditions
# ...                                        ...                          ...
# 189974  Racial Segregation, White and Hispanic  Social and Economic Factors
# 189975  Racial Segregation, White and Hispanic  Social and Economic Factors
# 189976  Racial Segregation, White and Hispanic  Social and Economic Factors
# 189977  Racial Segregation, White and Hispanic  Social and Economic Factors
# 189978  Racial Segregation, White and Hispanic  Social and Economic Factors
#
#                metric_subcat_label  \
# 0                           Cancer
# 1                           Cancer
# 2                           Cancer
# 3                           Cancer
# 4                           Cancer
# ...                            ...
# 189974  Racial Segregation Indices
# 189975  Racial Segregation Indices
# 189976  Racial Segregation Indices
# 189977  Racial Segregation Indices
# 189978  Racial Segregation Indices
#
#                                metric_item_label_subtitle  \
# 0       Deaths from all types of cancer (per 100,000 p...
# 1       Deaths from all types of cancer (per 100,000 p...
# 2       Deaths from all types of cancer (per 100,000 p...
# 3       Deaths from all types of cancer (per 100,000 p...
# 4       Deaths from all types of cancer (per 100,000 p...
# ...                                                   ...
# 189974  Residential segregation of white non-Hispanic ...
# 189975  Residential segregation of white non-Hispanic ...
# 189976  Residential segregation of white non-Hispanic ...
# 189977  Residential segregation of white non-Hispanic ...
# 189978  Residential segregation of white non-Hispanic ...
#
#        metric_cat_item_yaxis_label  \
# 0                      Per 100,000
# 1                      Per 100,000
# 2                      Per 100,000
# 3                      Per 100,000
# 4                      Per 100,000
# ...                            ...
# 189974             Lower is better
# 189975             Lower is better
# 189976             Lower is better
# 189977             Lower is better
# 189978             Lower is better
#
#                               metric_source_desc_label_fn  \
# 0       National Vital Statistics System (NVSS), Cente...
# 1       National Vital Statistics System (NVSS), Cente...
# 2       National Vital Statistics System (NVSS), Cente...
# 3       National Vital Statistics System (NVSS), Cente...
# 4       National Vital Statistics System (NVSS), Cente...
# ...                                                   ...
# 189974      American Community Survey, U.S. Census Bureau
# 189975      American Community Survey, U.S. Census Bureau
# 189976      American Community Survey, U.S. Census Bureau
# 189977      American Community Survey, U.S. Census Bureau
# 189978      American Community Survey, U.S. Census Bureau
#
#                     metric_source_desc_label_url_fn geo_label_city  \
# 0           https://www.cdc.gov/nchs/nvss/index.htm      Cleveland
# 1           https://www.cdc.gov/nchs/nvss/index.htm        Oakland
# 2           https://www.cdc.gov/nchs/nvss/index.htm  San Francisco
# 3           https://www.cdc.gov/nchs/nvss/index.htm     Long Beach
# 4           https://www.cdc.gov/nchs/nvss/index.htm      Cleveland
# ...                                             ...            ...
# 189974  https://www.census.gov/programs-surveys/acs        Chicago
# 189975  https://www.census.gov/programs-surveys/acs      Charlotte
# 189976  https://www.census.gov/programs-surveys/acs         Boston
# 189977  https://www.census.gov/programs-surveys/acs      Baltimore
# 189978  https://www.census.gov/programs-surveys/acs         Austin
#
#        geo_label_state geo_label_citystate  ...  value_90_ci_low  \
# 0                   OH       Cleveland, OH  ...              NaN
# 1                   CA         Oakland, CA  ...              NaN
# 2                   CA   San Francisco, CA  ...              NaN
# 3                   CA      Long Beach, CA  ...              NaN
# 4                   OH       Cleveland, OH  ...              NaN
# ...                ...                 ...  ...              ...
# 189974              IL         Chicago, IL  ...              NaN
# 189975              NC       Charlotte, NC  ...              NaN
# 189976              MA          Boston, MA  ...              NaN
# 189977              MD       Baltimore, MD  ...              NaN
# 189978              TX          Austin, TX  ...              NaN
#
#         value_90_ci_high  geo_strata_region            geo_strata_poverty  \
# 0                    NaN            Midwest    Poorest cities (18%+ poor)
# 1                    NaN               West  Less poor cities (<18% poor)
# 2                    NaN               West  Less poor cities (<18% poor)
# 3                    NaN               West  Less poor cities (<18% poor)
# 4                    NaN            Midwest    Poorest cities (18%+ poor)
# ...                  ...                ...                           ...
# 189974               NaN            Midwest  Less poor cities (<18% poor)
# 189975               NaN              South  Less poor cities (<18% poor)
# 189976               NaN          Northeast  Less poor cities (<18% poor)
# 189977               NaN              South    Poorest cities (18%+ poor)
# 189978               NaN              South  Less poor cities (<18% poor)
#
#          geo_strata_Population                  geo_strata_PopDensity  \
# 0       Smaller (<1.3 million)    Lower pop. density (<10k per sq mi)
# 1       Smaller (<1.3 million)    Lower pop. density (<10k per sq mi)
# 2       Smaller (<1.3 million)  Highest pop. density (>10k per sq mi)
# 3       Smaller (<1.3 million)                 Smaller (<1.3 million)
# 4       Smaller (<1.3 million)    Lower pop. density (<10k per sq mi)
# ...                        ...                                    ...
# 189974  Largest (>1.3 million)  Highest pop. density (>10k per sq mi)
# 189975  Smaller (<1.3 million)    Lower pop. density (<10k per sq mi)
# 189976  Smaller (<1.3 million)  Highest pop. density (>10k per sq mi)
# 189977  Smaller (<1.3 million)    Lower pop. density (<10k per sq mi)
# 189978  Smaller (<1.3 million)    Lower pop. density (<10k per sq mi)
#
#           geo_strata_Segregation strata_race_label strata_sex_label  \
# 0       Highly Segregated (50%+)             Black           Female
# 1         Less Segregated (<50%)          Hispanic             Male
# 2         Less Segregated (<50%)               All           Female
# 3       Highly Segregated (50%+)          Hispanic           Female
# 4       Highly Segregated (50%+)             Black             Male
# ...                          ...               ...              ...
# 189974  Highly Segregated (50%+)               All             Both
# 189975    Less Segregated (<50%)               All             Both
# 189976  Highly Segregated (50%+)               All             Both
# 189977  Highly Segregated (50%+)               All             Both
# 189978    Less Segregated (<50%)               All             Both
#
#         strata_race_sex_label
# 0                Black Female
# 1               Hispanic Male
# 2                         NaN
# 3             Hispanic Female
# 4                  Black Male
# ...                       ...
# 189974                    NaN
# 189975                    NaN
# 189976                    NaN
# 189977                    NaN
# 189978                    NaN
#
# [188667 rows x 31 columns]

# %% [markdown]
# ### metric on geo_strat
# - abstract geo_strat

# %%
geo_strat_cols = list(filter(lambda x : 'geo_strat' in x,df_city.columns))
geo_info_cols = list(filter(lambda x : 'geo_label' in x,df_city.columns))[:3]

df_temp = df_city[geo_info_cols+geo_strat_cols]

df_temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 188667 entries, 0 to 189978
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   geo_label_city          188667 non-null  object
#  1   geo_label_state         188667 non-null  object
#  2   geo_label_citystate     188667 non-null  object
#  3   geo_strata_region       188667 non-null  object
#  4   geo_strata_poverty      188667 non-null  object
#  5   geo_strata_Population   188666 non-null  object
#  6   geo_strata_PopDensity   188667 non-null  object
#  7   geo_strata_Segregation  188667 non-null  object
# dtypes: object(8)
# memory usage: 13.0+ MB

# %%
# EDA 결과, las vegas와 long beach에 대해서 오기입된 record가 하나씩 있음
# 오기입된 outlier을 제외하고 반복되어 등장한 것만 추림
dup_cond = df_temp.duplicated(keep=False)
print(len(df_temp[dup_cond].value_counts()))
#df_temp[dup_cond].value_counts()
# Out:
# 35

# %%
df_geo_strat = df_temp[dup_cond].value_counts().reset_index()

# %%
df_geo_info = df_geo_strat.set_index('geo_label_city')

df_geo_info
# Out:
#                geo_label_state geo_label_citystate geo_strata_region  \
# geo_label_city
# New York City               NY   New York City, NY         Northeast
# Houston                     TX         Houston, TX             South
# Los Angeles                 CA     Los Angeles, CA              West
# Philadelphia                PA    Philadelphia, PA         Northeast
# San Diego                   CA       San Diego, CA              West
# Chicago                     IL         Chicago, IL           Midwest
# San Francisco               CA   San Francisco, CA              West
# Las Vegas                   NV       Las Vegas, NV              West
# Boston                      MA          Boston, MA         Northeast
# Oakland                     CA         Oakland, CA              West
# Dallas                      TX          Dallas, TX             South
# Fort Worth                  TX      Fort Worth, TX             South
# Seattle                     WA         Seattle, WA              West
# Phoenix                     AZ         Phoenix, AZ              West
# Charlotte                   NC       Charlotte, NC             South
# San Antonio                 TX     San Antonio, TX             South
# Washington                  DC      Washington, DC             South
# Portland                    OR        Portland, OR              West
# Long Beach                  CA      Long Beach, CA              West
# San Jose                    CA        San Jose, CA              West
# Austin                      TX          Austin, TX             South
# Detroit                     MI         Detroit, MI           Midwest
# Denver                      CO          Denver, CO              West
# Cleveland                   OH       Cleveland, OH           Midwest
# Baltimore                   MD       Baltimore, MD             South
# Oklahoma City               OK   Oklahoma City, OK             South
# Indianapolis                IN    Indianapolis, IN           Midwest
# Columbus                    OH        Columbus, OH           Midwest
# Milwaukee                   WI       Milwaukee, WI           Midwest
# Kansas City                 MO     Kansas City, MO           Midwest
# Tucson                      AZ          Tucson, AZ              West
# Memphis                     TN         Memphis, TN             South
# El Paso                     TX         El Paso, TX             South
# Louisville                  KY      Louisville, KY             South
# Minneapolis                 MN     Minneapolis, MN           Midwest
#
#                           geo_strata_poverty   geo_strata_Population  \
# geo_label_city
# New York City   Less poor cities (<18% poor)  Largest (>1.3 million)
# Houston           Poorest cities (18%+ poor)  Largest (>1.3 million)
# Los Angeles     Less poor cities (<18% poor)  Largest (>1.3 million)
# Philadelphia      Poorest cities (18%+ poor)  Largest (>1.3 million)
# San Diego       Less poor cities (<18% poor)  Largest (>1.3 million)
# Chicago         Less poor cities (<18% poor)  Largest (>1.3 million)
# San Francisco   Less poor cities (<18% poor)  Smaller (<1.3 million)
# Las Vegas       Less poor cities (<18% poor)  Smaller (<1.3 million)
# Boston          Less poor cities (<18% poor)  Smaller (<1.3 million)
# Oakland         Less poor cities (<18% poor)  Smaller (<1.3 million)
# Dallas          Less poor cities (<18% poor)  Largest (>1.3 million)
# Fort Worth      Less poor cities (<18% poor)  Smaller (<1.3 million)
# Seattle         Less poor cities (<18% poor)  Smaller (<1.3 million)
# Phoenix         Less poor cities (<18% poor)  Largest (>1.3 million)
# Charlotte       Less poor cities (<18% poor)  Smaller (<1.3 million)
# San Antonio     Less poor cities (<18% poor)  Largest (>1.3 million)
# Washington      Less poor cities (<18% poor)  Smaller (<1.3 million)
# Portland        Less poor cities (<18% poor)  Smaller (<1.3 million)
# Long Beach      Less poor cities (<18% poor)  Smaller (<1.3 million)
# San Jose        Less poor cities (<18% poor)  Smaller (<1.3 million)
# Austin          Less poor cities (<18% poor)  Smaller (<1.3 million)
# Detroit           Poorest cities (18%+ poor)  Smaller (<1.3 million)
# Denver          Less poor cities (<18% poor)  Smaller (<1.3 million)
# Cleveland         Poorest cities (18%+ poor)  Smaller (<1.3 million)
# Baltimore         Poorest cities (18%+ poor)  Smaller (<1.3 million)
# Oklahoma City   Less poor cities (<18% poor)  Smaller (<1.3 million)
# Indianapolis    Less poor cities (<18% poor)  Smaller (<1.3 million)
# Columbus        Less poor cities (<18% poor)  Smaller (<1.3 million)
# Milwaukee         Poorest cities (18%+ poor)  Smaller (<1.3 million)
# Kansas City     Less poor cities (<18% poor)  Smaller (<1.3 million)
# Tucson            Poorest cities (18%+ poor)  Smaller (<1.3 million)
# Memphis           Poorest cities (18%+ poor)  Smaller (<1.3 million)
# El Paso           Poorest cities (18%+ poor)  Smaller (<1.3 million)
# Louisville      Less poor cities (<18% poor)  Smaller (<1.3 million)
# Minneapolis     Less poor cities (<18% poor)  Smaller (<1.3 million)
#
#                                 geo_strata_PopDensity  \
# geo_label_city
# New York City   Highest pop. density (>10k per sq mi)
# Houston           Lower pop. density (<10k per sq mi)
# Los Angeles       Lower pop. density (<10k per sq mi)
# Philadelphia    Highest pop. density (>10k per sq mi)
# San Diego         Lower pop. density (<10k per sq mi)
# Chicago         Highest pop. density (>10k per sq mi)
# San Francisco   Highest pop. density (>10k per sq mi)
# Las Vegas         Lower pop. density (<10k per sq mi)
# Boston          Highest pop. density (>10k per sq mi)
# Oakland           Lower pop. density (<10k per sq mi)
# Dallas            Lower pop. density (<10k per sq mi)
# Fort Worth        Lower pop. density (<10k per sq mi)
# Seattle           Lower pop. density (<10k per sq mi)
# Phoenix           Lower pop. density (<10k per sq mi)
# Charlotte         Lower pop. density (<10k per sq mi)
# San Antonio       Lower pop. density (<10k per sq mi)
# Washington      Highest pop. density (>10k per sq mi)
# Portland          Lower pop. density (<10k per sq mi)
# Long Beach        Lower pop. density (<10k per sq mi)
# San Jose          Lower pop. density (<10k per sq mi)
# Austin            Lower pop. density (<10k per sq mi)
# Detroit           Lower pop. density (<10k per sq mi)
# Denver            Lower pop. density (<10k per sq mi)
# Cleveland         Lower pop. density (<10k per sq mi)
# Baltimore         Lower pop. density (<10k per sq mi)
# Oklahoma City     Lower pop. density (<10k per sq mi)
# Indianapolis      Lower pop. density (<10k per sq mi)
# Columbus          Lower pop. density (<10k per sq mi)
# Milwaukee         Lower pop. density (<10k per sq mi)
# Kansas City       Lower pop. density (<10k per sq mi)
# Tucson            Lower pop. density (<10k per sq mi)
# Memphis           Lower pop. density (<10k per sq mi)
# El Paso           Lower pop. density (<10k per sq mi)
# Louisville        Lower pop. density (<10k per sq mi)
# Minneapolis       Lower pop. density (<10k per sq mi)
#
#                   geo_strata_Segregation  count
# geo_label_city
# New York City   Highly Segregated (50%+)   6535
# Houston         Highly Segregated (50%+)   6431
# Los Angeles     Highly Segregated (50%+)   6372
# Philadelphia    Highly Segregated (50%+)   6310
# San Diego         Less Segregated (<50%)   6251
# Chicago         Highly Segregated (50%+)   6210
# San Francisco     Less Segregated (<50%)   6121
# Las Vegas         Less Segregated (<50%)   5848
# Boston          Highly Segregated (50%+)   5718
# Oakland           Less Segregated (<50%)   5676
# Dallas          Highly Segregated (50%+)   5655
# Fort Worth        Less Segregated (<50%)   5628
# Seattle           Less Segregated (<50%)   5507
# Phoenix         Highly Segregated (50%+)   5437
# Charlotte         Less Segregated (<50%)   5381
# San Antonio       Less Segregated (<50%)   5349
# Washington      Highly Segregated (50%+)   5264
# Portland          Less Segregated (<50%)   5219
# Long Beach      Highly Segregated (50%+)   5215
# San Jose          Less Segregated (<50%)   5206
# Austin            Less Segregated (<50%)   5198
# Detroit         Highly Segregated (50%+)   5160
# Denver            Less Segregated (<50%)   5157
# Cleveland       Highly Segregated (50%+)   5113
# Baltimore       Highly Segregated (50%+)   5101
# Oklahoma City     Less Segregated (<50%)   5030
# Indianapolis      Less Segregated (<50%)   4916
# Columbus          Less Segregated (<50%)   4907
# Milwaukee       Highly Segregated (50%+)   4881
# Kansas City       Less Segregated (<50%)   4848
# Tucson            Less Segregated (<50%)   4799
# Memphis         Highly Segregated (50%+)   4631
# El Paso           Less Segregated (<50%)   4553
# Louisville        Less Segregated (<50%)   4527
# Minneapolis       Less Segregated (<50%)   4511

# %%
save_path = os.path.join(RSLT_DIR,'geo_strat_info.csv')
df_geo_info.to_csv(save_path,index=True)

# %% [markdown]
# - except for geo_strata_region, all of them is ordinal and binary
# - in geo_strata_region, minimal length between each regions could be base of metric
#     - a condition of metric :
#
#         (distance between a, c) <= (distance between a, b) + (distance between b, c)

# %%
df_region = df_geo_strat.groupby('geo_strata_region')['geo_label_state'].apply(set)

df_region
# Out:
# geo_strata_region
# Midwest      {MO, MN, IN, IL, MI, WI, OH}
# Northeast                    {PA, MA, NY}
# South        {KY, DC, TN, TX, MD, NC, OK}
# West             {CA, WA, AZ, NV, OR, CO}
# Name: geo_label_state, dtype: object

# %%
df_geo_strat[geo_strat_cols].value_counts()
# Out:
# geo_strata_region  geo_strata_poverty            geo_strata_Population   geo_strata_PopDensity                  geo_strata_Segregation
# West               Less poor cities (<18% poor)  Smaller (<1.3 million)  Lower pop. density (<10k per sq mi)    Less Segregated (<50%)      6
# South              Less poor cities (<18% poor)  Smaller (<1.3 million)  Lower pop. density (<10k per sq mi)    Less Segregated (<50%)      5
# Midwest            Less poor cities (<18% poor)  Smaller (<1.3 million)  Lower pop. density (<10k per sq mi)    Less Segregated (<50%)      4
#                    Poorest cities (18%+ poor)    Smaller (<1.3 million)  Lower pop. density (<10k per sq mi)    Highly Segregated (50%+)    3
# South              Poorest cities (18%+ poor)    Smaller (<1.3 million)  Lower pop. density (<10k per sq mi)    Highly Segregated (50%+)    2
# West               Less poor cities (<18% poor)  Largest (>1.3 million)  Lower pop. density (<10k per sq mi)    Highly Segregated (50%+)    2
#                                                  Smaller (<1.3 million)  Lower pop. density (<10k per sq mi)    Highly Segregated (50%+)    1
#                                                                          Highest pop. density (>10k per sq mi)  Less Segregated (<50%)      1
#                                                  Largest (>1.3 million)  Lower pop. density (<10k per sq mi)    Less Segregated (<50%)      1
# South              Poorest cities (18%+ poor)    Smaller (<1.3 million)  Lower pop. density (<10k per sq mi)    Less Segregated (<50%)      1
# Midwest            Less poor cities (<18% poor)  Largest (>1.3 million)  Highest pop. density (>10k per sq mi)  Highly Segregated (50%+)    1
# South              Poorest cities (18%+ poor)    Largest (>1.3 million)  Lower pop. density (<10k per sq mi)    Highly Segregated (50%+)    1
#                    Less poor cities (<18% poor)  Smaller (<1.3 million)  Highest pop. density (>10k per sq mi)  Highly Segregated (50%+)    1
#                                                  Largest (>1.3 million)  Lower pop. density (<10k per sq mi)    Less Segregated (<50%)      1
#                                                                                                                 Highly Segregated (50%+)    1
# Northeast          Poorest cities (18%+ poor)    Largest (>1.3 million)  Highest pop. density (>10k per sq mi)  Highly Segregated (50%+)    1
#                    Less poor cities (<18% poor)  Smaller (<1.3 million)  Highest pop. density (>10k per sq mi)  Highly Segregated (50%+)    1
#                                                  Largest (>1.3 million)  Highest pop. density (>10k per sq mi)  Highly Segregated (50%+)    1
# West               Poorest cities (18%+ poor)    Smaller (<1.3 million)  Lower pop. density (<10k per sq mi)    Less Segregated (<50%)      1
# Name: count, dtype: int64

# %%
for col in geo_strat_cols:
    display(df_geo_strat[col].value_counts())
# Out:
# geo_strata_region
# South        12
# West         12
# Midwest       8
# Northeast     3
# Name: count, dtype: int64
# geo_strata_poverty
# Less poor cities (<18% poor)    26
# Poorest cities (18%+ poor)       9
# Name: count, dtype: int64
# geo_strata_Population
# Smaller (<1.3 million)    26
# Largest (>1.3 million)     9
# Name: count, dtype: int64
# geo_strata_PopDensity
# Lower pop. density (<10k per sq mi)      29
# Highest pop. density (>10k per sq mi)     6
# Name: count, dtype: int64
# geo_strata_Segregation
# Less Segregated (<50%)      20
# Highly Segregated (50%+)    15
# Name: count, dtype: int64

# %% [markdown]
# basically,
# - if a,b are adjacent : d(a,b) = 1
# - if minimal path == 2 : d(a,b) = 1.732 (cf. sqrt 3)
#
# (cf : 정삼각형 2 개 붙어있는 모양)

# %%
import itertools

region_adjacent = [
    { "Midwest", "Northeast" },
    { "Midwest", "South" },
    { "Midwest", "West" },
    { "West", "South" },
    { "South", "Northeast" }
]

    
def metric_on_adj(points,adjacents,far_distance = 1.732):
    metric_dict=dict()
    for a,b in itertools.product(points,repeat=2):
        if a == b : metric_dict[(a,b)] = 0
        elif {a,b} in adjacents : metric_dict[(a,b)] = 1
        else : metric_dict[(a,b)] = far_distance 
    return lambda x,y : metric_dict[(x,y)]

metric_region = metric_on_adj(df_region.index,region_adjacent)

print(type(metric_region))
print(metric_region('West','Northeast'))
# Out:
# <class 'function'>
# 1.732

# %% [markdown]
# the algorithm could be applied on other nominal categories, e.g. race, sex, and other binay ordinal categories.

# %%
metric_binary = lambda x,y : 0 if x==y else 1
# metric_binary.__setattr__('name','metric_binary') -> 함수에 이름 정해주는 법 어떻게?

entire_race = ['All','White','Black','Hispanic','Asian/PI','Natives']
race_adjacnet = [
    {'All', a}
    for a in entire_race
    if a != 'All'
]
metric_race = metric_on_adj(entire_race, race_adjacnet)

entire_sex = ['Both','Female','Male']
sex_adjacnet = [
    {'Both', a}
    for a in entire_race
    if a != 'Both'
]
metric_sex = metric_on_adj(entire_sex, sex_adjacnet)

metric_race('White','Black')
# Out:
# 1.732

# %%
dict_metric = dict()

dict_metric['strata_race_label'] = metric_race
dict_metric['strata_sex_label'] = metric_sex
dict_metric['geo_strata_region'] = metric_region

for col in geo_strat_cols:
    if col == 'geo_strata_region' : continue
    dict_metric[col] = metric_binary

dict_metric
# Out:
# {'strata_race_label': <function __main__.metric_on_adj.<locals>.<lambda>(x, y)>,
#  'strata_sex_label': <function __main__.metric_on_adj.<locals>.<lambda>(x, y)>,
#  'geo_strata_region': <function __main__.metric_on_adj.<locals>.<lambda>(x, y)>,
#  'geo_strata_poverty': <function __main__.<lambda>(x, y)>,
#  'geo_strata_Population': <function __main__.<lambda>(x, y)>,
#  'geo_strata_PopDensity': <function __main__.<lambda>(x, y)>,
#  'geo_strata_Segregation': <function __main__.<lambda>(x, y)>}

# %%
dict_metric['geo_strata_Segregation'].__name__
# Out:
# '<lambda>'

# %%
dict_metric['geo_strata_region'] ('Midwest','Midwest')
# Out:
# 0

# %%
dict_metric['strata_race_label'] ('All','White')
# Out:
# 1

# %% [markdown]
# ### distance between cities
# - 각 axis 에서의 거리를 L7 norm 한 것으로 테스트
# - 7은 임의로 정한 것으로 필요시 다른 값으로 테스트 해봐도 좋을 듯

# %%
df_geo_info
# Out:
#                geo_label_state geo_label_citystate geo_strata_region  \
# geo_label_city
# New York City               NY   New York City, NY         Northeast
# Houston                     TX         Houston, TX             South
# Los Angeles                 CA     Los Angeles, CA              West
# Philadelphia                PA    Philadelphia, PA         Northeast
# San Diego                   CA       San Diego, CA              West
# Chicago                     IL         Chicago, IL           Midwest
# San Francisco               CA   San Francisco, CA              West
# Las Vegas                   NV       Las Vegas, NV              West
# Boston                      MA          Boston, MA         Northeast
# Oakland                     CA         Oakland, CA              West
# Dallas                      TX          Dallas, TX             South
# Fort Worth                  TX      Fort Worth, TX             South
# Seattle                     WA         Seattle, WA              West
# Phoenix                     AZ         Phoenix, AZ              West
# Charlotte                   NC       Charlotte, NC             South
# San Antonio                 TX     San Antonio, TX             South
# Washington                  DC      Washington, DC             South
# Portland                    OR        Portland, OR              West
# Long Beach                  CA      Long Beach, CA              West
# San Jose                    CA        San Jose, CA              West
# Austin                      TX          Austin, TX             South
# Detroit                     MI         Detroit, MI           Midwest
# Denver                      CO          Denver, CO              West
# Cleveland                   OH       Cleveland, OH           Midwest
# Baltimore                   MD       Baltimore, MD             South
# Oklahoma City               OK   Oklahoma City, OK             South
# Indianapolis                IN    Indianapolis, IN           Midwest
# Columbus                    OH        Columbus, OH           Midwest
# Milwaukee                   WI       Milwaukee, WI           Midwest
# Kansas City                 MO     Kansas City, MO           Midwest
# Tucson                      AZ          Tucson, AZ              West
# Memphis                     TN         Memphis, TN             South
# El Paso                     TX         El Paso, TX             South
# Louisville                  KY      Louisville, KY             South
# Minneapolis                 MN     Minneapolis, MN           Midwest
#
#                           geo_strata_poverty   geo_strata_Population  \
# geo_label_city
# New York City   Less poor cities (<18% poor)  Largest (>1.3 million)
# Houston           Poorest cities (18%+ poor)  Largest (>1.3 million)
# Los Angeles     Less poor cities (<18% poor)  Largest (>1.3 million)
# Philadelphia      Poorest cities (18%+ poor)  Largest (>1.3 million)
# San Diego       Less poor cities (<18% poor)  Largest (>1.3 million)
# Chicago         Less poor cities (<18% poor)  Largest (>1.3 million)
# San Francisco   Less poor cities (<18% poor)  Smaller (<1.3 million)
# Las Vegas       Less poor cities (<18% poor)  Smaller (<1.3 million)
# Boston          Less poor cities (<18% poor)  Smaller (<1.3 million)
# Oakland         Less poor cities (<18% poor)  Smaller (<1.3 million)
# Dallas          Less poor cities (<18% poor)  Largest (>1.3 million)
# Fort Worth      Less poor cities (<18% poor)  Smaller (<1.3 million)
# Seattle         Less poor cities (<18% poor)  Smaller (<1.3 million)
# Phoenix         Less poor cities (<18% poor)  Largest (>1.3 million)
# Charlotte       Less poor cities (<18% poor)  Smaller (<1.3 million)
# San Antonio     Less poor cities (<18% poor)  Largest (>1.3 million)
# Washington      Less poor cities (<18% poor)  Smaller (<1.3 million)
# Portland        Less poor cities (<18% poor)  Smaller (<1.3 million)
# Long Beach      Less poor cities (<18% poor)  Smaller (<1.3 million)
# San Jose        Less poor cities (<18% poor)  Smaller (<1.3 million)
# Austin          Less poor cities (<18% poor)  Smaller (<1.3 million)
# Detroit           Poorest cities (18%+ poor)  Smaller (<1.3 million)
# Denver          Less poor cities (<18% poor)  Smaller (<1.3 million)
# Cleveland         Poorest cities (18%+ poor)  Smaller (<1.3 million)
# Baltimore         Poorest cities (18%+ poor)  Smaller (<1.3 million)
# Oklahoma City   Less poor cities (<18% poor)  Smaller (<1.3 million)
# Indianapolis    Less poor cities (<18% poor)  Smaller (<1.3 million)
# Columbus        Less poor cities (<18% poor)  Smaller (<1.3 million)
# Milwaukee         Poorest cities (18%+ poor)  Smaller (<1.3 million)
# Kansas City     Less poor cities (<18% poor)  Smaller (<1.3 million)
# Tucson            Poorest cities (18%+ poor)  Smaller (<1.3 million)
# Memphis           Poorest cities (18%+ poor)  Smaller (<1.3 million)
# El Paso           Poorest cities (18%+ poor)  Smaller (<1.3 million)
# Louisville      Less poor cities (<18% poor)  Smaller (<1.3 million)
# Minneapolis     Less poor cities (<18% poor)  Smaller (<1.3 million)
#
#                                 geo_strata_PopDensity  \
# geo_label_city
# New York City   Highest pop. density (>10k per sq mi)
# Houston           Lower pop. density (<10k per sq mi)
# Los Angeles       Lower pop. density (<10k per sq mi)
# Philadelphia    Highest pop. density (>10k per sq mi)
# San Diego         Lower pop. density (<10k per sq mi)
# Chicago         Highest pop. density (>10k per sq mi)
# San Francisco   Highest pop. density (>10k per sq mi)
# Las Vegas         Lower pop. density (<10k per sq mi)
# Boston          Highest pop. density (>10k per sq mi)
# Oakland           Lower pop. density (<10k per sq mi)
# Dallas            Lower pop. density (<10k per sq mi)
# Fort Worth        Lower pop. density (<10k per sq mi)
# Seattle           Lower pop. density (<10k per sq mi)
# Phoenix           Lower pop. density (<10k per sq mi)
# Charlotte         Lower pop. density (<10k per sq mi)
# San Antonio       Lower pop. density (<10k per sq mi)
# Washington      Highest pop. density (>10k per sq mi)
# Portland          Lower pop. density (<10k per sq mi)
# Long Beach        Lower pop. density (<10k per sq mi)
# San Jose          Lower pop. density (<10k per sq mi)
# Austin            Lower pop. density (<10k per sq mi)
# Detroit           Lower pop. density (<10k per sq mi)
# Denver            Lower pop. density (<10k per sq mi)
# Cleveland         Lower pop. density (<10k per sq mi)
# Baltimore         Lower pop. density (<10k per sq mi)
# Oklahoma City     Lower pop. density (<10k per sq mi)
# Indianapolis      Lower pop. density (<10k per sq mi)
# Columbus          Lower pop. density (<10k per sq mi)
# Milwaukee         Lower pop. density (<10k per sq mi)
# Kansas City       Lower pop. density (<10k per sq mi)
# Tucson            Lower pop. density (<10k per sq mi)
# Memphis           Lower pop. density (<10k per sq mi)
# El Paso           Lower pop. density (<10k per sq mi)
# Louisville        Lower pop. density (<10k per sq mi)
# Minneapolis       Lower pop. density (<10k per sq mi)
#
#                   geo_strata_Segregation  count
# geo_label_city
# New York City   Highly Segregated (50%+)   6535
# Houston         Highly Segregated (50%+)   6431
# Los Angeles     Highly Segregated (50%+)   6372
# Philadelphia    Highly Segregated (50%+)   6310
# San Diego         Less Segregated (<50%)   6251
# Chicago         Highly Segregated (50%+)   6210
# San Francisco     Less Segregated (<50%)   6121
# Las Vegas         Less Segregated (<50%)   5848
# Boston          Highly Segregated (50%+)   5718
# Oakland           Less Segregated (<50%)   5676
# Dallas          Highly Segregated (50%+)   5655
# Fort Worth        Less Segregated (<50%)   5628
# Seattle           Less Segregated (<50%)   5507
# Phoenix         Highly Segregated (50%+)   5437
# Charlotte         Less Segregated (<50%)   5381
# San Antonio       Less Segregated (<50%)   5349
# Washington      Highly Segregated (50%+)   5264
# Portland          Less Segregated (<50%)   5219
# Long Beach      Highly Segregated (50%+)   5215
# San Jose          Less Segregated (<50%)   5206
# Austin            Less Segregated (<50%)   5198
# Detroit         Highly Segregated (50%+)   5160
# Denver            Less Segregated (<50%)   5157
# Cleveland       Highly Segregated (50%+)   5113
# Baltimore       Highly Segregated (50%+)   5101
# Oklahoma City     Less Segregated (<50%)   5030
# Indianapolis      Less Segregated (<50%)   4916
# Columbus          Less Segregated (<50%)   4907
# Milwaukee       Highly Segregated (50%+)   4881
# Kansas City       Less Segregated (<50%)   4848
# Tucson            Less Segregated (<50%)   4799
# Memphis         Highly Segregated (50%+)   4631
# El Paso           Less Segregated (<50%)   4553
# Louisville        Less Segregated (<50%)   4527
# Minneapolis       Less Segregated (<50%)   4511

# %%
print(metric_region('Northeast', 'Northeast'))
# Out:
# 0

# %%
print(dict_metric['geo_strata_region']('Northeast', 'Northeast'))
# Out:
# 0

# %%
city_list = list(df_geo_info.index)

metric_val= dict()
for a, b in itertools.product(city_list,repeat=2):
    diff = [
        dict_metric[col](df_geo_info.loc[a,col],
                         df_geo_info.loc[b,col])
        for col in geo_strat_cols
        ]
    metric_val[(a,b)] = np.linalg.norm(np.array(diff),ord=7)
    
metric_val
# Out:
# {('New York City', 'New York City'): 0.0,
#  ('New York City', 'Houston'): 1.169930812758687,
#  ('New York City', 'Los Angeles'): 1.7372440623952268,
#  ('New York City', 'Philadelphia'): 1.0,
#  ('New York City', 'San Diego'): 1.7423948319061235,
#  ('New York City', 'Chicago'): 1.0,
#  ('New York City', 'San Francisco'): 1.7423948319061235,
#  ('New York City', 'Las Vegas'): 1.7474558315662452,
#  ('New York City', 'Boston'): 1.0,
#  ('New York City', 'Oakland'): 1.7474558315662452,
#  ('New York City', 'Dallas'): 1.1040895136738123,
#  ('New York City', 'Fort Worth'): 1.2190136542044754,
#  ('New York City', 'Seattle'): 1.7474558315662452,
#  ('New York City', 'Phoenix'): 1.7372440623952268,
#  ('New York City', 'Charlotte'): 1.2190136542044754,
#  ('New York City', 'San Antonio'): 1.169930812758687,
#  ('New York City', 'Washington'): 1.1040895136738123,
#  ('New York City', 'Portland'): 1.7474558315662452,
#  ('New York City', 'Long Beach'): 1.7423948319061235,
#  ('New York City', 'San Jose'): 1.7474558315662452,
#  ('New York City', 'Austin'): 1.2190136542044754,
#  ('New York City', 'Detroit'): 1.2190136542044754,
#  ('New York City', 'Denver'): 1.7474558315662452,
#  ('New York City', 'Cleveland'): 1.2190136542044754,
#  ('New York City', 'Baltimore'): 1.2190136542044754,
#  ('New York City', 'Oklahoma City'): 1.2190136542044754,
#  ('New York City', 'Indianapolis'): 1.2190136542044754,
#  ('New York City', 'Columbus'): 1.2190136542044754,
#  ('New York City', 'Milwaukee'): 1.2190136542044754,
#  ('New York City', 'Kansas City'): 1.2190136542044754,
#  ('New York City', 'Tucson'): 1.7524303838023036,
#  ('New York City', 'Memphis'): 1.2190136542044754,
#  ('New York City', 'El Paso'): 1.2584989506418267,
#  ('New York City', 'Louisville'): 1.2190136542044754,
#  ('New York City', 'Minneapolis'): 1.2190136542044754,
#  ('Houston', 'New York City'): 1.169930812758687,
#  ('Houston', 'Houston'): 0.0,
#  ('Houston', 'Los Angeles'): 1.1040895136738123,
#  ('Houston', 'Philadelphia'): 1.1040895136738123,
#  ('Houston', 'San Diego'): 1.169930812758687,
#  ('Columbus', 'San Diego'): 1.1040895136738123,
#  ('Columbus', 'Chicago'): 1.169930812758687,
#  ('Columbus', 'San Francisco'): 1.1040895136738123,
#  ('Columbus', 'Las Vegas'): 1.0,
#  ('Columbus', 'Boston'): 1.169930812758687,
#  ('Columbus', 'Oakland'): 1.0,
#  ('Columbus', 'Dallas'): 1.169930812758687,
#  ('Columbus', 'Fort Worth'): 1.0,
#  ('Columbus', 'Seattle'): 1.0,
#  ('Columbus', 'Phoenix'): 1.169930812758687,
#  ('Columbus', 'Charlotte'): 1.0,
#  ('Columbus', 'San Antonio'): 1.1040895136738123,
#  ('Columbus', 'Washington'): 1.169930812758687,
#  ('Columbus', 'Portland'): 1.0,
#  ('Columbus', 'Long Beach'): 1.1040895136738123,
#  ('Columbus', 'San Jose'): 1.0,
#  ('Columbus', 'Austin'): 1.0,
#  ('Columbus', 'Detroit'): 1.1040895136738123,
#  ('Columbus', 'Denver'): 1.0,
#  ('Columbus', 'Cleveland'): 1.1040895136738123,
#  ('Columbus', 'Baltimore'): 1.169930812758687,
#  ('Columbus', 'Oklahoma City'): 1.0,
#  ('Columbus', 'Indianapolis'): 0.0,
#  ('Columbus', 'Columbus'): 0.0,
#  ('Columbus', 'Milwaukee'): 1.1040895136738123,
#  ('Columbus', 'Kansas City'): 0.0,
#  ('Columbus', 'Tucson'): 1.1040895136738123,
#  ('Columbus', 'Memphis'): 1.169930812758687,
#  ('Columbus', 'El Paso'): 1.1040895136738123,
#  ('Columbus', 'Louisville'): 1.0,
#  ('Columbus', 'Minneapolis'): 0.0,
#  ('Milwaukee', 'New York City'): 1.2190136542044754,
#  ('Milwaukee', 'Houston'): 1.1040895136738123,
#  ('Milwaukee', 'Los Angeles'): 1.169930812758687,
#  ('Milwaukee', 'Philadelphia'): 1.169930812758687,
#  ('Milwaukee', 'San Diego'): 1.2190136542044754,
#  ('Milwaukee', 'Chicago'): 1.169930812758687,
#  ('Milwaukee', 'San Francisco'): 1.2190136542044754,
#  ('Milwaukee', 'Las Vegas'): 1.169930812758687,
#  ('Milwaukee', 'Boston'): 1.169930812758687,
#  ('Milwaukee', 'Oakland'): 1.169930812758687,
#  ('Milwaukee', 'Dallas'): 1.169930812758687,
#  ('Milwaukee', 'Fort Worth'): 1.169930812758687,
#  ('Milwaukee', 'Seattle'): 1.169930812758687,
#  ('Milwaukee', 'Phoenix'): 1.169930812758687,
#  ('Milwaukee', 'Charlotte'): 1.169930812758687,
#  ('Milwaukee', 'San Antonio'): 1.2190136542044754,
#  ('Milwaukee', 'Washington'): 1.169930812758687,
#  ('Milwaukee', 'Portland'): 1.169930812758687,
#  ('Milwaukee', 'Long Beach'): 1.1040895136738123,
#  ('Milwaukee', 'San Jose'): 1.169930812758687,
#  ...}

# %%
metric_val[('Portland','Seattle')]
# Out:
# 0.0

# %%
metric_val[('New York City', 'Denver')]
# Out:
# 1.7474558315662452

# %%
temp = pd.Series(metric_val).reset_index()

pd.pivot_table(temp, index = 'level_0', columns = 'level_1')
# Out:
#                       0                                                    \
# Washington     1.169931  1.169931  1.219014   0.000000
#
# [35 rows x 35 columns]

# %%
temp[0].value_counts().sort_index()
# Out:
# 0
# 0.000000    107
# 1.000000    264
# 1.104090    296
# 1.169931    338
# 1.219014    122
# 1.258499     26
# 1.737244      8
# 1.742395     26
# 1.747456     24
# 1.752430     14
# Name: count, dtype: int64

# %%
#dict_metric['geo_label_city'] = lambda x,y : np.linalg.norm(np.array([metric_val[(x,y)],0.3 * metric_binary(x,y)]),ord=3)
dict_metric['geo_label_city'] = lambda x,y : metric_val[(x,y)]

# %%
dict_metric
# Out:
# {'strata_race_label': <function __main__.metric_on_adj.<locals>.<lambda>(x, y)>,
#  'strata_sex_label': <function __main__.metric_on_adj.<locals>.<lambda>(x, y)>,
#  'geo_strata_region': <function __main__.metric_on_adj.<locals>.<lambda>(x, y)>,
#  'geo_strata_poverty': <function __main__.<lambda>(x, y)>,
#  'geo_strata_Population': <function __main__.<lambda>(x, y)>,
#  'geo_strata_PopDensity': <function __main__.<lambda>(x, y)>,
#  'geo_strata_Segregation': <function __main__.<lambda>(x, y)>,
#  'geo_label_city': <function __main__.<lambda>(x, y)>}

# %%
dict_metric['geo_label_city'] ('Portland','Seattle')
# Out:
# 0.0

# %%
metric_val[('New York City', 'Denver')]
# Out:
# 1.7474558315662452

# %%
metric_val[('Portland','Seattle')]
# Out:
# 0.0

# %%
df_geo_info.loc[['Portland','Seattle']]
# Out:
#                geo_label_state geo_label_citystate geo_strata_region  \
# geo_label_city
# Portland                    OR        Portland, OR              West
# Seattle                     WA         Seattle, WA              West
#
#                           geo_strata_poverty   geo_strata_Population  \
# geo_label_city
# Portland        Less poor cities (<18% poor)  Smaller (<1.3 million)
# Seattle         Less poor cities (<18% poor)  Smaller (<1.3 million)
#
#                               geo_strata_PopDensity  geo_strata_Segregation  \
# geo_label_city
# Portland        Lower pop. density (<10k per sq mi)  Less Segregated (<50%)
# Seattle         Lower pop. density (<10k per sq mi)  Less Segregated (<50%)
#
#                 count
# geo_label_city
# Portland         5219
# Seattle          5507

# %% [markdown]
# - dict_metric을 pkl 파일로 저장해서 사용할 수 있을 것 같음

# %% [markdown]
# # KNN regression

# %% [markdown]
# ### LOAD DATA

# %%
pvtb_name = 'pvtb_city_entire_ver0.csv'


pvtb_path = os.path.join(pvtb_dir,pvtb_name)
pvtb_entire = pd.read_csv(pvtb_path)

pvtb_entire
# Out:
#      geo_label_city  date_label strata_race_label strata_sex_label  \
# 0            Austin        2010               All             Both
# 1            Austin        2010               All           Female
# 2            Austin        2010               All             Male
# 3            Austin        2010          Asian/PI             Both
# 4            Austin        2010          Asian/PI           Female
# ...             ...         ...               ...              ...
# 7275     Washington        2022          Hispanic             Male
# 7276     Washington        2022           Natives             Both
# 7277     Washington        2022             White             Both
# 7278     Washington        2022             White           Female
# 7279     Washington        2022             White             Male
#
#       Active Transportation | Riding Bike to Work  \
# 0                                        1.458997
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# ...                                           ...
# 7275                                          NaN
# 7276                                          NaN
# 7277                                          NaN
# 7278                                          NaN
# 7279                                          NaN
#
#       Active Transportation | Walking to Work  \
# 0                                    2.506039
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ...                                       ...
# 7275                                      NaN
# 7276                                 8.766234
# 7277                                14.201808
# 7278                                      NaN
# 7279                                      NaN
#
#       Air Pollution | Hazardous Air Quality  Air Pollution | Poor Air Quality  \
# 0                                  2.191781                         25.479452
# 1                                       NaN                               NaN
# 2                                       NaN                               NaN
# 3                                       NaN                               NaN
# 4                                       NaN                               NaN
# ...                                     ...                               ...
# 7275                                    NaN                               NaN
# 7276                                    NaN                               NaN
# 7277                                    NaN                               NaN
# 7278                                    NaN                               NaN
# 7279                                    NaN                               NaN
#
#       Birth Control | Teen Birth Control  Births | Low Birthweight  ...  \
# 0                                    NaN                  7.836414  ...
# 1                                    NaN                       NaN  ...
# 2                                    NaN                       NaN  ...
# 3                                    NaN                  8.785406  ...
# 4                                    NaN                       NaN  ...
# ...                                  ...                       ...  ...
# 7275                                 NaN                       NaN  ...
# 7276                                 NaN                       NaN  ...
# 7277                                 NaN                  5.574537  ...
# 7278                                 NaN                       NaN  ...
# 7279                                 NaN                       NaN  ...
#
#       Substance Use | Adult Smoking  Substance Use | Drug Overdose Deaths  \
# 0                              14.1                             14.814379
# 1                               NaN                             12.110401
# 2                               NaN                             17.451652
# 3                               NaN                                   NaN
# 4                               NaN                                   NaN
# ...                             ...                                   ...
# 7275                            NaN                             25.584642
# 7276                            NaN                                   NaN
# 7277                            NaN                             13.498547
# 7278                            NaN                              6.485127
# 7279                            NaN                             20.246498
#
#       Substance Use | Opioid Overdose Deaths  Substance Use | Teen Alcohol  \
# 0                                   5.316296                           NaN
# 1                                   4.224056                           NaN
# 2                                   6.417004                           NaN
# 3                                        NaN                           NaN
# 4                                        NaN                           NaN
# ...                                      ...                           ...
# 7275                               21.067009                           NaN
# 7276                                     NaN                           NaN
# 7277                                8.887272                           NaN
# 7278                                     NaN                           NaN
# 7279                               14.137920                           NaN
#
#       Substance Use | Teen Marijuana  Substance Use | Teen Smoking  \
# 0                                NaN                           NaN
# 1                                NaN                           NaN
# 2                                NaN                           NaN
# 3                                NaN                           NaN
# 4                                NaN                           NaN
# ...                              ...                           ...
# 7275                             NaN                           NaN
# 7276                             NaN                           NaN
# 7277                             NaN                           NaN
# 7278                             NaN                           NaN
# 7279                             NaN                           NaN
#
#       Transportation | Drives Alone to Work  Transportation | Lack of Car  \
# 0                                 71.701852                      7.104797
# 1                                       NaN                           NaN
# 2                                       NaN                           NaN
# 3                                       NaN                           NaN
# 4                                       NaN                           NaN
# ...                                     ...                           ...
# 7275                                    NaN                           NaN
# 7276                              19.237013                           NaN
# 7277                              24.173919                           NaN
# 7278                                    NaN                           NaN
# 7279                                    NaN                           NaN
#
#       Transportation | Longer Driving Commute Time  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# ...                                            ...
# 7275                                           NaN
# 7276                                           NaN
# 7277                                           NaN
# 7278                                           NaN
# 7279                                           NaN
#
#       Transportation | Public Transportation Use
# 0                                       4.673879
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# ...                                          ...
# 7275                                         NaN
# 7276                                   38.879870
# 7277                                   21.684225
# 7278                                         NaN
# 7279                                         NaN
#
# [7280 rows x 122 columns]

# %% [markdown]
# **user defined metric on dataset**
#
# - city 사이의 metric은 city 이름과 독립적인 변수로 정의한 내용을 저장해 놓은 것 뿐이 때문에 아래에서 metric을 구할 때 city간 metric을 이용해도 무관함
# - city 사이의 거리와 year 사이 거리의 euclidean으로 시도

# %%
def metric_cityyear(X,Y):
    city_x,city_y = city_list[int(X[0])],city_list[int(Y[0])]
    diff = [dict_metric['geo_label_city'](city_x,city_y),
            abs(X[1]-Y[1]),
            dict_metric['strata_race_label'](X[2],Y[2]),
            dict_metric['strata_sex_label'](X[3],Y[3]),
            ]
    return np.linalg.norm(np.array(diff),ord=5)

# %%
dict_metric['strata_race_label']('White','Black')
# Out:
# 1.732

# %%
weight_norm = np.array([0.4,0.1,0.5,0.5])

def metric_cityyear_weighted(X,Y):
    city_x,city_y = city_list[int(X[0])],city_list[int(Y[0])]
    race_x, race_y = entire_race[int(X[2])], entire_race[int(Y[2])]
    sex_x, sex_y = entire_sex[int(X[3])], entire_sex[int(Y[3])]
    diff = [dict_metric['geo_label_city'](city_x,city_y),
            abs(X[1]-Y[1]),
            dict_metric['strata_race_label'](race_x,race_y),
            dict_metric['strata_sex_label'](sex_x,sex_y),
            ]
    return np.linalg.norm(np.array(diff)*weight_norm,ord=5)

vec_metric_cy_weighted= np.vectorize(metric_cityyear_weighted)
#함수 내에서 쓰인 외부의 변수들도 decompose하려고 하기 때문에, city_list 등을 모두 exclude 해야 작동함

# %%
a = np.arange(5)
print(type(a[0]))
city_list[a[0]]
# Out:
# <class 'numpy.int64'>
# 'New York City'

# %%
import numpy as np

def g(x,p):
  return p[0]+x*p[1]+x*x*p[2]

print(g(5,[0,0,1]))

vg = np.vectorize(g, excluded=['p'])
print(vg(x=[0,1,2,3,4,5],p=[0,1,2]))
# Out:
# 25
# [ 0  3 10 21 36 55]

# %%
weight_norm = np.array([0.4,0.1,0.5,0.5])
#weight를 1보다 작게 주는 것이 정수로 주는 것보다
#vectorize 안 한 상황에서는 한번씩 해봤을 때는 빠르게 나왔음

def metric_cityyear_weighted(city_list,entire_race,entire_sex,dict_metric,weight_norm,X,Y):
    city_x, city_y = city_list[int(X[0])],city_list[int(Y[0])]
    race_x, race_y = entire_race[int(X[2])], entire_race[int(Y[2])]
    sex_x, sex_y = entire_sex[int(X[3])], entire_sex[int(Y[3])]
    diff = [dict_metric['geo_label_city'](city_x,city_y),
            abs(X[1]-Y[1]),
            dict_metric['strata_race_label'](race_x,race_y),
            dict_metric['strata_sex_label'](sex_x,sex_y),
            ]
    return np.linalg.norm(np.array(diff)*weight_norm,ord=5)

vec_metric_cy_weighted= np.vectorize(lambda x, y : metric_cityyear_weighted(city_list,entire_race,entire_sex,dict_metric,weight_norm,x,y),excluded={0,1})
vec_metric_cy_noweight= np.vectorize(lambda x, y : metric_cityyear_weighted(city_list,entire_race,entire_sex,dict_metric,[0.25,0.25,0.25,0.25],x,y),excluded={0,1})
vec_metric_cy_noweight2= np.vectorize(lambda x, y : metric_cityyear_weighted(city_list,entire_race,entire_sex,dict_metric,[1,1,1,1],x,y),excluded={0,1})

# %%
vec_metric_city = np.vectorize(dict_metric['geo_label_city'])

# %%
def idx2city(city_list,idx):
    return city_list[idx]

idx2city(city_list,0)
# Out:
# 'New York City'

# %%
vec_idx2city=np.vectorize(idx2city,excluded={0})

# %%
vec_idx2city(city_list,0)
# Out:
# array('New York City', dtype='<U13')

# %%
vec_metric_city('New York City','Portland')
# Out:
# array(1.74745583)

# %%
vec_metric_cy_weighted(np.array([20,2010,0,0]),np.array([20,2010,0,1]))
# Out:
# 0.866

# %%
type(vec_metric_cy_weighted)
# Out:
# numpy.vectorize

# %%
from sklearn.neighbors import KNeighborsRegressor

test_col = [
    'Deaths | Premature Death',                                  
    'Deaths | Injury Deaths',                                    
    'Cancer | All Cancer Deaths',                                
    'Cardiovascular Disease | Cardiovascular Disease Deaths',    
    'Deaths | Deaths from All Causes',                           
    'Substance Use | Drug Overdose Deaths',                      
    'Cardiovascular Disease | Heart Disease Deaths',             
    'Diabetes and Obesity | Diabetes Deaths',                    
    'Cancer | Lung Cancer Deaths',                               
    'Life Expectancy at Birth | Life Expectancy',                
    'Mental Health | Suicide',                                   
    'Deaths | Motor Vehicle Deaths',                             
    'Deaths | Gun Deaths (Firearms)',                            
    'Respiratory Infection | Pneumonia or Influenza Deaths',     
    'Substance Use | Opioid Overdose Deaths',                    
    'Cancer | Colorectal Cancer Deaths',                         
    'Crime Incidents | Homicides',                               
]

# %%
test_df = pvtb_entire[['geo_label_city','date_label','strata_race_label','strata_sex_label',test_col[0]]]
test_df
# Out:
#      geo_label_city  date_label strata_race_label strata_sex_label  \
# 0            Austin        2010               All             Both
# 1            Austin        2010               All           Female
# 2            Austin        2010               All             Male
# 3            Austin        2010          Asian/PI             Both
# 4            Austin        2010          Asian/PI           Female
# ...             ...         ...               ...              ...
# 7275     Washington        2022          Hispanic             Male
# 7276     Washington        2022           Natives             Both
# 7277     Washington        2022             White             Both
# 7278     Washington        2022             White           Female
# 7279     Washington        2022             White             Male
#
#       Deaths | Premature Death
# 0                  5094.792265
# 1                  3807.898474
# 2                  6377.256790
# 3                  2579.797021
# 4                  2025.151915
# ...                        ...
# 7275               6300.589535
# 7276                       NaN
# 7277               2231.116039
# 7278               1609.792900
# 7279               2815.793085
#
# [7280 rows x 5 columns]

# %%
city_list
# Out:
# ['New York City',
#  'Houston',
#  'Los Angeles',
#  'Philadelphia',
#  'San Diego',
#  'Chicago',
#  'San Francisco',
#  'Las Vegas',
#  'Boston',
#  'Oakland',
#  'Dallas',
#  'Fort Worth',
#  'Seattle',
#  'Phoenix',
#  'Charlotte',
#  'San Antonio',
#  'Washington',
#  'Portland',
#  'Long Beach',
#  'San Jose',
#  'Austin',
#  'Detroit',
#  'Denver',
#  'Cleveland',
#  'Baltimore',
#  'Oklahoma City',
#  'Indianapolis',
#  'Columbus',
#  'Milwaukee',
#  'Kansas City',
#  'Tucson',
#  'Memphis',
#  'El Paso',
#  'Louisville',
#  'Minneapolis']

# %%
entire_race, entire_sex
# Out:
# (['All', 'White', 'Black', 'Hispanic', 'Asian/PI', 'Natives'],
#  ['Both', 'Female', 'Male'])

# %%
test_df['city_idx'] = test_df['geo_label_city'].apply(lambda x : city_list.index(x))
test_df['race_idx'] = test_df['strata_race_label'].apply(lambda x : entire_race.index(x))
test_df['sex_idx'] = test_df['strata_sex_label'].apply(lambda x : entire_sex.index(x))
# Out:
# /tmp/ipykernel_206470/87728289.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['city_idx'] = test_df['geo_label_city'].apply(lambda x : city_list.index(x))
# /tmp/ipykernel_206470/87728289.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['race_idx'] = test_df['strata_race_label'].apply(lambda x : entire_race.index(x))
# /tmp/ipykernel_206470/87728289.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['sex_idx'] = test_df['strata_sex_label'].apply(lambda x : entire_sex.index(x))

# %%
test_nonan = test_df.dropna()
racesex_col = ['strata_race_label','strata_sex_label']
X= test_nonan[['city_idx','date_label']+['race_idx','sex_idx']]
y = test_nonan[test_col[0]]

# %%
X.head()
# Out:
#    city_idx  date_label  race_idx  sex_idx
# 0        20        2010         0        0
# 1        20        2010         0        1
# 2        20        2010         0        2
# 3        20        2010         4        0
# 4        20        2010         4        1

# %%
metric_cityyear_weighted(X.iloc[0],X.iloc[1])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/doeun/code/AI/ESTSOFT2024/workspace/1.project1_structured/BCHI/research/240620_how_to_fill_missing_knn.ipynb Cell 75 in 1
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/doeun/code/AI/ESTSOFT2024/workspace/1.project1_structured/BCHI/research/240620_how_to_fill_missing_knn.ipynb#Y134sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> metric_cityyear_weighted(X.iloc[0],X.iloc[1])
#
# TypeError: metric_cityyear_weighted() missing 5 required positional arguments: 'entire_sex', 'dict_metric', 'weight_norm', 'X', and 'Y'

# %%
input = np.array([X.iloc[0],X.iloc[1]])

input[0]
# Out:
# array([  20, 2010,    0,    0])

# %%
knn_test = KNeighborsRegressor(n_neighbors=5,weights='distance',metric=vec_metric_cy_weighted,algorithm='auto')

# %%
knn_test.fit(X,y)
# Out:
# KNeighborsRegressor(metric=<numpy.vectorize object at 0x7f0f9aef9b20>,
#                     weights='distance')

# %%
y_pred   = knn_test.predict(X)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/doeun/code/AI/ESTSOFT2024/workspace/1.project1_structured/BCHI/research/240620_how_to_fill_missing_knn.ipynb Cell 79 in 1
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/doeun/code/AI/ESTSOFT2024/workspace/1.project1_structured/BCHI/research/240620_how_to_fill_missing_knn.ipynb#Y141sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> y_pred   = knn_test.predict(X)
#
# File ~/anaconda3/envs/EST_NA/lib/python3.8/site-packages/sklearn/neighbors/_regression.py:240, in KNeighborsRegressor.predict(self, X)
#     238     neigh_dist = None
#     239 else:
# --> 240     neigh_dist, neigh_ind = self.kneighbors(X)
#     242 weights = _get_weights(neigh_dist, self.weights)
#     244 _y = self._y
#
# File ~/anaconda3/envs/EST_NA/lib/python3.8/site-packages/sklearn/neighbors/_base.py:877, in KNeighborsMixin.kneighbors(self, X, n_neighbors, return_distance)
#     871     if issparse(X):
#     872         raise ValueError(
#     873             "%s does not work with sparse matrices. Densify the data, "
#     874             "or set algorithm='brute'"
#     875             % self._fit_method
#     876         )
# --> 877     chunked_results = Parallel(n_jobs, prefer="threads")(
#     878         delayed(_tree_query_parallel_helper)(
#     879             self._tree, X[s], n_neighbors, return_distance
#     880         )
#     881         for s in gen_even_slices(X.shape[0], n_jobs)
#     882     )
#     883 else:
#     884     raise ValueError("internal: _fit_method not recognized")
#
# File ~/anaconda3/envs/EST_NA/lib/python3.8/site-packages/sklearn/utils/parallel.py:65, in Parallel.__call__(self, iterable)
#      60 config = get_config()
#      61 iterable_with_config = (
#      62     (_with_config(delayed_func, config), args, kwargs)
#      63     for delayed_func, args, kwargs in iterable
#      64 )
# ---> 65 return super().__call__(iterable_with_config)
#
# File ~/anaconda3/envs/EST_NA/lib/python3.8/site-packages/joblib/parallel.py:1918, in Parallel.__call__(self, iterable)
#    1916     output = self._get_sequential_output(iterable)
#    1917     next(output)
# -> 1918     return output if self.return_generator else list(output)
#    1920 # Let's create an ID that uniquely identifies the current call. If the
#    1921 # call is interrupted early and that the same instance is immediately
#    1922 # re-used, this id will be used to prevent workers that were
#    1923 # concurrently finalizing a task from the previous call to run the
#    1924 # callback.
#    1925 with self._lock:
#
# File ~/anaconda3/envs/EST_NA/lib/python3.8/site-packages/joblib/parallel.py:1847, in Parallel._get_sequential_output(self, iterable)
#    1845 self.n_dispatched_batches += 1
#    1846 self.n_dispatched_tasks += 1
# -> 1847 res = func(*args, **kwargs)
#    1848 self.n_completed_tasks += 1
#    1849 self.print_progress()
#
# File ~/anaconda3/envs/EST_NA/lib/python3.8/site-packages/sklearn/utils/parallel.py:127, in _FuncWrapper.__call__(self, *args, **kwargs)
#     125     config = {}
#     126 with config_context(**config):
# --> 127     return self.function(*args, **kwargs)
#
# File ~/anaconda3/envs/EST_NA/lib/python3.8/site-packages/sklearn/neighbors/_base.py:683, in _tree_query_parallel_helper(tree, *args, **kwargs)
#     677 def _tree_query_parallel_helper(tree, *args, **kwargs):
#     678     """Helper for the Parallel calls in KNeighborsMixin.kneighbors.
#     679
#     680     The Cython method tree.query is not directly picklable by cloudpickle
#     681     under PyPy.
#     682     """
# --> 683     return tree.query(*args, **kwargs)
#
# File sklearn/neighbors/_binary_tree.pxi:1159, in sklearn.neighbors._ball_tree.BinaryTree.query()
#
# File sklearn/neighbors/_binary_tree.pxi:1621, in sklearn.neighbors._ball_tree.BinaryTree._query_single_depthfirst()
#
# File sklearn/neighbors/_binary_tree.pxi:1621, in sklearn.neighbors._ball_tree.BinaryTree._query_single_depthfirst()
#
# File sklearn/neighbors/_binary_tree.pxi:1619, in sklearn.neighbors._ball_tree.BinaryTree._query_single_depthfirst()
#
# File sklearn/neighbors/_binary_tree.pxi:1619, in sklearn.neighbors._ball_tree.BinaryTree._query_single_depthfirst()
#
# File sklearn/neighbors/_binary_tree.pxi:1621, in sklearn.neighbors._ball_tree.BinaryTree._query_single_depthfirst()
#
# File sklearn/neighbors/_binary_tree.pxi:1624, in sklearn.neighbors._ball_tree.BinaryTree._query_single_depthfirst()
#
# File sklearn/neighbors/_binary_tree.pxi:1621, in sklearn.neighbors._ball_tree.BinaryTree._query_single_depthfirst()
#
# File sklearn/neighbors/_binary_tree.pxi:1602, in sklearn.neighbors._ball_tree.BinaryTree._query_single_depthfirst()
#
# File sklearn/neighbors/_binary_tree.pxi:1007, in sklearn.neighbors._ball_tree.BinaryTree.rdist()
#
# File sklearn/metrics/_dist_metrics.pyx:478, in sklearn.metrics._dist_metrics.DistanceMetric64.rdist()
#
# File sklearn/metrics/_dist_metrics.pyx:2773, in sklearn.metrics._dist_metrics.PyFuncDistance64.dist()
#
# File sklearn/metrics/_dist_metrics.pyx:2784, in sklearn.metrics._dist_metrics.PyFuncDistance64._dist()
#
# File ~/anaconda3/envs/EST_NA/lib/python3.8/site-packages/numpy/lib/function_base.py:2329, in vectorize.__call__(self, *args, **kwargs)
#    2326     vargs = [args[_i] for _i in inds]
#    2327     vargs.extend([kwargs[_n] for _n in names])
# -> 2329 return self._vectorize_call(func=func, args=vargs)
#
# File ~/anaconda3/envs/EST_NA/lib/python3.8/site-packages/numpy/lib/function_base.py:2405, in vectorize._vectorize_call(self, func, args)
#    2403     res = self._vectorize_call_with_signature(func, args)
#    2404 elif not args:
# -> 2405     res = func()
#    2406 else:
#    2407     ufunc, otypes = self._get_ufunc_and_otypes(func=func, args=args)
#
# File ~/anaconda3/envs/EST_NA/lib/python3.8/site-packages/numpy/lib/function_base.py:2324, in vectorize.__call__.<locals>.func(*vargs)
#    2322     the_args[_i] = vargs[_n]
#    2323 kwargs.update(zip(names, vargs[len(inds):]))
# -> 2324 return self.pyfunc(*the_args, **kwargs)
#
# KeyboardInterrupt:

# %%
from sklearn.metrics import mean_squared_error

print(mean_squared_error(y_pred,y))
print(mean_squared_error([np.mean(y)]*len(y),y))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/doeun/code/AI/ESTSOFT2024/workspace/1.project1_structured/BCHI/research/240620_how_to_fill_missing_knn.ipynb Cell 80 in 3
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/doeun/code/AI/ESTSOFT2024/workspace/1.project1_structured/BCHI/research/240620_how_to_fill_missing_knn.ipynb#Y142sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> from sklearn.metrics import mean_squared_error
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/doeun/code/AI/ESTSOFT2024/workspace/1.project1_structured/BCHI/research/240620_how_to_fill_missing_knn.ipynb#Y142sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> print(mean_squared_error(y_pred,y))
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/doeun/code/AI/ESTSOFT2024/workspace/1.project1_structured/BCHI/research/240620_how_to_fill_missing_knn.ipynb#Y142sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> print(mean_squared_error([np.mean(y)]*len(y),y))
#
# NameError: name 'y_pred' is not defined

# %%
from sklearn.metrics import mean_absolute_percentage_error, mean_squared_error, mean_squared_log_error, r2_score

print(mean_absolute_percentage_error(y_pred,y))
print(mean_absolute_percentage_error([np.mean(y)]*len(y),y))
print()
print(np.sqrt(mean_squared_error(y_pred,y)))
print(np.sqrt(mean_squared_error([np.mean(y)]*len(y),y)))
print()
print(np.sqrt(mean_squared_log_error(y_pred,y)))
print(np.sqrt(mean_squared_log_error([np.mean(y)]*len(y),y)))

print(r2_score(y,y_pred))
# Out:
# 0.09444136712344771
# 0.4351945227627554
#
# 1088.3433265188785
# 4083.4416513835763
#
# 0.15958008485761127
# 0.5623152636954458

# %%
len(y_pred), len(y)
# Out:
# (6825, 6825)

# %%
fig,ax = plt.subplots()
ax.plot(y,y,alpha = 0.3)
ax.scatter(y_pred,y,s=3, alpha = 0.8)
pass

# %%
fig,axes = plt.subplots(2,1)
sns.histplot(y,label='actual',ax=axes[0],alpha=0.5)
sns.histplot(y_pred,label='knn_pred',ax=axes[0],alpha=0.5)

sns.histplot(y-np.mean(y),ax=axes[1], label = 'baseline',alpha=0.5)
sns.histplot(y-y_pred,ax=axes[1], label = 'knn_pred',alpha=0.5)
axes[0].legend()

print(y.mean(),y.std())
# Out:
# 7220.0270940443515 4083.740837496106

# %% [markdown]
# ### train test split and cross validation

# %%
from sklearn.model_selection import train_test_split, cross_val_score, cross_val_predict
from sklearn.metrics import r2_score

# %%
from sklearn.model_selection import train_test_split, cross_val_score, cross_val_predict
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_percentage_error as mape
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import mean_squared_log_error as msle

# %%
train_X, test_X, train_y, test_y = train_test_split(X,y,
                                                    test_size = 0.2,
                                                    random_state=801) #check how to using stratify option

display(train_X.shape)
display(test_X.shape)
display(train_y.shape)
display(test_y .shape)
# Out:
# (5460, 4)
# (1365, 4)
# (5460,)
# (1365,)

# %%
knn_model = KNeighborsRegressor(n_neighbors=7,weights='distance',metric=vec_metric_cy_weighted,algorithm='auto')
knn_model.fit(train_X, train_y)
# Out:
# KNeighborsRegressor(metric=<numpy.vectorize object at 0x7f10414e3610>,
#                     n_neighbors=7, weights='distance')

# %%
y_pred = knn_model.predict(test_X)

#n=5, 7 둘다 시간/MSE에 큰 차이는 없는 것으로 보임
#k_nn 특성상 train set의 크기가 시간/MSE에 더 큰 영향을 주는 것으로 보임

# %%
print("test rmse : ",np.sqrt(mean_squared_error(y_pred,test_y)),"/ baseline rmse : ", np.sqrt(mean_squared_error([train_y.mean()]*len(test_y),test_y)))
print("test mape : ",(mape(y_pred,test_y)),"/ baseline mape : ", (mape([train_y.mean()]*len(test_y),test_y)))
print("r2 score : ", r2_score(test_y,y_pred))

fig,ax = plt.subplots()
ax.plot(test_y,test_y,alpha = 0.3, lw=1.5)
ax.scatter(test_y,y_pred,s=3, alpha = 0.7)
ax.set_xlabel('Prediction')
ax.set_ylabel('Actual')
ax.set_title(test_col[0])
pass
# Out:
# test rmse :  1594.6763472121118 / baseline rmse :  4027.8392351868088
# test mape :  0.1627628847459461 / baseline mape :  0.43784585184730046
# r2 score :  0.8430551686192889

# %%
data = pd.DataFrame(data = test_y)
data.columns = ['actual']
data['knn_pred'] = y_pred
data
# Out:
#            actual     knn_pred
# 1775  6714.055103  6729.605471
# 3351  7574.098632  7799.727427
# 4553  5646.357481  7634.705649
# 5103  8633.328322  8244.794851
# 1418  3784.795546  3688.870007
# ...           ...          ...
# 789   3830.174434  4446.625832
# 3715  3502.083552  4396.586933
# 6659  3481.654688  3472.485875
# 2266  5417.272148  4867.306418
# 6417  3103.213160  3243.446384
#
# [1365 rows x 2 columns]

# %%
fig,axes = plt.subplots(2,1)

sns.histplot(test_y,label='actual',ax=axes[0],alpha=0.5)
sns.histplot(y_pred,label='knn_pred',ax=axes[0],alpha=0.5)

sns.histplot(test_y-np.mean(train_y),ax=axes[1], label = 'baseline',alpha=0.5)
sns.histplot(test_y-y_pred,ax=axes[1], label = 'knn_pred',alpha=0.5)
axes[0].legend()
axes[0].set_title('Distributions of Actual and Predicted Values')
axes[0].set_xlabel('')
axes[1].set_title('Distributions of Errors')

print(test_y.mean(),test_y.std())
# Out:
# 7105.79272914359 4026.7826091168167

# %%
knn_model = KNeighborsRegressor(n_neighbors=5,weights='distance',metric=vec_metric_cy_weighted,algorithm='auto')
knn_model.fit(train_X, train_y)
# Out:
# KNeighborsRegressor(metric=<numpy.vectorize object at 0x7f0f9aef9b20>,
#                     weights='distance')

# %%
y_pred = knn_model.predict(test_X)

#n=5, 7 둘다 시간/MSE에 큰 차이는 없는 것으로 보임
#k_nn 특성상 train set의 크기가 시간/MSE에 더 큰 영향을 주는 것으로 보임

# %%
print("test rmse : ",np.sqrt(mean_squared_error(y_pred,test_y)),"/ baseline rmse : ", np.sqrt(mean_squared_error([train_y.mean()]*len(test_y),test_y)))
print("test mape : ",(mape(y_pred,test_y)),"/ baseline mape : ", (mape([train_y.mean()]*len(test_y),test_y)))
print("r2 score : ", r2_score(test_y,y_pred))

fig,ax = plt.subplots()
ax.plot(test_y,test_y,alpha = 0.3, lw=1.5)
ax.scatter(test_y,y_pred,s=3, alpha = 0.7)
ax.set_xlabel('Prediction')
ax.set_ylabel('Actual')
ax.set_title(test_col[0])
pass
# Out:
# test rmse :  1578.8585894084215 / baseline rmse :  4027.8392351868088
# test mape :  0.1579565424505716 / baseline mape :  0.43784585184730046
# r2 score :  0.8461532307105573

# %%
fig,axes = plt.subplots(2,1)

sns.histplot(test_y,label='actual',ax=axes[0],alpha=0.5)
sns.histplot(y_pred,label='knn_pred',ax=axes[0],alpha=0.5)

sns.histplot(test_y-np.mean(train_y),ax=axes[1], label = 'baseline',alpha=0.5)
sns.histplot(test_y-y_pred,ax=axes[1], label = 'knn_pred',alpha=0.5)
axes[0].legend()
axes[0].set_title('Distributions of Actual and Predicted Values')
axes[0].set_xlabel('')
axes[1].set_title('Distributions of Errors')

print(test_y.mean(),test_y.std())
# Out:
# 7105.79272914359 4026.7826091168167

# %% [markdown]
# ### when without weight

# %%
knn_model = KNeighborsRegressor(n_neighbors=7,weights='distance',metric=vec_metric_cy_noweight,algorithm='auto')
knn_model.fit(train_X, train_y)
# Out:
# KNeighborsRegressor(metric=<numpy.vectorize object at 0x7f0f9aef9ac0>,
#                     n_neighbors=7, weights='distance')

# %%
y_pred = knn_model.predict(test_X)

#n=5, 7 둘다 시간/MSE에 큰 차이는 없는 것으로 보임
#k_nn 특성상 train set의 크기가 시간/MSE에 더 큰 영향을 주는 것으로 보임

# %%
print("test rmse : ",np.sqrt(mean_squared_error(y_pred,test_y)),"/ baseline rmse : ", np.sqrt(mean_squared_error([train_y.mean()]*len(test_y),test_y)))
print("test mape : ",(mape(y_pred,test_y)),"/ baseline mape : ", (mape([train_y.mean()]*len(test_y),test_y)))
print("r2 score : ", r2_score(test_y,y_pred))

fig,ax = plt.subplots()
ax.plot(test_y,test_y,alpha = 0.3, lw=1.5)
ax.scatter(test_y,y_pred,s=3, alpha = 0.7)
ax.set_xlabel('Prediction')
ax.set_ylabel('Actual')
ax.set_title(test_col[0])
pass
# Out:
# test rmse :  1832.4998522350352 / baseline rmse :  4027.8392351868088
# test mape :  0.20272464681097785 / baseline mape :  0.43784585184730046
# r2 score :  0.7927522572903493

# %%
fig,axes = plt.subplots(2,1)

sns.histplot(test_y,label='actual',ax=axes[0],alpha=0.5)
sns.histplot(y_pred,label='knn_pred',ax=axes[0],alpha=0.5)

sns.histplot(test_y-np.mean(train_y),ax=axes[1], label = 'baseline',alpha=0.5)
sns.histplot(test_y-y_pred,ax=axes[1], label = 'knn_pred',alpha=0.5)
axes[0].legend()
axes[0].set_title('Distributions of Actual and Predicted Values')
axes[0].set_xlabel('')
axes[1].set_title('Distributions of Errors')

print(test_y.mean(),test_y.std())
# Out:
# 7105.79272914359 4026.7826091168167

# %%
knn_model = KNeighborsRegressor(n_neighbors=5,weights='distance',metric=vec_metric_cy_noweight,algorithm='auto')
knn_model.fit(train_X, train_y)
# Out:
# KNeighborsRegressor(metric=<numpy.vectorize object at 0x7f0f9aef9ac0>,
#                     weights='distance')

# %%
y_pred = knn_model.predict(test_X)

#n=5, 7 둘다 시간/MSE에 큰 차이는 없는 것으로 보임
#k_nn 특성상 train set의 크기가 시간/MSE에 더 큰 영향을 주는 것으로 보임

# %%
print("test rmse : ",np.sqrt(mean_squared_error(y_pred,test_y)),"/ baseline rmse : ", np.sqrt(mean_squared_error([train_y.mean()]*len(test_y),test_y)))
print("test mape : ",(mape(y_pred,test_y)),"/ baseline mape : ", (mape([train_y.mean()]*len(test_y),test_y)))
print("r2 score : ", r2_score(test_y,y_pred))

fig,ax = plt.subplots()
ax.plot(test_y,test_y,alpha = 0.3, lw=1.5)
ax.scatter(test_y,y_pred,s=3, alpha = 0.7)
ax.set_xlabel('Prediction')
ax.set_ylabel('Actual')
ax.set_title(test_col[0])
pass
# Out:
# test rmse :  1865.3876685980745 / baseline rmse :  4027.8392351868088
# test mape :  0.2081095812976489 / baseline mape :  0.43784585184730046
# r2 score :  0.7852465668576445

# %%
fig,axes = plt.subplots(2,1)

sns.histplot(test_y,label='actual',ax=axes[0],alpha=0.5)
sns.histplot(y_pred,label='knn_pred',ax=axes[0],alpha=0.5)

sns.histplot(test_y-np.mean(train_y),ax=axes[1], label = 'baseline',alpha=0.5)
sns.histplot(test_y-y_pred,ax=axes[1], label = 'knn_pred',alpha=0.5)
axes[0].legend()
axes[0].set_title('Distributions of Actual and Predicted Values')
axes[0].set_xlabel('')
axes[1].set_title('Distributions of Errors')

print(test_y.mean(),test_y.std())
# Out:
# 7105.79272914359 4026.7826091168167

# %%
knn_model = KNeighborsRegressor(n_neighbors=5,weights='distance',metric='cosine',algorithm='auto')
knn_model.fit(train_X, train_y)
# Out:
# KNeighborsRegressor(metric='cosine', weights='distance')

# %%
knn_model = KNeighborsRegressor(n_neighbors=5,weights='distance',metric='thank',algorithm='auto')
knn_model.fit(train_X, train_y)
# Out:
# ---------------------------------------------------------------------------
# InvalidParameterError                     Traceback (most recent call last)
# /home/doeun/code/AI/ESTSOFT2024/workspace/1.project1_structured/BCHI/research/240620_how_to_fill_missing_knn.ipynb Cell 108 in 2
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/doeun/code/AI/ESTSOFT2024/workspace/1.project1_structured/BCHI/research/240620_how_to_fill_missing_knn.ipynb#Y255sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> knn_model = KNeighborsRegressor(n_neighbors=5,weights='distance',metric='thank',algorithm='auto')
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/doeun/code/AI/ESTSOFT2024/workspace/1.project1_structured/BCHI/research/240620_how_to_fill_missing_knn.ipynb#Y255sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> knn_model.fit(train_X, train_y)
#
# File ~/anaconda3/envs/EST_NA/lib/python3.8/site-packages/sklearn/base.py:1145, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1140 partial_fit_and_fitted = (
#    1141     fit_method.__name__ == "partial_fit" and _is_fitted(estimator)
#    1142 )
#    1144 if not global_skip_validation and not partial_fit_and_fitted:
# -> 1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
#    1152     return fit_method(estimator, *args, **kwargs)
#
# File ~/anaconda3/envs/EST_NA/lib/python3.8/site-packages/sklearn/base.py:638, in BaseEstimator._validate_params(self)
#     630 def _validate_params(self):
#     631     """Validate types and values of constructor parameters
#     632
#     633     The expected type and values must be defined in the `_parameter_constraints`
#    (...)
#     636     accepted constraints.
#     637     """
# --> 638     validate_parameter_constraints(
#     639         self._parameter_constraints,
#     640         self.get_params(deep=False),
#     641         caller_name=self.__class__.__name__,
#     642     )
#
# File ~/anaconda3/envs/EST_NA/lib/python3.8/site-packages/sklearn/utils/_param_validation.py:96, in validate_parameter_constraints(parameter_constraints, params, caller_name)
#      90 else:
#      91     constraints_str = (
#      92         f"{', '.join([str(c) for c in constraints[:-1]])} or"
#      93         f" {constraints[-1]}"
#      94     )
# ---> 96 raise InvalidParameterError(
#      97     f"The {param_name!r} parameter of {caller_name} must be"
#      98     f" {constraints_str}. Got {param_val!r} instead."
#      99 )
#
# InvalidParameterError: The 'metric' parameter of KNeighborsRegressor must be a str among {'pyfunc', 'russellrao', 'p', 'canberra', 'mahalanobis', 'nan_euclidean', 'chebyshev', 'seuclidean', 'haversine', 'correlation', 'hamming', 'rogerstanimoto', 'precomputed', 'kulsinski', 'sokalmichener', 'cosine', 'l1', 'braycurtis', 'sokalsneath', 'infinity', 'l2', 'sqeuclidean', 'manhattan', 'yule', 'jaccard', 'cityblock', 'minkowski', 'euclidean', 'dice'} or a callable. Got 'thank' instead.

# %%
knn_model = KNeighborsRegressor(n_neighbors=5,weights='distance',metric='canberra',algorithm='auto')
knn_model.fit(train_X, train_y)
# Out:
# KNeighborsRegressor(metric='canberra', weights='distance')

# %%
knn_model = KNeighborsRegressor(n_neighbors=5,weights='distance',metric='rogerstanimoto',algorithm='auto')
knn_model.fit(train_X, train_y)
# Out:
# KNeighborsRegressor(metric='rogerstanimoto', weights='distance')

# %%
y_pred = knn_model.predict(test_X)

#n=5, 7 둘다 시간/MSE에 큰 차이는 없는 것으로 보임
#k_nn 특성상 train set의 크기가 시간/MSE에 더 큰 영향을 주는 것으로 보임

# %%
print("test rmse : ",np.sqrt(mean_squared_error(y_pred,test_y)),"/ baseline rmse : ", np.sqrt(mean_squared_error([train_y.mean()]*len(test_y),test_y)))
print("test mape : ",(mape(y_pred,test_y)),"/ baseline mape : ", (mape([train_y.mean()]*len(test_y),test_y)))
print("r2 score : ", r2_score(test_y,y_pred))

fig,ax = plt.subplots()
ax.plot(test_y,test_y,alpha = 0.3, lw=1.5)
ax.scatter(test_y,y_pred,s=3, alpha = 0.7)
ax.set_xlabel('Prediction')
ax.set_ylabel('Actual')
ax.set_title(test_col[0])
pass
# Out:
# test rmse :  15.719239232862785 / baseline rmse :  15.186505772665296
# test mape :  0.5195449081977226 / baseline mape :  0.416479326054475
# r2 score :  -0.07472092721882695

# %% [markdown]
# ## check for other labels

# %%
test_cols =[
    'Substance Use | Opioid Overdose Deaths',                    
    'Births | Prenatal Care',                                    
    'Life Expectancy at Birth | Life Expectancy',                
    'Sexually Transmitted Disease | HIV/AIDS Prevalence',        
    'Respiratory Infection | Flu Vaccinations, Medicare',        
    'Health Insurance | Uninsured, Child',                       
    'Population | Single-Parent Families',                       
    'Active Transportation | Walking to Work',                   
    'Transportation | Drives Alone to Work',                     
    'Transportation | Public Transportation Use',                
    'Health Insurance | Uninsured, All Ages',                    
    'Deaths | Infant Deaths',                                    
    'Deaths | Maternal Deaths',                                  
    'Births | Preterm Births',                                   
]

# %%
test_df = pvtb_entire[['geo_label_city','date_label','strata_race_label','strata_sex_label']+test_cols]
test_df['city_idx'] = test_df['geo_label_city'].apply(lambda x : city_list.index(x))
test_df['race_idx'] = test_df['strata_race_label'].apply(lambda x : entire_race.index(x))
test_df['sex_idx'] = test_df['strata_sex_label'].apply(lambda x : entire_sex.index(x))
# Out:
# /tmp/ipykernel_206470/1684340861.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['city_idx'] = test_df['geo_label_city'].apply(lambda x : city_list.index(x))
# /tmp/ipykernel_206470/1684340861.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['race_idx'] = test_df['strata_race_label'].apply(lambda x : entire_race.index(x))
# /tmp/ipykernel_206470/1684340861.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['sex_idx'] = test_df['strata_sex_label'].apply(lambda x : entire_sex.index(x))

# %%
dict_df = dict()

input_col = ['city_idx','date_label']+['race_idx','sex_idx']

for col in test_cols:
    temp = test_df[input_col+[col]]
    temp_nonan = temp.dropna()
    dict_df[col] = temp_nonan[input_col], temp_nonan[col]

# %%
dict_train_test = {
    col: train_test_split(*dict_df[col],
                         test_size = 0.2,
                         random_state=801) #check how to using stratify option
    for col in test_cols}

model = KNeighborsRegressor(n_neighbors=7,weights='distance',metric=vec_metric_cy_weighted,algorithm='auto')
dict_knn, dict_pred = dict(), dict()

# %%
dict_train_test = {
    col: train_test_split(*dict_df[col],
                         test_size = 0.2,
                         random_state=801) #check how to using stratify option
    for col in test_cols}

model = KNeighborsRegressor(n_neighbors=5,weights='distance',metric='canberra',algorithm='auto')
dict_knn, dict_pred = dict(), dict()

# %%
dict_train_test = {
    col: train_test_split(*dict_df[col],
                         test_size = 0.2,
                         random_state=801) #check how to using stratify option
    for col in test_cols}

model = KNeighborsRegressor(n_neighbors=5,weights='distance',metric='braycurtis',algorithm='auto')
dict_knn, dict_pred = dict(), dict()

# %%
import copy, time

for col in test_cols[::2]:
    knn_col = copy.deepcopy(model)
    train_X, test_X, train_y, test_y = dict_train_test[col]
    
    start = time.time()
    knn_col.fit(train_X,train_y)
    y_pred = knn_col.predict(test_X)
    end = time.time()
    
    print (col,'/ n : ',len(train_X),f"/, time : {end-start:.5f} (sec)")
    dict_knn[col], dict_pred[col] = knn_col, y_pred
# Out:
# Substance Use | Opioid Overdose Deaths / n :  3851 /, time : 0.01620 (sec)
# Life Expectancy at Birth | Life Expectancy / n :  3993 /, time : 0.01182 (sec)
# Respiratory Infection | Flu Vaccinations, Medicare / n :  1596 /, time : 0.01434 (sec)
# Population | Single-Parent Families / n :  1764 /, time : 0.01134 (sec)
# Transportation | Drives Alone to Work / n :  1764 /, time : 0.00764 (sec)
# Health Insurance | Uninsured, All Ages / n :  1680 /, time : 0.00918 (sec)
# Deaths | Maternal Deaths / n :  800 /, time : 0.00612 (sec)

# %%
from sklearn.metrics import mean_absolute_percentage_error as mape
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import mean_squared_log_error as msle

# %%
dict_score = dict()

for col in test_cols[::2]:
    train_X, test_X, train_y, test_y = dict_train_test[col]
    rmse_model = np.sqrt(mse(dict_pred[col],test_y))
    rmse_base = np.sqrt(mse([train_y.mean()]*len(test_y),test_y))
    msle_model = msle(dict_pred[col],test_y)
    msle_base = msle([train_y.mean()]*len(test_y),test_y)
    mape_model = (mape(dict_pred[col],test_y))
    mape_base = (mape([train_y.mean()]*len(test_y),test_y))
    r2_model = r2_score(test_y,dict_pred[col])
    r2_base = r2_score([train_y.mean()]*len(test_y),dict_pred[col])
    dict_score[col] = {
        'rmse' : [rmse_model, rmse_base],
        'msle' : [msle_model, msle_base],
        'mape' : [mape_model, mape_base],
        'r2_score' : [r2_model,r2_base]
    }
    print('{}\nr2 score : {:.5f}'.format(col,r2_model))
    print('rmse_model : {:.5f} / rmse_base : {:.5f}\t'.format(*dict_score[col]['rmse']),
          'mape_model : {:.5f} / mape_base : {:.5f}\t'.format(*dict_score[col]['mape']),
          'msle_model : {:.5f} / msle_base : {:.5f}'.format(*dict_score[col]['msle']))
    print('-'*150)
# Out:
# Substance Use | Opioid Overdose Deaths
# r2 score : 0.68662
# rmse_model : 15.86517 / rmse_base : 28.40608	 mape_model : 0.34284 / mape_base : 0.83497	 msle_model : 0.21191 / msle_base : 0.97675
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Life Expectancy at Birth | Life Expectancy
# r2 score : 0.78596
# rmse_model : 2.45502 / rmse_base : 5.30834	 mape_model : 0.02484 / mape_base : 0.05405	 msle_model : 0.00102 / msle_base : 0.00468
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Respiratory Infection | Flu Vaccinations, Medicare
# r2 score : 0.75837
# rmse_model : 4.80922 / rmse_base : 9.78970	 mape_model : 0.09436 / mape_base : 0.19567	 msle_model : 0.01438 / msle_base : 0.05867
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Population | Single-Parent Families
# r2 score : 0.72777
# rmse_model : 4.95396 / rmse_base : 9.49745	 mape_model : 0.21073 / mape_base : 0.41890	 msle_model : 0.07111 / msle_base : 0.23740
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Transportation | Drives Alone to Work
# r2 score : 0.74562
# rmse_model : 8.00286 / rmse_base : 15.87002	 mape_model : 0.10238 / mape_base : 0.20938	 msle_model : 0.02841 / msle_base : 0.09783
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Health Insurance | Uninsured, All Ages
# r2 score : 0.58436
# rmse_model : 5.28051 / rmse_base : 8.25498	 mape_model : 0.30089 / mape_base : 0.50314	 msle_model : 0.11561 / msle_base : 0.32508
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Deaths | Maternal Deaths
# r2 score : 0.55997
# rmse_model : 10.05835 / rmse_base : 15.18651	 mape_model : 0.25463 / mape_base : 0.41648	 msle_model : 0.12440 / msle_base : 0.29634
# ------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
# x = data.iloc[n].index, y = data.iloc[n].values

data_plot ={
    col : (dict_train_test[col][3], dict_pred[col])
    for col in test_cols[::2]
}
data_line = {
    col : (dict_train_test[col][3],dict_train_test[col][3])
    for col in test_cols[::2]
}

fig,axes = plt.subplots(3,3,figsize=(12,12))
fig,axes = pair_plot_feat_hue(fig=fig,axes=axes,data=data_line,
#fig,axes = pair_plot_feat_hue(fig=None,axes=None,data=data_line,
                              pair_plot=sns.lineplot,lw=0.5)
#fig.set_size_inches(12,8, forward=True)
#왠지 모르게 저걸 설정하면 망가짐 
fig,axes = pair_plot_feat_hue(fig=fig,axes=axes,data=data_plot,
                              pair_plot=sns.scatterplot,s=5,alpha=0.65)

for n,key in enumerate(data_plot.keys()):
    ax = axes.flatten()[n]
    ax.set_ylabel('')
    ax.set_title(key,fontsize=12)
    ax.set_xlabel('rmse_model : {:.3f} | rmse_base : {:.3f}\nr2 score : {:.3f} {:>35}\n'.format(*dict_score[key]['rmse'],dict_score[key]['r2_score'][0],
        f'n = {len(dict_train_test[key][0])}'), fontsize=10, ha ='left')

for ax in axes.flatten():
    plt.setp(ax.get_yticklabels(),rotation = 0, fontsize = 9)
    plt.setp(ax.get_xticklabels(),ha ='center',rotation = 0, fontsize = 9)
#    print(ax.get_yticklabels())
#    print('-'*30)

#print(axes.flatten()[2].get_yticklabels())

# %%
ax = axes.flatten()[2]
ax.get_yticklabels()
# Out:
# [Text(0, 0.0, '0'),
#  Text(0, 10.0, '10'),
#  Text(0, 20.0, '20'),
#  Text(0, 30.0, '30'),
#  Text(0, 40.0, '40'),
#  Text(0, 50.0, '50')]

# %%
df_score = pd.DataFrame(dict_score[test_cols[0]]).T[[1,0]]
df_score
# Out:
#                   1          0
# rmse      28.406076  18.238338
# mape       0.834974   0.507099
# msle       0.976750   0.310252
# r2_score   0.000000   0.585849

# %%
from itertools import repeat, chain

fig,axes = plt.subplots(len(data_plot),3,figsize=(15,20))
for n, col in enumerate(data_plot.keys()):
    #quo, rem = divmod(n,3)
    ax1, ax2, ax3 = axes[n][0], axes[n][1], axes[n][2]
    test_y, y_pred = data_plot[col]
    train_y = dict_train_test[col][2]
    
    sns.histplot(test_y,label='actual',ax=ax1,alpha=0.5)
    sns.histplot(y_pred,label='knn_pred',ax=ax1,alpha=0.5)
    ax1.legend(fontsize=9)
    
    sns.histplot(test_y-np.mean(train_y),ax=ax2, label = 'baseline',alpha=0.5)
    sns.histplot(test_y-y_pred,ax=ax2, label = 'knn_pred',alpha=0.5)
    ax2.legend(fontsize=9)
    
    df_score = pd.DataFrame(dict_score[col]).T[[1,0]]
    xs = list(chain.from_iterable(repeat(val,2) for val in df_score.index))
    ax3r = ax3.twinx()
    sns.barplot(x=xs[:4],y=list(df_score.values.reshape(-1))[:4],
                hue = ['knn_pred','base']*2,ax=ax3,alpha=0.65,legend=False)
    sns.barplot(x=xs[4:],y=list(df_score.values.reshape(-1))[4:],
                hue = ['knn_pred','base']*2,ax=ax3r,alpha=0.8,legend=False)
    ax3.set_yscale('log')
    ax3r.set_ylim([0.0,1.15])
    ax3r.bar_label(ax3r.containers[0], fontsize=8, fmt='%.4f')
    ax3r.bar_label(ax3r.containers[1], fontsize=8, fmt='%.4f')
    ax3.grid(False)
    ax3r.grid(False)
    ax3r.set_yscale('linear')    
    ax3.bar_label(ax3.containers[0], fontsize=8, fmt='%.4f')
    ax3.bar_label(ax3.containers[1], fontsize=8, fmt='%.4f')
    #ax3.axvline()
    
    ax1.set_title(str_cutter(col,50),fontsize=15,loc='left',ha='left')
    ax2.xaxis.set_label_coords(-0.02, -0.15)
    ax2.set_xlabel('rmse_model : {:.3f} | rmse_base : {:.3f}\nr2 score : {:.3f} {:>48}\n'.format(*dict_score[col]['rmse'],dict_score[col]['r2_score'][0],
        f'n = {len(dict_train_test[col][0])}'), fontsize=10,ha ='left')
    #ax2.xaxis.set_label_position('left')
    ax1.set_xlabel('')
    ax3.set_xlabel('')
    ax1.set_ylabel('count',fontsize =10) 
    ax2.set_ylabel('count',fontsize =10) 
    plt.setp(ax3.get_yticklabels(),rotation = 0, fontsize = 9, color='#333333')
    plt.setp(ax3r.get_yticklabels(),rotation = 0, fontsize = 9)

for ax in axes.flatten():
    plt.setp(ax.get_yticklabels(),rotation = 0, fontsize = 9)
    plt.setp(ax.get_xticklabels(),ha ='center',rotation = 0, fontsize = 9)

# %% [markdown]
# cf. 누락율이 꽤나 높음에도 예상보다 잘 맞춤
# - 단 해당 칼럼들은 race-sex집단에서 stratified 된 집단이 각 도시/연도 별로 최소 하나는 있는 도시/연도가 50% 이상임
# - 위의 비율 기준, 118개 중 상위 30 ~ 44 위의 label들 (100% ~ 53.8%)
# - 45위 부터는 25% 미만으로 떨어짐
#
#     (구체적 내용 : 240619_check_missing_entire.ipynb)
# - 현재 연도를 많이 보지 않으니, 도시 기준으로 분포하는 비율을 봐서, 추가적인 후보를 추릴 수 있을 것 같음

# %%
msno.bar(pvtb_entire[list(data_plot.keys())])
# Out:
# <Axes: >

# %% [markdown]
# ## TODO : refactoring
