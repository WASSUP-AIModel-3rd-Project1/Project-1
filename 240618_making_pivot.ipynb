# %%
import numpy as np 
import pandas as pd 
import matplotlib as mpl
import matplotlib.pyplot as plt 
import missingno as msno
import seaborn as sns 
import os

# %%
import matplotlib_inline.backend_inline

matplotlib_inline.backend_inline.set_matplotlib_formats("png2x")
# 테마 설정: "default", "classic", "dark_background", "fivethirtyeight", "seaborn"
mpl.style.use("fivethirtyeight")
# 이미지가 레이아웃 안으로 들어오도록 함
mpl.rcParams.update({"figure.constrained_layout.use": True})

# %%
import matplotlib.font_manager as fm
font_list = fm.findSystemFonts(fontpaths=None, fontext='ttf')
[fm.FontProperties(fname=font).get_name() for font in font_list if 'D2C' in font]
plt.rc('font', family='D2Coding')
mpl.rcParams['axes.unicode_minus'] = False

# %%
DATASET_DIR = '/home/doeun/code/AI/ESTSOFT2024/workspace/dataset/'
load_dir_name = 'america_big_cities_health_inventory'
file_name = 'BigCitiesHealth.csv'
RSLT_DIR = '/home/doeun/code/AI/ESTSOFT2024/workspace/1.project1_structured/BCHI/processed/'

# %% [markdown]
# ## FUNCTIONS

# %% [markdown]
# - preprocess

# %%
def count_key_opt(data:pd.DataFrame,key,opt):
    rslt = dict()
    labels = data[key].unique()
    form = data[opt].value_counts().sort_values(ascending=False)
    form.iloc[:] = 0

    for feat in labels:
        cond = data[key]==feat
        val = form.copy()
        temp = data.loc[cond,opt].value_counts()
        val.loc[temp.index] = temp
        rslt[feat] = val

    return pd.DataFrame(rslt).T

# %% [markdown]
# - plot

# %%
import re

def choose_split_point(word_len,space,ths):
    # 윗 줄에 space 만큼 공백이 있고, 한 줄의 길이가 ths로 제한 되어있을 때
    # 어떤 지점에서 단어를 끊어줄지 정하기
    # |-------ths-------|
    # |-space-|---------|-space-|------| : word
    #         |-------ths-------|
    print(word_len,space,ths)
    if word_len < ths + space :
        if abs(word_len/2 -ths) <= abs(word_len/2-space) :
            return word_len-ths
        else :
            return word_len - space if word_len < 2 * space else space
    else :
        return ths if word_len - (ths + space) < 0.3 * ths else space

def minimize_seq_idx_np(domain:np.array,func):
    vfunc = np.vectorize(func)
    temp = np.argsort(vfunc(domain))
    return temp[0]

def modify_strlen_ths(last,new,ths=16):
    front = len(last)
    space = ths - (1+front)
    if len(new) < space :
        rslt = [last + ' ' + new]
    else :
        if len(new) < ths:
            rslt = [last, new]
        else:
            cut = choose_split_point(len(new),space-1,ths-1)
            new_h, new_e = new[:cut]+'-', new[cut:]
            if cut < ths-1 :
                rslt = modify_strlen_ths(last+' '+new_h,new_e)
            else :
                rslt = [last] + modify_strlen_ths(new_h,new_e) 
    return rslt

def str_cutter(sentnc, ths = 16):
    words= sentnc.split(' ')
    rslt, pnt = [''], 0
    while pnt < len(words):
        last = '' if len(rslt)==0 else rslt[-1]
        next_ele = modify_strlen_ths(last,words[pnt],ths)
        rslt = rslt[:-1] + next_ele
        pnt += 1
    return '\n'.join(rslt)[1:]
#알고리즘 때문에 맨 앞에 빈칸 하나 들어가게 되는 이슈 있음

print(str_cutter('Racial Segregation Indices | Racial Segregation, White and Hispanic', 13))
# Out:
# Racial
# Segregation
# Indices |
# Racial
# Segregation,
# White and
# Hispanic

# %%
def choose_plot_grid(n:int,r_max=8,c_max=17):
    rs = np.sqrt(n)
    r_min = np.ceil(n/c_max)
    sppt = np.arange(r_min,r_max+1) #need error process
    col_nums = np.ceil(n/sppt)
    res = col_nums * sppt -n
    min_idx = np.where(res==np.min(res))
    #TODO : if len(min_idx) > 1 : minimize abs(sppt-col_nums), col_nums
    return sppt[min_idx[0]], col_nums[min_idx[0]]


def plot_feat_hue(data:pd.DataFrame,hue_label_dict=None):
    num_r, num_c = choose_plot_grid(len(data))
    fig, axes = plt.subplots(num_r,num_c,figsize=(21,17),sharex=True,sharey=True)
    for n,ax in enumerate(axes.flatten()):
        plt.setp(ax.get_xticklabels(),ha = 'left',rotation = 90)
        if n >= len(data) : continue
        sns.barplot(x=data.iloc[n].index, y = data.iloc[n].values,ax =ax)
        feat_name = data.index[n]
        if hue_label_dict: color = 'b' if hue_label_dict[feat_name] else 'k'
        else : color = 'k'
        ax.set_xlabel(str_cutter(feat_name,20),loc='left',fontsize = 8.3,color=color)

    pass

# %%
file_path = os.path.join(DATASET_DIR,load_dir_name,file_name)
df = pd.read_csv(file_path)

df.info()
# Out:
# /tmp/ipykernel_223497/3563803696.py:2: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 189979 entries, 0 to 189978
# Data columns (total 31 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   metric_item_label                189979 non-null  object
#  1   metric_cat_label                 189979 non-null  object
#  2   metric_subcat_label              189979 non-null  object
#  3   metric_item_label_subtitle       189979 non-null  object
#  4   metric_cat_item_yaxis_label      189979 non-null  object
#  5   metric_source_desc_label_fn      189979 non-null  object
#  6   metric_source_desc_label_url_fn  189979 non-null  object
#  7   geo_label_city                   189979 non-null  object
#  8   geo_label_state                  188667 non-null  object
#  9   geo_label_citystate              189979 non-null  object
#  10  geo_fips_code                    188667 non-null  float64
#  11  value                            189979 non-null  float64
#  12  date_label                       189979 non-null  int64
#  13  geo_label_proxy_or_real          189979 non-null  object
#  14  geo_label_proxy_footnote         16804 non-null   object
#  15  geo_fips_desc                    189979 non-null  object
#  16  date_label_proxy_or_real         189979 non-null  object
#  17  date_label_proxy_footnote        54759 non-null   object
#  18  value_ci_flag_yesno              189979 non-null  object
#  19  value_95_ci_low                  118670 non-null  float64
#  20  value_95_ci_high                 118682 non-null  float64
#  21  value_90_ci_low                  0 non-null       float64
#  22  value_90_ci_high                 0 non-null       float64
#  23  geo_strata_region                188667 non-null  object
#  24  geo_strata_poverty               188667 non-null  object
#  25  geo_strata_Population            188666 non-null  object
#  26  geo_strata_PopDensity            188667 non-null  object
#  27  geo_strata_Segregation           188667 non-null  object
#  28  strata_race_label                189979 non-null  object
#  29  strata_sex_label                 189979 non-null  object
#  30  strata_race_sex_label            46662 non-null   object
# dtypes: float64(6), int64(1), object(24)
# memory usage: 44.9+ MB

# %%
df["metric_label"] = df["metric_subcat_label"]+' | '+df["metric_item_label"]

# %%
cond1 = df['strata_race_label'] == 'Asian'

df_racesex=df[['strata_race_label','strata_sex_label','metric_label','geo_label_city','date_label','value']]

df_racesex.loc[cond1,'strata_race_label'] = 'Asian/PI'

cond1 = df['strata_race_label'] == 'American Indian/Alaska Native'
df_racesex.loc[cond1,'strata_race_label'] = 'Natives'

# %%
df_racesex['metric_label'].value_counts()
# Out:
# metric_label
# Deaths | Premature Death                                  6825
# Deaths | Injury Deaths                                    6405
# Deaths | Deaths from All Causes                           6244
# Cancer | All Cancer Deaths                                6233
# Cardiovascular Disease | Cardiovascular Disease Deaths    6195
#                                                           ...
# Housing | Homeless, Total                                  266
# Housing | Vacant Housing and Homelessness                  266
# Housing | Homeless, Children                               256
# Respiratory Infection | COVID-19 Vaccination, Adults        70
# Respiratory Infection | COVID-19 Vaccination, Seniors       70
# Name: count, Length: 118, dtype: int64

# %% [markdown]
# ## Before making pivot table
#
# - agg 전에 race, sex, city, year, label 별로 unique 한지

# %%
df_racesex.columns
# Out:
# Index(['strata_race_label', 'strata_sex_label', 'metric_label',
#        'geo_label_city', 'date_label', 'value'],
#       dtype='object')

# %%
cols = list(df_racesex.columns)[:-1]
check_rslt = df_racesex.duplicated(subset=cols)
print(np.sum(check_rslt),'/',len(check_rslt))
# Out:
# 0 / 189979

# %% [markdown]
# #### cf. 추가 EDA
# ##### race, sex, label, city 기준 하나씩 밖에 없는 데이터

# %%
check_rslt = df_racesex.duplicated(subset=cols[-1])
df_racesex[~check_rslt]
# Out:
#    strata_race_label strata_sex_label                metric_label  \
# 0              Black           Female  Cancer | All Cancer Deaths
# 1           Hispanic             Male  Cancer | All Cancer Deaths
# 2                All           Female  Cancer | All Cancer Deaths
# 3           Hispanic           Female  Cancer | All Cancer Deaths
# 4              Black             Male  Cancer | All Cancer Deaths
# 5              White           Female  Cancer | All Cancer Deaths
# 8              Black           Female  Cancer | All Cancer Deaths
# 9           Hispanic             Both  Cancer | All Cancer Deaths
# 12          Asian/PI             Both  Cancer | All Cancer Deaths
# 16             White           Female  Cancer | All Cancer Deaths
# 18               All             Male  Cancer | All Cancer Deaths
# 30             Black             Male  Cancer | All Cancer Deaths
# 34          Hispanic             Male  Cancer | All Cancer Deaths
#
#    geo_label_city  date_label       value
# 0       Cleveland        2014  209.595434
# 1         Oakland        2016  162.848255
# 2   San Francisco        2021   96.706067
# 3      Long Beach        2018  104.393295
# 4       Cleveland        2013  297.171301
# 5          Dallas        2010  151.115278
# 8     San Antonio        2022  202.205060
# 9        Columbus        2011   91.778076
# 12         Tucson        2015  107.470476
# 16     Long Beach        2019  146.532030
# 18   Indianapolis        2012  270.170824
# 30         Denver        2017  240.195610
# 34         Denver        2020  151.860038

# %% [markdown]
# - label, city, year 기준 하나씩 밖에 없는 데이터

# %%
check_rslt = df_racesex.duplicated(subset=cols[2:])
df_thin_label = df_racesex[~check_rslt]
df_thin_label
# Out:
#        strata_race_label strata_sex_label  \
# 0                  Black           Female
# 1               Hispanic             Male
# 2                    All           Female
# 3               Hispanic           Female
# 4                  Black             Male
# ...                  ...              ...
# 189974               All             Both
# 189975               All             Both
# 189976               All             Both
# 189977               All             Both
# 189978               All             Both
#
#                                              metric_label geo_label_city  \
# 0                              Cancer | All Cancer Deaths      Cleveland
# 1                              Cancer | All Cancer Deaths        Oakland
# 2                              Cancer | All Cancer Deaths  San Francisco
# 3                              Cancer | All Cancer Deaths     Long Beach
# 4                              Cancer | All Cancer Deaths      Cleveland
# ...                                                   ...            ...
# 189974  Racial Segregation Indices | Racial Segregatio...        Chicago
# 189975  Racial Segregation Indices | Racial Segregatio...      Charlotte
# 189976  Racial Segregation Indices | Racial Segregatio...         Boston
# 189977  Racial Segregation Indices | Racial Segregatio...      Baltimore
# 189978  Racial Segregation Indices | Racial Segregatio...         Austin
#
#         date_label       value
# 0             2014  209.595434
# 1             2016  162.848255
# 2             2021   96.706067
# 3             2018  104.393295
# 4             2013  297.171301
# ...            ...         ...
# 189974        2010   60.194312
# 189975        2010   54.301191
# 189976        2010   55.285524
# 189977        2010   50.466207
# 189978        2010   49.973935
#
# [46749 rows x 6 columns]

# %%
cond0 = ~(df_thin_label[cols[0]] == 'All')
cond1 = ~(df_thin_label[cols[1]] == 'Both')

cond_ok = (~cond0) & (~cond1)
print('only for whole race-sex stats : ',len(df_thin_label[cond_ok]),'/',len(df_thin_label))

print("only for a race : ",len(df_thin_label[cond0]),'/',len(df_thin_label))
print("only for a sex : ",len(df_thin_label[cond1]),'/',len(df_thin_label))

cond = cond0 & cond1
print("only for a race-sex : ",len(df_thin_label[cond]),'/',len(df_thin_label))
df_thin_label.loc[cond,cols[2]].value_counts()
# Out:
# only for whole race-sex stats :  31308 / 46749
# only for a race :  13271 / 46749
# only for a sex :  4564 / 46749
# only for a race-sex :  2394 / 46749
# metric_label
# Mental Health | Suicide                          449
# Deaths | Premature Death                         418
# Crime Incidents | Homicides                      318
# Substance Use | Opioid Overdose Deaths           265
# Cancer | All Cancer Deaths                       250
# Deaths | Deaths from All Causes                  211
# Cancer | Colorectal Cancer Deaths                189
# Substance Use | Drug Overdose Deaths             126
# Respiratory Infection | COVID-19 Deaths           45
# Deaths | Motor Vehicle Deaths                     33
# Deaths | Injury Deaths                            27
# Cardiovascular Disease | Heart Disease Deaths     25
# Diabetes and Obesity | Diabetes Deaths            24
# Deaths | Gun Deaths (Firearms)                    14
# Name: count, dtype: int64

# %% [markdown]
# - label, city 별로 하나 밖에 없는 데이터

# %%
check_rslt = df_racesex.duplicated(subset=cols[2:4])
df_thin_label = df_racesex[~check_rslt]
display(df_thin_label)
display(df_thin_label[cols[2]].value_counts())
display(df_thin_label[cols[3]].value_counts())
# Out:
#        strata_race_label strata_sex_label  \
# 0                  Black           Female
# 1               Hispanic             Male
# 2                    All           Female
# 3               Hispanic           Female
# 5                  White           Female
# ...                  ...              ...
# 189542               All             Both
# 189543               All             Both
# 189544               All             Both
# 189545               All             Both
# 189546               All             Both
#
#                                              metric_label geo_label_city  \
# 0                              Cancer | All Cancer Deaths      Cleveland
# 1                              Cancer | All Cancer Deaths        Oakland
# 2                              Cancer | All Cancer Deaths  San Francisco
# 3                              Cancer | All Cancer Deaths     Long Beach
# 5                              Cancer | All Cancer Deaths         Dallas
# ...                                                   ...            ...
# 189542  Racial Segregation Indices | Racial Segregatio...        Chicago
# 189543  Racial Segregation Indices | Racial Segregatio...      Charlotte
# 189544  Racial Segregation Indices | Racial Segregatio...         Boston
# 189545  Racial Segregation Indices | Racial Segregatio...      Baltimore
# 189546  Racial Segregation Indices | Racial Segregatio...         Austin
#
#         date_label       value
# 0             2014  209.595434
# 1             2016  162.848255
# 2             2021   96.706067
# 3             2018  104.393295
# 5             2010  151.115278
# ...            ...         ...
# 189542        2022   58.434179
# 189543        2022   55.088016
# 189544        2022   53.781505
# 189545        2022   46.920883
# 189546        2022   36.170256
#
# [3893 rows x 6 columns]
# metric_label
# Cancer | All Cancer Deaths                     36
# Air Pollution | Poor Air Quality               36
# Transportation | Drives Alone to Work          36
# Active Transportation | Riding Bike to Work    36
# Active Transportation | Walking to Work        36
#                                                ..
# School Violence | Weapons in School            18
# Dietary Quality | Teen Breakfast               18
# Mental Health | Teen Suicidal Ideation         18
# Birth Control | Teen Birth Control             18
# Physical Activity | Teen Physical Education    17
# Name: count, Length: 118, dtype: int64
# geo_label_city
# Philadelphia     118
# San Diego        118
# Baltimore        118
# Chicago          118
# Detroit          118
# Los Angeles      118
# Charlotte        118
# Boston           118
# San Francisco    117
# Washington       117
# New York City    117
# Fort Worth       117
# Oakland          116
# Cleveland        116
# Seattle          116
# Houston          115
# Dallas           115
# Portland         115
# U.S. Total       110
# Las Vegas        105
# Columbus          99
# Indianapolis      99
# Phoenix           99
# Milwaukee         99
# Memphis           99
# Louisville        99
# Minneapolis       99
# Oklahoma City     99
# Denver            98
# San Antonio       98
# San Jose          98
# Austin            98
# Long Beach        98
# El Paso           98
# Tucson            97
# Kansas City       96
# Name: count, dtype: int64

# %%
cond0 = ~(df_thin_label[cols[0]] == 'All')
cond1 = ~(df_thin_label[cols[1]] == 'Both')

cond_ok = (~cond0) & (~cond1)
print('only for whole race-sex stats : ',len(df_thin_label[cond_ok]),'/',len(df_thin_label))

print("only for a race : ",len(df_thin_label[cond0]),'/',len(df_thin_label))
print("only for a sex : ",len(df_thin_label[cond1]),'/',len(df_thin_label))

cond = cond0 & cond1
print("only for a race-sex : ",len(df_thin_label[cond]),'/',len(df_thin_label))
df_thin_label.loc[cond,cols[2]].value_counts()
# Out:
# only for whole race-sex stats :  2540 / 3893
# only for a race :  1196 / 3893
# only for a sex :  365 / 3893
# only for a race-sex :  208 / 3893
# metric_label
# Mental Health | Suicide                    35
# Substance Use | Drug Overdose Deaths       35
# Deaths | Premature Death                   32
# Crime Incidents | Homicides                21
# Cancer | All Cancer Deaths                 20
# Respiratory Infection | COVID-19 Deaths    20
# Deaths | Deaths from All Causes            16
# Substance Use | Opioid Overdose Deaths     15
# Cancer | Colorectal Cancer Deaths          14
# Name: count, dtype: int64

# %%
df_thin_label.loc[cond,cols[3]].value_counts()
# Out:
# geo_label_city
# Philadelphia     8
# Los Angeles      8
# Denver           8
# Dallas           7
# New York City    7
# Phoenix          7
# Austin           7
# Oakland          7
# Boston           7
# Fort Worth       7
# Washington       6
# Milwaukee        6
# Louisville       6
# Houston          6
# Cleveland        6
# San Diego        6
# Las Vegas        6
# Indianapolis     6
# Seattle          6
# San Antonio      6
# Long Beach       6
# Memphis          6
# Tucson           5
# Charlotte        5
# Minneapolis      5
# San Jose         5
# San Francisco    5
# El Paso          5
# Baltimore        5
# Chicago          5
# Detroit          5
# Portland         5
# Kansas City      5
# Columbus         4
# Oklahoma City    4
# Name: count, dtype: int64

# %%
df_thin_label.loc[cond,cols[4]].value_counts()
# Out:
# date_label
# 2013    32
# 2014    26
# 2012    23
# 2017    21
# 2016    20
# 2021    19
# 2020    16
# 2010    13
# 2018    10
# 2022    10
# 2011     7
# 2019     6
# 2015     5
# Name: count, dtype: int64

# %% [markdown]
# - label, year 별로 하나 밖에 없는 데이터

# %%
print(cols[2::2])
check_rslt = df_racesex.duplicated(subset=cols[2::2])
df_thin_label = df_racesex[~check_rslt]
display(df_thin_label)
display(df_thin_label[cols[2]].value_counts())
display(df_thin_label[cols[3]].value_counts())
# Out:
# ['metric_label', 'date_label']
#        strata_race_label strata_sex_label  \
# 0                  Black           Female
# 1               Hispanic             Male
# 2                    All           Female
# 3               Hispanic           Female
# 4                  Black             Male
# ...                  ...              ...
# 189799               All             Both
# 189835               All             Both
# 189871               All             Both
# 189907               All             Both
# 189943               All             Both
#
#                                              metric_label geo_label_city  \
# 0                              Cancer | All Cancer Deaths      Cleveland
# 1                              Cancer | All Cancer Deaths        Oakland
# 2                              Cancer | All Cancer Deaths  San Francisco
# 3                              Cancer | All Cancer Deaths     Long Beach
# 4                              Cancer | All Cancer Deaths      Cleveland
# ...                                                   ...            ...
# 189799  Racial Segregation Indices | Racial Segregatio...     U.S. Total
# 189835  Racial Segregation Indices | Racial Segregatio...     U.S. Total
# 189871  Racial Segregation Indices | Racial Segregatio...     U.S. Total
# 189907  Racial Segregation Indices | Racial Segregatio...     U.S. Total
# 189943  Racial Segregation Indices | Racial Segregatio...     U.S. Total
#
#         date_label       value
# 0             2014  209.595434
# 1             2016  162.848255
# 2             2021   96.706067
# 3             2018  104.393295
# 4             2013  297.171301
# ...            ...         ...
# 189799        2014   50.890911
# 189835        2013   50.890911
# 189871        2012   52.438849
# 189907        2011   52.438849
# 189943        2010   52.438849
#
# [1409 rows x 6 columns]
# metric_label
# Cancer | All Cancer Deaths                               13
# Mental Health | Suicide                                  13
# Air Pollution | Poor Air Quality                         13
# Transportation | Drives Alone to Work                    13
# Active Transportation | Riding Bike to Work              13
#                                                          ..
# Housing | Vacant Housing and Homelessness                 8
# Births | Preterm Births                                   7
# Respiratory Infection | COVID-19 Deaths                   3
# Respiratory Infection | COVID-19 Vaccination, Seniors     2
# Respiratory Infection | COVID-19 Vaccination, Adults      2
# Name: count, Length: 118, dtype: int64
# geo_label_city
# U.S. Total       293
# Milwaukee        130
# Las Vegas        112
# Seattle           98
# Houston           52
# Phoenix           48
# New York City     41
# Long Beach        41
# Dallas            38
# Tucson            35
# Washington        32
# Louisville        31
# Oakland           30
# Chicago           28
# Los Angeles       28
# Boston            26
# Detroit           26
# Baltimore         26
# Philadelphia      25
# San Diego         23
# Indianapolis      21
# Fort Worth        21
# San Francisco     20
# Charlotte         17
# Cleveland         17
# San Jose          17
# Memphis           16
# Columbus          16
# San Antonio       16
# El Paso           14
# Minneapolis       13
# Austin            13
# Denver            13
# Kansas City       13
# Portland          11
# Oklahoma City      8
# Name: count, dtype: int64

# %%
cond0 = ~(df_thin_label[cols[0]] == 'All')
cond1 = ~(df_thin_label[cols[1]] == 'Both')

cond_ok = (~cond0) & (~cond1)
print('only for whole race-sex stats : ',len(df_thin_label[cond_ok]),'/',len(df_thin_label))

print("only for a race : ",len(df_thin_label[cond0]),'/',len(df_thin_label))
print("only for a sex : ",len(df_thin_label[cond1]),'/',len(df_thin_label))

cond = cond0 & cond1
print("only for a race-sex : ",len(df_thin_label[cond]),'/',len(df_thin_label))
df_thin_label.loc[cond,cols[2]].value_counts()
# Out:
# only for whole race-sex stats :  918 / 1409
# only for a race :  425 / 1409
# only for a sex :  138 / 1409
# only for a race-sex :  72 / 1409
# metric_label
# Deaths | Premature Death                   13
# Mental Health | Suicide                    13
# Cancer | All Cancer Deaths                  9
# Deaths | Deaths from All Causes             9
# Crime Incidents | Homicides                 8
# Substance Use | Opioid Overdose Deaths      8
# Cancer | Colorectal Cancer Deaths           5
# Substance Use | Drug Overdose Deaths        5
# Respiratory Infection | COVID-19 Deaths     2
# Name: count, dtype: int64

# %%
df_thin_label.loc[cond,cols[3]].value_counts()
# Out:
# geo_label_city
# Las Vegas        11
# Louisville        5
# Seattle           5
# New York City     4
# Washington        4
# Cleveland         4
# Denver            4
# Detroit           3
# Dallas            3
# Milwaukee         3
# Chicago           2
# Long Beach        2
# San Antonio       2
# San Jose          2
# Austin            2
# Columbus          2
# San Diego         2
# Philadelphia      2
# Tucson            1
# Fort Worth        1
# San Francisco     1
# Indianapolis      1
# Los Angeles       1
# Oklahoma City     1
# Charlotte         1
# Oakland           1
# Minneapolis       1
# Boston            1
# Name: count, dtype: int64

# %%
df_thin_label.loc[cond,cols[4]].value_counts()
# Out:
# date_label
# 2010    7
# 2022    7
# 2020    7
# 2012    7
# 2016    6
# 2013    6
# 2017    6
# 2014    5
# 2018    5
# 2019    5
# 2011    5
# 2021    4
# 2015    2
# Name: count, dtype: int64

# %% [markdown]
# ## Makin pivot tables
#
# 1. only for whole race-sex stats

# %%
cond_total_race = (df_racesex[cols[0]] == 'All')
cond_total_sex = (df_racesex[cols[1]] == 'Both')
cond_total_area = (df_racesex[cols[3]] == 'U.S. Total')

cond_total_racesex = (cond_total_race) & (cond_total_sex)

df_whole_total = df_racesex[cond_total_racesex]
df_city_total = df_racesex[cond_total_racesex & (~cond_total_area)]
df_US_total = df_racesex[cond_total_racesex & (cond_total_area)]

print(len(df_whole_total))
print(len(df_city_total))
print(len(df_US_total))
# Out:
# 46749
# 45437
# 1312

# %%
index_cols = ['geo_label_city','date_label']

pvtb_whole_total = pd.pivot_table(df_whole_total, index = index_cols, columns=['metric_label'],values=['value'])
pvtb_city_total = pd.pivot_table(df_city_total, index = index_cols, columns=['metric_label'],values=['value'])
pvtb_US_total = pd.pivot_table(df_US_total, index = index_cols, columns=['metric_label'],values=['value'])

display(pvtb_whole_total)
display(pvtb_city_total)
display(pvtb_US_total)
# Out:
#                                                                 value  \
# metric_label              Active Transportation | Riding Bike to Work
# geo_label_city date_label
# Austin         2010                                          1.458997
#                2011                                          1.458997
#                2012                                          1.458997
#                2013                                          1.326730
#                2014                                          1.326730
# ...                                                               ...
# Washington     2018                                          3.316120
#                2019                                          3.316120
#                2020                                          3.316120
#                2021                                          3.316120
#                2022                                          3.316120
#
#                                                                    \
# metric_label              Active Transportation | Walking to Work
# geo_label_city date_label
# Austin         2010                                      2.506039
#                2011                                      2.506039
#                2012                                      2.506039
#                2013                                      2.281223
#                2014                                      2.281223
# ...                                                           ...
# Washington     2018                                     10.266102
#                2019                                     10.266102
#                2020                                     10.266102
#                2021                                     10.266102
#                2022                                     10.266102
#
#                                                                  \
# metric_label              Air Pollution | Hazardous Air Quality
# geo_label_city date_label
# Austin         2010                                    2.191781
#                2011                                    3.835616
#                2012                                    2.185792
#                2013                                    1.095890
#                2014                                    0.000000
# ...                                                         ...
# Washington     2018                                    1.643836
#                2019                                    1.369863
#                2020                                    0.273224
#                2021                                    2.191781
#                2022                                    1.877934
#
#                                                             \
# metric_label              Air Pollution | Poor Air Quality
# geo_label_city date_label
# Austin         2010                              25.479452
#                2011                              38.356164
#                2012                              31.967213
#                2013                              31.780822
#                2014                              31.780822
# ...                                                    ...
# Washington     2018                              35.616438
#                2019                              33.698630
#                2020                              14.207650
#                2021                              30.958904
#                2022                              28.169014
#
#                                                               \
# metric_label              Birth Control | Teen Birth Control
# geo_label_city date_label
# Austin         2010                                      NaN
#                2011                                      NaN
#                2012                                      NaN
#                2013                                      NaN
#                2014                                      NaN
# ...                                                      ...
# Washington     2018                                     22.0
#                2019                                     20.8
#                2020                                     20.8
#                2021                                      NaN
#                2022                                      NaN
#
#                                                                            \
# metric_label              Births | Low Birthweight Births | Prenatal Care
# geo_label_city date_label
# Austin         2010                       7.836414              68.065826
#                2011                       7.858909              69.538996
#                2012                       7.893722              72.059393
#                2013                       7.716502              74.345139
#                2014                       7.578234              76.014734
# ...                                            ...                    ...
# Washington     2018                      10.107357              70.844190
#                2019                       9.803055              71.639682
#                2020                       9.671965              72.875092
#                2021                       9.656761              72.056605
#                2022                       9.704213              71.801141
#
#                                                                         \
# metric_label              Births | Preterm Births Births | Teen Births
# geo_label_city date_label
# Austin         2010                           NaN            46.316886
#                2011                           NaN            43.609322
#                2012                           NaN            38.367156
#                2013                           NaN            35.584707
#                2014                           NaN            32.654459
# ...                                           ...                  ...
# Washington     2018                     10.383966            18.438721
#                2019                     10.117118            16.202425
#                2020                     10.112782            14.799331
#                2021                     10.046893            13.606135
#                2022                     10.160876            13.073772
#
#                                                       ...  \
# metric_label              Cancer | All Cancer Deaths  ...
# geo_label_city date_label                             ...
# Austin         2010                       155.012166  ...
#                2011                       153.549681  ...
#                2012                       147.124442  ...
#                2013                       141.815859  ...
#                2014                       136.550686  ...
# ...                                              ...  ...
# Washington     2018                       148.158152  ...
#                2019                       145.163363  ...
#                2020                       143.442017  ...
#                2021                       141.704506  ...
#                2022                       142.690247  ...
#
#                                                          \
# metric_label              Substance Use | Adult Smoking
# geo_label_city date_label
# Austin         2010                                14.1
#                2011                                14.1
#                2012                                14.1
#                2013                                14.1
#                2014                                14.1
# ...                                                 ...
# Washington     2018                                15.6
#                2019                                14.9
#                2020                                13.1
#                2021                                11.9
#                2022                                11.9
#
#                                                                 \
# metric_label              Substance Use | Drug Overdose Deaths
# geo_label_city date_label
# Austin         2010                                  14.814379
#                2011                                  15.118114
#                2012                                  15.692254
#                2013                                  13.729450
#                2014                                  12.717682
# ...                                                        ...
# Washington     2018                                  40.885422
#                2019                                  45.660156
#                2020                                  55.241138
#                2021                                  62.666692
#                2022                                  65.013552
#
#                                                                   \
# metric_label              Substance Use | Opioid Overdose Deaths
# geo_label_city date_label
# Austin         2010                                     5.316296
#                2011                                     5.043283
#                2012                                     4.584205
#                2013                                     3.122614
#                2014                                     4.276205
# ...                                                          ...
# Washington     2018                                    30.473018
#                2019                                    34.179401
#                2020                                    41.551477
#                2021                                    46.707442
#                2022                                    47.962100
#
#                                                         \
# metric_label              Substance Use | Teen Alcohol
# geo_label_city date_label
# Austin         2010                                NaN
#                2011                                NaN
#                2012                                NaN
#                2013                                NaN
#                2014                                NaN
# ...                                                ...
# Washington     2018                               20.5
#                2019                               20.2
#                2020                               20.2
#                2021                                NaN
#                2022                                NaN
#
#                                                           \
# metric_label              Substance Use | Teen Marijuana
# geo_label_city date_label
# Austin         2010                                  NaN
#                2011                                  NaN
#                2012                                  NaN
#                2013                                  NaN
#                2014                                  NaN
# ...                                                  ...
# Washington     2018                                 33.0
#                2019                                 29.2
#                2020                                 29.2
#                2021                                  NaN
#                2022                                  NaN
#
#                                                         \
# metric_label              Substance Use | Teen Smoking
# geo_label_city date_label
# Austin         2010                                NaN
#                2011                                NaN
#                2012                                NaN
#                2013                                NaN
#                2014                                NaN
# ...                                                ...
# Washington     2018                                5.3
#                2019                                5.3
#                2020                                5.3
#                2021                                NaN
#                2022                                NaN
#
#                                                                  \
# metric_label              Transportation | Drives Alone to Work
# geo_label_city date_label
# Austin         2010                                   71.701852
#                2011                                   71.701852
#                2012                                   71.701852
#                2013                                   73.771815
#                2014                                   73.771815
# ...                                                         ...
# Washington     2018                                   29.692477
#                2019                                   29.692477
#                2020                                   29.692477
#                2021                                   29.692477
#                2022                                   29.692477
#
#                                                         \
# metric_label              Transportation | Lack of Car
# geo_label_city date_label
# Austin         2010                           7.104797
#                2011                           7.104797
#                2012                           7.104797
#                2013                           6.314895
#                2014                           6.314895
# ...                                                ...
# Washington     2018                          35.708473
#                2019                          35.708473
#                2020                          35.708473
#                2021                          35.708473
#                2022                          35.708473
#
#                                                                         \
# metric_label              Transportation | Longer Driving Commute Time
# geo_label_city date_label
# Austin         2010                                                NaN
#                2011                                                NaN
#                2012                                                NaN
#                2013                                          31.257569
#                2014                                          31.257569
# ...                                                                ...
# Washington     2018                                          49.469076
#                2019                                          49.469076
#                2020                                          49.469076
#                2021                                          49.469076
#                2022                                          49.469076
#
#
# metric_label              Transportation | Public Transportation Use
# geo_label_city date_label
# Austin         2010                                         4.673879
#                2011                                         4.673879
#                2012                                         4.673879
#                2013                                         3.926705
#                2014                                         3.926705
# ...                                                              ...
# Washington     2018                                        24.668293
#                2019                                        24.668293
#                2020                                        24.668293
#                2021                                        24.668293
#                2022                                        24.668293
#
# [468 rows x 118 columns]
#                                                                 value  \
# metric_label              Active Transportation | Riding Bike to Work
# geo_label_city date_label
# Austin         2010                                          1.458997
#                2011                                          1.458997
#                2012                                          1.458997
#                2013                                          1.326730
#                2014                                          1.326730
# ...                                                               ...
# Washington     2018                                          3.316120
#                2019                                          3.316120
#                2020                                          3.316120
#                2021                                          3.316120
#                2022                                          3.316120
#
#                                                                    \
# metric_label              Active Transportation | Walking to Work
# geo_label_city date_label
# Austin         2010                                      2.506039
#                2011                                      2.506039
#                2012                                      2.506039
#                2013                                      2.281223
#                2014                                      2.281223
# ...                                                           ...
# Washington     2018                                     10.266102
#                2019                                     10.266102
#                2020                                     10.266102
#                2021                                     10.266102
#                2022                                     10.266102
#
#                                                                  \
# metric_label              Air Pollution | Hazardous Air Quality
# geo_label_city date_label
# Austin         2010                                    2.191781
#                2011                                    3.835616
#                2012                                    2.185792
#                2013                                    1.095890
#                2014                                    0.000000
# ...                                                         ...
# Washington     2018                                    1.643836
#                2019                                    1.369863
#                2020                                    0.273224
#                2021                                    2.191781
#                2022                                    1.877934
#
#                                                             \
# metric_label              Air Pollution | Poor Air Quality
# geo_label_city date_label
# Austin         2010                              25.479452
#                2011                              38.356164
#                2012                              31.967213
#                2013                              31.780822
#                2014                              31.780822
# ...                                                    ...
# Washington     2018                              35.616438
#                2019                              33.698630
#                2020                              14.207650
#                2021                              30.958904
#                2022                              28.169014
#
#                                                               \
# metric_label              Birth Control | Teen Birth Control
# geo_label_city date_label
# Austin         2010                                      NaN
#                2011                                      NaN
#                2012                                      NaN
#                2013                                      NaN
#                2014                                      NaN
# ...                                                      ...
# Washington     2018                                     22.0
#                2019                                     20.8
#                2020                                     20.8
#                2021                                      NaN
#                2022                                      NaN
#
#                                                                            \
# metric_label              Births | Low Birthweight Births | Prenatal Care
# geo_label_city date_label
# Austin         2010                       7.836414              68.065826
#                2011                       7.858909              69.538996
#                2012                       7.893722              72.059393
#                2013                       7.716502              74.345139
#                2014                       7.578234              76.014734
# ...                                            ...                    ...
# Washington     2018                      10.107357              70.844190
#                2019                       9.803055              71.639682
#                2020                       9.671965              72.875092
#                2021                       9.656761              72.056605
#                2022                       9.704213              71.801141
#
#                                                                         \
# metric_label              Births | Preterm Births Births | Teen Births
# geo_label_city date_label
# Austin         2010                           NaN            46.316886
#                2011                           NaN            43.609322
#                2012                           NaN            38.367156
#                2013                           NaN            35.584707
#                2014                           NaN            32.654459
# ...                                           ...                  ...
# Washington     2018                     10.383966            18.438721
#                2019                     10.117118            16.202425
#                2020                     10.112782            14.799331
#                2021                     10.046893            13.606135
#                2022                     10.160876            13.073772
#
#                                                       ...  \
# metric_label              Cancer | All Cancer Deaths  ...
# geo_label_city date_label                             ...
# Austin         2010                       155.012166  ...
#                2011                       153.549681  ...
#                2012                       147.124442  ...
#                2013                       141.815859  ...
#                2014                       136.550686  ...
# ...                                              ...  ...
# Washington     2018                       148.158152  ...
#                2019                       145.163363  ...
#                2020                       143.442017  ...
#                2021                       141.704506  ...
#                2022                       142.690247  ...
#
#                                                          \
# metric_label              Substance Use | Adult Smoking
# geo_label_city date_label
# Austin         2010                                14.1
#                2011                                14.1
#                2012                                14.1
#                2013                                14.1
#                2014                                14.1
# ...                                                 ...
# Washington     2018                                15.6
#                2019                                14.9
#                2020                                13.1
#                2021                                11.9
#                2022                                11.9
#
#                                                                 \
# metric_label              Substance Use | Drug Overdose Deaths
# geo_label_city date_label
# Austin         2010                                  14.814379
#                2011                                  15.118114
#                2012                                  15.692254
#                2013                                  13.729450
#                2014                                  12.717682
# ...                                                        ...
# Washington     2018                                  40.885422
#                2019                                  45.660156
#                2020                                  55.241138
#                2021                                  62.666692
#                2022                                  65.013552
#
#                                                                   \
# metric_label              Substance Use | Opioid Overdose Deaths
# geo_label_city date_label
# Austin         2010                                     5.316296
#                2011                                     5.043283
#                2012                                     4.584205
#                2013                                     3.122614
#                2014                                     4.276205
# ...                                                          ...
# Washington     2018                                    30.473018
#                2019                                    34.179401
#                2020                                    41.551477
#                2021                                    46.707442
#                2022                                    47.962100
#
#                                                         \
# metric_label              Substance Use | Teen Alcohol
# geo_label_city date_label
# Austin         2010                                NaN
#                2011                                NaN
#                2012                                NaN
#                2013                                NaN
#                2014                                NaN
# ...                                                ...
# Washington     2018                               20.5
#                2019                               20.2
#                2020                               20.2
#                2021                                NaN
#                2022                                NaN
#
#                                                           \
# metric_label              Substance Use | Teen Marijuana
# geo_label_city date_label
# Austin         2010                                  NaN
#                2011                                  NaN
#                2012                                  NaN
#                2013                                  NaN
#                2014                                  NaN
# ...                                                  ...
# Washington     2018                                 33.0
#                2019                                 29.2
#                2020                                 29.2
#                2021                                  NaN
#                2022                                  NaN
#
#                                                         \
# metric_label              Substance Use | Teen Smoking
# geo_label_city date_label
# Austin         2010                                NaN
#                2011                                NaN
#                2012                                NaN
#                2013                                NaN
#                2014                                NaN
# ...                                                ...
# Washington     2018                                5.3
#                2019                                5.3
#                2020                                5.3
#                2021                                NaN
#                2022                                NaN
#
#                                                                  \
# metric_label              Transportation | Drives Alone to Work
# geo_label_city date_label
# Austin         2010                                   71.701852
#                2011                                   71.701852
#                2012                                   71.701852
#                2013                                   73.771815
#                2014                                   73.771815
# ...                                                         ...
# Washington     2018                                   29.692477
#                2019                                   29.692477
#                2020                                   29.692477
#                2021                                   29.692477
#                2022                                   29.692477
#
#                                                         \
# metric_label              Transportation | Lack of Car
# geo_label_city date_label
# Austin         2010                           7.104797
#                2011                           7.104797
#                2012                           7.104797
#                2013                           6.314895
#                2014                           6.314895
# ...                                                ...
# Washington     2018                          35.708473
#                2019                          35.708473
#                2020                          35.708473
#                2021                          35.708473
#                2022                          35.708473
#
#                                                                         \
# metric_label              Transportation | Longer Driving Commute Time
# geo_label_city date_label
# Austin         2010                                                NaN
#                2011                                                NaN
#                2012                                                NaN
#                2013                                          31.257569
#                2014                                          31.257569
# ...                                                                ...
# Washington     2018                                          49.469076
#                2019                                          49.469076
#                2020                                          49.469076
#                2021                                          49.469076
#                2022                                          49.469076
#
#
# metric_label              Transportation | Public Transportation Use
# geo_label_city date_label
# Austin         2010                                         4.673879
#                2011                                         4.673879
#                2012                                         4.673879
#                2013                                         3.926705
#                2014                                         3.926705
# ...                                                              ...
# Washington     2018                                        24.668293
#                2019                                        24.668293
#                2020                                        24.668293
#                2021                                        24.668293
#                2022                                        24.668293
#
# [455 rows x 118 columns]
#                                                                 value  \
# metric_label              Active Transportation | Riding Bike to Work
# geo_label_city date_label
# U.S. Total     2010                                          0.548428
#                2011                                          0.548428
#                2012                                          0.548428
#                2013                                          0.587269
#                2014                                          0.587269
#                2015                                          0.587269
#                2016                                          0.587269
#                2017                                          0.587269
#                2018                                          0.460903
#                2019                                          0.460903
#                2020                                          0.460903
#                2021                                          0.460903
#                2022                                          0.460903
#
#                                                                    \
# metric_label              Active Transportation | Walking to Work
# geo_label_city date_label
# U.S. Total     2010                                      2.667280
#                2011                                      2.667280
#                2012                                      2.667280
#                2013                                      2.728075
#                2014                                      2.728075
#                2015                                      2.728075
#                2016                                      2.728075
#                2017                                      2.728075
#                2018                                      2.429932
#                2019                                      2.429932
#                2020                                      2.429932
#                2021                                      2.429932
#                2022                                      2.429932
#
#                                                                  \
# metric_label              Air Pollution | Hazardous Air Quality
# geo_label_city date_label
# U.S. Total     2010                                    5.068512
#                2011                                    6.144475
#                2012                                    6.975557
#                2013                                    3.445394
#                2014                                    3.219178
#                2015                                    3.630477
#                2016                                    2.998975
#                2017                                    3.528589
#                2018                                    4.130990
#                2019                                    2.171535
#                2020                                    4.562917
#                2021                                    4.465866
#                2022                                    2.966538
#
#                                                             \
# metric_label              Air Pollution | Poor Air Quality
# geo_label_city date_label
# U.S. Total     2010                              46.954181
#                2011                              52.178816
#                2012                              48.861564
#                2013                              45.263482
#                2014                              42.842466
#                2015                              41.553455
#                2016                              36.583452
#                2017                              38.548489
#                2018                              39.393064
#                2019                              37.197102
#                2020                              34.935977
#                2021                              39.166585
#                2022                              35.933943
#
#                                                               \
# metric_label              Birth Control | Teen Birth Control
# geo_label_city date_label
# U.S. Total     2010                                     12.9
#                2011                                     12.9
#                2012                                     12.9
#                2013                                     13.7
#                2014                                     13.7
#                2015                                     13.8
#                2016                                     13.8
#                2017                                     13.8
#                2018                                     13.8
#                2019                                     11.9
#                2020                                     11.9
#                2021                                      NaN
#                2022                                      NaN
#
#                                                                            \
# metric_label              Births | Low Birthweight Births | Prenatal Care
# geo_label_city date_label
# U.S. Total     2010                       8.880309              64.604016
#                2011                       8.840747              66.209399
#                2012                       8.777975              68.999378
#                2013                       8.759168              70.994663
#                2014                       8.786281              72.678508
#                2015                       8.848829              74.480699
#                2016                       8.965850              72.472540
#                2017                       9.015067              73.281689
#                2018                       9.054676              73.947733
#                2019                       9.039690              74.420804
#                2020                       8.200000              74.420804
#                2021                       8.200000              77.700000
#                2022                       8.200000              77.700000
#
#                                                                         \
# metric_label              Births | Preterm Births Births | Teen Births
# geo_label_city date_label
# U.S. Total     2010                           NaN                 26.5
#                2011                           NaN                 26.5
#                2012                           NaN                 26.5
#                2013                           NaN                 26.5
#                2014                           NaN                 24.2
#                2015                           NaN                 22.3
#                2016                           9.8                 20.3
#                2017                           9.9                 18.8
#                2018                          10.0                 17.4
#                2019                          10.2                 16.7
#                2020                          10.1                 15.4
#                2021                          10.5                 13.9
#                2022                          10.5                 13.9
#
#                                                       ...  \
# metric_label              Cancer | All Cancer Deaths  ...
# geo_label_city date_label                             ...
# U.S. Total     2010                            172.8  ...
#                2011                            169.0  ...
#                2012                            166.5  ...
#                2013                            163.2  ...
#                2014                            161.2  ...
#                2015                            158.5  ...
#                2016                            155.8  ...
#                2017                            152.5  ...
#                2018                            149.1  ...
#                2019                            146.2  ...
#                2020                            146.2  ...
#                2021                            146.6  ...
#                2022                            146.6  ...
#
#                                                          \
# metric_label              Substance Use | Adult Smoking
# geo_label_city date_label
# U.S. Total     2010                                18.1
#                2011                                18.1
#                2012                                18.1
#                2013                                18.1
#                2014                                18.1
#                2015                                17.5
#                2016                                17.0
#                2017                                17.1
#                2018                                16.1
#                2019                                16.0
#                2020                                15.5
#                2021                                14.4
#                2022                                14.4
#
#                                                                 \
# metric_label              Substance Use | Drug Overdose Deaths
# geo_label_city date_label
# U.S. Total     2010                                       12.3
#                2011                                       12.3
#                2012                                       13.2
#                2013                                       13.1
#                2014                                       13.8
#                2015                                       14.7
#                2016                                       16.3
#                2017                                       19.8
#                2018                                       21.7
#                2019                                       20.7
#                2020                                       21.6
#                2021                                       28.3
#                2022                                       32.4
#
#                                                                   \
# metric_label              Substance Use | Opioid Overdose Deaths
# geo_label_city date_label
# U.S. Total     2010                                          6.8
#                2011                                          7.3
#                2012                                          7.4
#                2013                                          7.9
#                2014                                          9.0
#                2015                                         10.4
#                2016                                         13.3
#                2017                                         14.9
#                2018                                         14.6
#                2019                                         15.5
#                2020                                         15.5
#                2021                                         21.4
#                2022                                         24.7
#
#                                                         \
# metric_label              Substance Use | Teen Alcohol
# geo_label_city date_label
# U.S. Total     2010                               38.7
#                2011                               38.7
#                2012                               38.7
#                2013                               34.9
#                2014                               34.9
#                2015                               32.8
#                2016                               32.8
#                2017                               29.8
#                2018                               29.8
#                2019                               29.2
#                2020                               29.2
#                2021                                NaN
#                2022                                NaN
#
#                                                           \
# metric_label              Substance Use | Teen Marijuana
# geo_label_city date_label
# U.S. Total     2010                                 23.1
#                2011                                 23.1
#                2012                                 23.1
#                2013                                 23.4
#                2014                                 23.4
#                2015                                 21.7
#                2016                                 21.7
#                2017                                 19.8
#                2018                                 19.8
#                2019                                 21.7
#                2020                                 21.7
#                2021                                  NaN
#                2022                                  NaN
#
#                                                         \
# metric_label              Substance Use | Teen Smoking
# geo_label_city date_label
# U.S. Total     2010                               18.1
#                2011                               18.1
#                2012                               18.1
#                2013                               15.7
#                2014                               15.7
#                2015                               10.8
#                2016                               10.8
#                2017                                8.8
#                2018                                8.8
#                2019                                6.0
#                2020                                6.0
#                2021                                NaN
#                2022                                NaN
#
#                                                                  \
# metric_label              Transportation | Drives Alone to Work
# geo_label_city date_label
# U.S. Total     2010                                   76.330842
#                2011                                   76.330842
#                2012                                   76.330842
#                2013                                   76.442231
#                2014                                   76.442231
#                2015                                   76.442231
#                2016                                   76.442231
#                2017                                   76.442231
#                2018                                   71.673328
#                2019                                   71.673328
#                2020                                   71.673328
#                2021                                   71.673328
#                2022                                   71.673328
#
#                                                         \
# metric_label              Transportation | Lack of Car
# geo_label_city date_label
# U.S. Total     2010                           8.608855
#                2011                           8.608855
#                2012                           8.608855
#                2013                           8.809877
#                2014                           8.809877
#                2015                           8.809877
#                2016                           8.809877
#                2017                           8.809877
#                2018                           8.330821
#                2019                           8.330821
#                2020                           8.330821
#                2021                           8.330821
#                2022                           8.330821
#
#                                                                         \
# metric_label              Transportation | Longer Driving Commute Time
# geo_label_city date_label
# U.S. Total     2010                                                NaN
#                2011                                                NaN
#                2012                                                NaN
#                2013                                          35.285365
#                2014                                          35.285365
#                2015                                          35.285365
#                2016                                          35.285365
#                2017                                          35.285365
#                2018                                          36.492221
#                2019                                          36.492221
#                2020                                          36.492221
#                2021                                          36.492221
#                2022                                          36.492221
#
#
# metric_label              Transportation | Public Transportation Use
# geo_label_city date_label
# U.S. Total     2010                                         5.002862
#                2011                                         5.002862
#                2012                                         5.002862
#                2013                                         5.125515
#                2014                                         5.125515
#                2015                                         5.125515
#                2016                                         5.125515
#                2017                                         5.125515
#                2018                                         3.794247
#                2019                                         3.794247
#                2020                                         3.794247
#                2021                                         3.794247
#                2022                                         3.794247
#
# [13 rows x 110 columns]

# %%
file_names=[
    'pvtb_whole_total_ver0.csv',
    'pvtb_city_total_ver0.csv',
    'pvtb_US_total_ver0.csv'
]

pvtb_dir = 'pvtb'

save_path=[
    os.path.join(RSLT_DIR,pvtb_dir,name)
    for name in file_names
]

pvtb_whole_total.to_csv(save_path[0],index=True)
pvtb_city_total.to_csv(save_path[1],index=True)
pvtb_US_total.to_csv(save_path[2],index=True)

# %% [markdown]
# 2. for an entire data

# %%
cond_total_area = (df_racesex[cols[3]] == 'U.S. Total')

df_whole_entire = df_racesex
df_city_entire = df_racesex[~cond_total_area]
df_US_entire = df_racesex[cond_total_area]

print(len(df_whole_entire))
print(len(df_city_entire))
print(len(df_US_entire))
# Out:
# 189979
# 188667
# 1312

# %%
index_cols = ['geo_label_city','date_label','strata_race_label','strata_sex_label']

pvtb_whole_entire = pd.pivot_table(df_whole_entire, index = index_cols, columns=['metric_label'],values=['value'])
pvtb_city_entire = pd.pivot_table(df_city_entire, index = index_cols, columns=['metric_label'],values=['value'])
pvtb_US_entire = pd.pivot_table(df_US_entire, index = index_cols, columns=['metric_label'],values=['value'])

display(pvtb_whole_entire)
display(pvtb_city_entire)
display(pvtb_US_entire)
# Out:
#                                                                                                    value  \
# metric_label                                                 Active Transportation | Riding Bike to Work
# geo_label_city date_label strata_race_label strata_sex_label
# Austin         2010       All               Both                                                1.458997
#                                             Female                                                   NaN
#                                             Male                                                     NaN
#                           Asian/PI          Both                                                     NaN
#                                             Female                                                   NaN
# ...                                                                                                  ...
# Washington     2022       Hispanic          Male                                                     NaN
#                           Natives           Both                                                     NaN
#                           White             Both                                                     NaN
#                                             Female                                                   NaN
#                                             Male                                                     NaN
#
#                                                                                                       \
# metric_label                                                 Active Transportation | Walking to Work
# geo_label_city date_label strata_race_label strata_sex_label
# Austin         2010       All               Both                                            2.506039
#                                             Female                                               NaN
#                                             Male                                                 NaN
#                           Asian/PI          Both                                                 NaN
#                                             Female                                               NaN
# ...                                                                                              ...
# Washington     2022       Hispanic          Male                                                 NaN
#                           Natives           Both                                            8.766234
#                           White             Both                                           14.201808
#                                             Female                                               NaN
#                                             Male                                                 NaN
#
#                                                                                                     \
# metric_label                                                 Air Pollution | Hazardous Air Quality
# geo_label_city date_label strata_race_label strata_sex_label
# Austin         2010       All               Both                                          2.191781
#                                             Female                                             NaN
#                                             Male                                               NaN
#                           Asian/PI          Both                                               NaN
#                                             Female                                             NaN
# ...                                                                                            ...
# Washington     2022       Hispanic          Male                                               NaN
#                           Natives           Both                                               NaN
#                           White             Both                                               NaN
#                                             Female                                             NaN
#                                             Male                                               NaN
#
#                                                                                                \
# metric_label                                                 Air Pollution | Poor Air Quality
# geo_label_city date_label strata_race_label strata_sex_label
# Austin         2010       All               Both                                    25.479452
#                                             Female                                        NaN
#                                             Male                                          NaN
#                           Asian/PI          Both                                          NaN
#                                             Female                                        NaN
# ...                                                                                       ...
# Washington     2022       Hispanic          Male                                          NaN
#                           Natives           Both                                          NaN
#                           White             Both                                          NaN
#                                             Female                                        NaN
#                                             Male                                          NaN
#
#                                                                                                  \
# metric_label                                                 Birth Control | Teen Birth Control
# geo_label_city date_label strata_race_label strata_sex_label
# Austin         2010       All               Both                                            NaN
#                                             Female                                          NaN
#                                             Male                                            NaN
#                           Asian/PI          Both                                            NaN
#                                             Female                                          NaN
# ...                                                                                         ...
# Washington     2022       Hispanic          Male                                            NaN
#                           Natives           Both                                            NaN
#                           White             Both                                            NaN
#                                             Female                                          NaN
#                                             Male                                            NaN
#
#                                                                                        \
# metric_label                                                 Births | Low Birthweight
# geo_label_city date_label strata_race_label strata_sex_label
# Austin         2010       All               Both                             7.836414
#                                             Female                                NaN
#                                             Male                                  NaN
#                           Asian/PI          Both                             8.785406
#                                             Female                                NaN
# ...                                                                               ...
# Washington     2022       Hispanic          Male                                  NaN
#                           Natives           Both                                  NaN
#                           White             Both                             5.574537
#                                             Female                                NaN
#                                             Male                                  NaN
#
#                                                                                      \
# metric_label                                                 Births | Prenatal Care
# geo_label_city date_label strata_race_label strata_sex_label
# Austin         2010       All               Both                          68.065826
#                                             Female                              NaN
#                                             Male                                NaN
#                           Asian/PI          Both                          82.261962
#                                             Female                              NaN
# ...                                                                             ...
# Washington     2022       Hispanic          Male                                NaN
#                           Natives           Both                                NaN
#                           White             Both                          84.861290
#                                             Female                              NaN
#                                             Male                                NaN
#
#                                                                                       \
# metric_label                                                 Births | Preterm Births
# geo_label_city date_label strata_race_label strata_sex_label
# Austin         2010       All               Both                                 NaN
#                                             Female                               NaN
#                                             Male                                 NaN
#                           Asian/PI          Both                                 NaN
#                                             Female                               NaN
# ...                                                                              ...
# Washington     2022       Hispanic          Male                                 NaN
#                           Natives           Both                                 NaN
#                           White             Both                            6.550297
#                                             Female                               NaN
#                                             Male                                 NaN
#
#                                                                                    \
# metric_label                                                 Births | Teen Births
# geo_label_city date_label strata_race_label strata_sex_label
# Austin         2010       All               Both                        46.316886
#                                             Female                            NaN
#                                             Male                              NaN
#                           Asian/PI          Both                         5.460005
#                                             Female                            NaN
# ...                                                                           ...
# Washington     2022       Hispanic          Male                              NaN
#                           Natives           Both                              NaN
#                           White             Both                         0.943990
#                                             Female                            NaN
#                                             Male                              NaN
#
#                                                                                          \
# metric_label                                                 Cancer | All Cancer Deaths
# geo_label_city date_label strata_race_label strata_sex_label
# Austin         2010       All               Both                             155.012166
#                                             Female                           133.000095
#                                             Male                             189.760269
#                           Asian/PI          Both                             110.214905
#                                             Female                            79.076751
# ...                                                                                 ...
# Washington     2022       Hispanic          Male                             106.913662
#                           Natives           Both                                    NaN
#                           White             Both                              91.848866
#                                             Female                                  NaN
#                                             Male                                    NaN
#
#                                                               ...  \
# metric_label                                                  ...
# geo_label_city date_label strata_race_label strata_sex_label  ...
# Austin         2010       All               Both              ...
#                                             Female            ...
#                                             Male              ...
#                           Asian/PI          Both              ...
#                                             Female            ...
# ...                                                           ...
# Washington     2022       Hispanic          Male              ...
#                           Natives           Both              ...
#                           White             Both              ...
#                                             Female            ...
#                                             Male              ...
#
#                                                                                             \
# metric_label                                                 Substance Use | Adult Smoking
# geo_label_city date_label strata_race_label strata_sex_label
# Austin         2010       All               Both                                      14.1
#                                             Female                                     NaN
#                                             Male                                       NaN
#                           Asian/PI          Both                                       NaN
#                                             Female                                     NaN
# ...                                                                                    ...
# Washington     2022       Hispanic          Male                                       NaN
#                           Natives           Both                                       NaN
#                           White             Both                                       NaN
#                                             Female                                     NaN
#                                             Male                                       NaN
#
#                                                                                                    \
# metric_label                                                 Substance Use | Drug Overdose Deaths
# geo_label_city date_label strata_race_label strata_sex_label
# Austin         2010       All               Both                                        14.814379
#                                             Female                                      12.110401
#                                             Male                                        17.451652
#                           Asian/PI          Both                                              NaN
#                                             Female                                            NaN
# ...                                                                                           ...
# Washington     2022       Hispanic          Male                                        25.584642
#                           Natives           Both                                              NaN
#                           White             Both                                        13.498547
#                                             Female                                       6.485127
#                                             Male                                        20.246498
#
#                                                                                                      \
# metric_label                                                 Substance Use | Opioid Overdose Deaths
# geo_label_city date_label strata_race_label strata_sex_label
# Austin         2010       All               Both                                           5.316296
#                                             Female                                         4.224056
#                                             Male                                           6.417004
#                           Asian/PI          Both                                                NaN
#                                             Female                                              NaN
# ...                                                                                             ...
# Washington     2022       Hispanic          Male                                          21.067009
#                           Natives           Both                                                NaN
#                           White             Both                                           8.887272
#                                             Female                                              NaN
#                                             Male                                          14.137920
#
#                                                                                            \
# metric_label                                                 Substance Use | Teen Alcohol
# geo_label_city date_label strata_race_label strata_sex_label
# Austin         2010       All               Both                                      NaN
#                                             Female                                    NaN
#                                             Male                                      NaN
#                           Asian/PI          Both                                      NaN
#                                             Female                                    NaN
# ...                                                                                   ...
# Washington     2022       Hispanic          Male                                      NaN
#                           Natives           Both                                      NaN
#                           White             Both                                      NaN
#                                             Female                                    NaN
#                                             Male                                      NaN
#
#                                                                                              \
# metric_label                                                 Substance Use | Teen Marijuana
# geo_label_city date_label strata_race_label strata_sex_label
# Austin         2010       All               Both                                        NaN
#                                             Female                                      NaN
#                                             Male                                        NaN
#                           Asian/PI          Both                                        NaN
#                                             Female                                      NaN
# ...                                                                                     ...
# Washington     2022       Hispanic          Male                                        NaN
#                           Natives           Both                                        NaN
#                           White             Both                                        NaN
#                                             Female                                      NaN
#                                             Male                                        NaN
#
#                                                                                            \
# metric_label                                                 Substance Use | Teen Smoking
# geo_label_city date_label strata_race_label strata_sex_label
# Austin         2010       All               Both                                      NaN
#                                             Female                                    NaN
#                                             Male                                      NaN
#                           Asian/PI          Both                                      NaN
#                                             Female                                    NaN
# ...                                                                                   ...
# Washington     2022       Hispanic          Male                                      NaN
#                           Natives           Both                                      NaN
#                           White             Both                                      NaN
#                                             Female                                    NaN
#                                             Male                                      NaN
#
#                                                                                                     \
# metric_label                                                 Transportation | Drives Alone to Work
# geo_label_city date_label strata_race_label strata_sex_label
# Austin         2010       All               Both                                         71.701852
#                                             Female                                             NaN
#                                             Male                                               NaN
#                           Asian/PI          Both                                               NaN
#                                             Female                                             NaN
# ...                                                                                            ...
# Washington     2022       Hispanic          Male                                               NaN
#                           Natives           Both                                         19.237013
#                           White             Both                                         24.173919
#                                             Female                                             NaN
#                                             Male                                               NaN
#
#                                                                                            \
# metric_label                                                 Transportation | Lack of Car
# geo_label_city date_label strata_race_label strata_sex_label
# Austin         2010       All               Both                                 7.104797
#                                             Female                                    NaN
#                                             Male                                      NaN
#                           Asian/PI          Both                                      NaN
#                                             Female                                    NaN
# ...                                                                                   ...
# Washington     2022       Hispanic          Male                                      NaN
#                           Natives           Both                                      NaN
#                           White             Both                                      NaN
#                                             Female                                    NaN
#                                             Male                                      NaN
#
#                                                                                                            \
# metric_label                                                 Transportation | Longer Driving Commute Time
# geo_label_city date_label strata_race_label strata_sex_label
# Austin         2010       All               Both                                                      NaN
#                                             Female                                                    NaN
#                                             Male                                                      NaN
#                           Asian/PI          Both                                                      NaN
#                                             Female                                                    NaN
# ...                                                                                                   ...
# Washington     2022       Hispanic          Male                                                      NaN
#                           Natives           Both                                                      NaN
#                           White             Both                                                      NaN
#                                             Female                                                    NaN
#                                             Male                                                      NaN
#
#
# metric_label                                                 Transportation | Public Transportation Use
# geo_label_city date_label strata_race_label strata_sex_label
# Austin         2010       All               Both                                               4.673879
#                                             Female                                                  NaN
#                                             Male                                                    NaN
#                           Asian/PI          Both                                                    NaN
#                                             Female                                                  NaN
# ...                                                                                                 ...
# Washington     2022       Hispanic          Male                                                    NaN
#                           Natives           Both                                              38.879870
#                           White             Both                                              21.684225
#                                             Female                                                  NaN
#                                             Male                                                    NaN
#
# [7293 rows x 118 columns]
#                                                                                                    value  \
# metric_label                                                 Active Transportation | Riding Bike to Work
# geo_label_city date_label strata_race_label strata_sex_label
# Austin         2010       All               Both                                                1.458997
#                                             Female                                                   NaN
#                                             Male                                                     NaN
#                           Asian/PI          Both                                                     NaN
#                                             Female                                                   NaN
# ...                                                                                                  ...
# Washington     2022       Hispanic          Male                                                     NaN
#                           Natives           Both                                                     NaN
#                           White             Both                                                     NaN
#                                             Female                                                   NaN
#                                             Male                                                     NaN
#
#                                                                                                       \
# metric_label                                                 Active Transportation | Walking to Work
# geo_label_city date_label strata_race_label strata_sex_label
# Austin         2010       All               Both                                            2.506039
#                                             Female                                               NaN
#                                             Male                                                 NaN
#                           Asian/PI          Both                                                 NaN
#                                             Female                                               NaN
# ...                                                                                              ...
# Washington     2022       Hispanic          Male                                                 NaN
#                           Natives           Both                                            8.766234
#                           White             Both                                           14.201808
#                                             Female                                               NaN
#                                             Male                                                 NaN
#
#                                                                                                     \
# metric_label                                                 Air Pollution | Hazardous Air Quality
# geo_label_city date_label strata_race_label strata_sex_label
# Austin         2010       All               Both                                          2.191781
#                                             Female                                             NaN
#                                             Male                                               NaN
#                           Asian/PI          Both                                               NaN
#                                             Female                                             NaN
# ...                                                                                            ...
# Washington     2022       Hispanic          Male                                               NaN
#                           Natives           Both                                               NaN
#                           White             Both                                               NaN
#                                             Female                                             NaN
#                                             Male                                               NaN
#
#                                                                                                \
# metric_label                                                 Air Pollution | Poor Air Quality
# geo_label_city date_label strata_race_label strata_sex_label
# Austin         2010       All               Both                                    25.479452
#                                             Female                                        NaN
#                                             Male                                          NaN
#                           Asian/PI          Both                                          NaN
#                                             Female                                        NaN
# ...                                                                                       ...
# Washington     2022       Hispanic          Male                                          NaN
#                           Natives           Both                                          NaN
#                           White             Both                                          NaN
#                                             Female                                        NaN
#                                             Male                                          NaN
#
#                                                                                                  \
# metric_label                                                 Birth Control | Teen Birth Control
# geo_label_city date_label strata_race_label strata_sex_label
# Austin         2010       All               Both                                            NaN
#                                             Female                                          NaN
#                                             Male                                            NaN
#                           Asian/PI          Both                                            NaN
#                                             Female                                          NaN
# ...                                                                                         ...
# Washington     2022       Hispanic          Male                                            NaN
#                           Natives           Both                                            NaN
#                           White             Both                                            NaN
#                                             Female                                          NaN
#                                             Male                                            NaN
#
#                                                                                        \
# metric_label                                                 Births | Low Birthweight
# geo_label_city date_label strata_race_label strata_sex_label
# Austin         2010       All               Both                             7.836414
#                                             Female                                NaN
#                                             Male                                  NaN
#                           Asian/PI          Both                             8.785406
#                                             Female                                NaN
# ...                                                                               ...
# Washington     2022       Hispanic          Male                                  NaN
#                           Natives           Both                                  NaN
#                           White             Both                             5.574537
#                                             Female                                NaN
#                                             Male                                  NaN
#
#                                                                                      \
# metric_label                                                 Births | Prenatal Care
# geo_label_city date_label strata_race_label strata_sex_label
# Austin         2010       All               Both                          68.065826
#                                             Female                              NaN
#                                             Male                                NaN
#                           Asian/PI          Both                          82.261962
#                                             Female                              NaN
# ...                                                                             ...
# Washington     2022       Hispanic          Male                                NaN
#                           Natives           Both                                NaN
#                           White             Both                          84.861290
#                                             Female                              NaN
#                                             Male                                NaN
#
#                                                                                       \
# metric_label                                                 Births | Preterm Births
# geo_label_city date_label strata_race_label strata_sex_label
# Austin         2010       All               Both                                 NaN
#                                             Female                               NaN
#                                             Male                                 NaN
#                           Asian/PI          Both                                 NaN
#                                             Female                               NaN
# ...                                                                              ...
# Washington     2022       Hispanic          Male                                 NaN
#                           Natives           Both                                 NaN
#                           White             Both                            6.550297
#                                             Female                               NaN
#                                             Male                                 NaN
#
#                                                                                    \
# metric_label                                                 Births | Teen Births
# geo_label_city date_label strata_race_label strata_sex_label
# Austin         2010       All               Both                        46.316886
#                                             Female                            NaN
#                                             Male                              NaN
#                           Asian/PI          Both                         5.460005
#                                             Female                            NaN
# ...                                                                           ...
# Washington     2022       Hispanic          Male                              NaN
#                           Natives           Both                              NaN
#                           White             Both                         0.943990
#                                             Female                            NaN
#                                             Male                              NaN
#
#                                                                                          \
# metric_label                                                 Cancer | All Cancer Deaths
# geo_label_city date_label strata_race_label strata_sex_label
# Austin         2010       All               Both                             155.012166
#                                             Female                           133.000095
#                                             Male                             189.760269
#                           Asian/PI          Both                             110.214905
#                                             Female                            79.076751
# ...                                                                                 ...
# Washington     2022       Hispanic          Male                             106.913662
#                           Natives           Both                                    NaN
#                           White             Both                              91.848866
#                                             Female                                  NaN
#                                             Male                                    NaN
#
#                                                               ...  \
# metric_label                                                  ...
# geo_label_city date_label strata_race_label strata_sex_label  ...
# Austin         2010       All               Both              ...
#                                             Female            ...
#                                             Male              ...
#                           Asian/PI          Both              ...
#                                             Female            ...
# ...                                                           ...
# Washington     2022       Hispanic          Male              ...
#                           Natives           Both              ...
#                           White             Both              ...
#                                             Female            ...
#                                             Male              ...
#
#                                                                                             \
# metric_label                                                 Substance Use | Adult Smoking
# geo_label_city date_label strata_race_label strata_sex_label
# Austin         2010       All               Both                                      14.1
#                                             Female                                     NaN
#                                             Male                                       NaN
#                           Asian/PI          Both                                       NaN
#                                             Female                                     NaN
# ...                                                                                    ...
# Washington     2022       Hispanic          Male                                       NaN
#                           Natives           Both                                       NaN
#                           White             Both                                       NaN
#                                             Female                                     NaN
#                                             Male                                       NaN
#
#                                                                                                    \
# metric_label                                                 Substance Use | Drug Overdose Deaths
# geo_label_city date_label strata_race_label strata_sex_label
# Austin         2010       All               Both                                        14.814379
#                                             Female                                      12.110401
#                                             Male                                        17.451652
#                           Asian/PI          Both                                              NaN
#                                             Female                                            NaN
# ...                                                                                           ...
# Washington     2022       Hispanic          Male                                        25.584642
#                           Natives           Both                                              NaN
#                           White             Both                                        13.498547
#                                             Female                                       6.485127
#                                             Male                                        20.246498
#
#                                                                                                      \
# metric_label                                                 Substance Use | Opioid Overdose Deaths
# geo_label_city date_label strata_race_label strata_sex_label
# Austin         2010       All               Both                                           5.316296
#                                             Female                                         4.224056
#                                             Male                                           6.417004
#                           Asian/PI          Both                                                NaN
#                                             Female                                              NaN
# ...                                                                                             ...
# Washington     2022       Hispanic          Male                                          21.067009
#                           Natives           Both                                                NaN
#                           White             Both                                           8.887272
#                                             Female                                              NaN
#                                             Male                                          14.137920
#
#                                                                                            \
# metric_label                                                 Substance Use | Teen Alcohol
# geo_label_city date_label strata_race_label strata_sex_label
# Austin         2010       All               Both                                      NaN
#                                             Female                                    NaN
#                                             Male                                      NaN
#                           Asian/PI          Both                                      NaN
#                                             Female                                    NaN
# ...                                                                                   ...
# Washington     2022       Hispanic          Male                                      NaN
#                           Natives           Both                                      NaN
#                           White             Both                                      NaN
#                                             Female                                    NaN
#                                             Male                                      NaN
#
# ...
#                2021       All               Both              ...
#                2022       All               Both              ...
#
#                                                                                             \
# metric_label                                                 Substance Use | Adult Smoking
# geo_label_city date_label strata_race_label strata_sex_label
# U.S. Total     2010       All               Both                                      18.1
#                2011       All               Both                                      18.1
#                2012       All               Both                                      18.1
#                2013       All               Both                                      18.1
#                2014       All               Both                                      18.1
#                2015       All               Both                                      17.5
#                2016       All               Both                                      17.0
#                2017       All               Both                                      17.1
#                2018       All               Both                                      16.1
#                2019       All               Both                                      16.0
#                2020       All               Both                                      15.5
#                2021       All               Both                                      14.4
#                2022       All               Both                                      14.4
#
#                                                                                                    \
# metric_label                                                 Substance Use | Drug Overdose Deaths
# geo_label_city date_label strata_race_label strata_sex_label
# U.S. Total     2010       All               Both                                             12.3
#                2011       All               Both                                             12.3
#                2012       All               Both                                             13.2
#                2013       All               Both                                             13.1
#                2014       All               Both                                             13.8
#                2015       All               Both                                             14.7
#                2016       All               Both                                             16.3
#                2017       All               Both                                             19.8
#                2018       All               Both                                             21.7
#                2019       All               Both                                             20.7
#                2020       All               Both                                             21.6
#                2021       All               Both                                             28.3
#                2022       All               Both                                             32.4
#
#                                                                                                      \
# metric_label                                                 Substance Use | Opioid Overdose Deaths
# geo_label_city date_label strata_race_label strata_sex_label
# U.S. Total     2010       All               Both                                                6.8
#                2011       All               Both                                                7.3
#                2012       All               Both                                                7.4
#                2013       All               Both                                                7.9
#                2014       All               Both                                                9.0
#                2015       All               Both                                               10.4
#                2016       All               Both                                               13.3
#                2017       All               Both                                               14.9
#                2018       All               Both                                               14.6
#                2019       All               Both                                               15.5
#                2020       All               Both                                               15.5
#                2021       All               Both                                               21.4
#                2022       All               Both                                               24.7
#
#                                                                                            \
# metric_label                                                 Substance Use | Teen Alcohol
# geo_label_city date_label strata_race_label strata_sex_label
# U.S. Total     2010       All               Both                                     38.7
#                2011       All               Both                                     38.7
#                2012       All               Both                                     38.7
#                2013       All               Both                                     34.9
#                2014       All               Both                                     34.9
#                2015       All               Both                                     32.8
#                2016       All               Both                                     32.8
#                2017       All               Both                                     29.8
#                2018       All               Both                                     29.8
#                2019       All               Both                                     29.2
#                2020       All               Both                                     29.2
#                2021       All               Both                                      NaN
#                2022       All               Both                                      NaN
#
#                                                                                              \
# metric_label                                                 Substance Use | Teen Marijuana
# geo_label_city date_label strata_race_label strata_sex_label
# U.S. Total     2010       All               Both                                       23.1
#                2011       All               Both                                       23.1
#                2012       All               Both                                       23.1
#                2013       All               Both                                       23.4
#                2014       All               Both                                       23.4
#                2015       All               Both                                       21.7
#                2016       All               Both                                       21.7
#                2017       All               Both                                       19.8
#                2018       All               Both                                       19.8
#                2019       All               Both                                       21.7
#                2020       All               Both                                       21.7
#                2021       All               Both                                        NaN
#                2022       All               Both                                        NaN
#
#                                                                                            \
# metric_label                                                 Substance Use | Teen Smoking
# geo_label_city date_label strata_race_label strata_sex_label
# U.S. Total     2010       All               Both                                     18.1
#                2011       All               Both                                     18.1
#                2012       All               Both                                     18.1
#                2013       All               Both                                     15.7
#                2014       All               Both                                     15.7
#                2015       All               Both                                     10.8
#                2016       All               Both                                     10.8
#                2017       All               Both                                      8.8
#                2018       All               Both                                      8.8
#                2019       All               Both                                      6.0
#                2020       All               Both                                      6.0
#                2021       All               Both                                      NaN
#                2022       All               Both                                      NaN
#
#                                                                                                     \
# metric_label                                                 Transportation | Drives Alone to Work
# geo_label_city date_label strata_race_label strata_sex_label
# U.S. Total     2010       All               Both                                         76.330842
#                2011       All               Both                                         76.330842
#                2012       All               Both                                         76.330842
#                2013       All               Both                                         76.442231
#                2014       All               Both                                         76.442231
#                2015       All               Both                                         76.442231
#                2016       All               Both                                         76.442231
#                2017       All               Both                                         76.442231
#                2018       All               Both                                         71.673328
#                2019       All               Both                                         71.673328
#                2020       All               Both                                         71.673328
#                2021       All               Both                                         71.673328
#                2022       All               Both                                         71.673328
#
#                                                                                            \
# metric_label                                                 Transportation | Lack of Car
# geo_label_city date_label strata_race_label strata_sex_label
# U.S. Total     2010       All               Both                                 8.608855
#                2011       All               Both                                 8.608855
#                2012       All               Both                                 8.608855
#                2013       All               Both                                 8.809877
#                2014       All               Both                                 8.809877
#                2015       All               Both                                 8.809877
#                2016       All               Both                                 8.809877
#                2017       All               Both                                 8.809877
#                2018       All               Both                                 8.330821
#                2019       All               Both                                 8.330821
#                2020       All               Both                                 8.330821
#                2021       All               Both                                 8.330821
#                2022       All               Both                                 8.330821
#
#                                                                                                            \
# metric_label                                                 Transportation | Longer Driving Commute Time
# geo_label_city date_label strata_race_label strata_sex_label
# U.S. Total     2010       All               Both                                                      NaN
#                2011       All               Both                                                      NaN
#                2012       All               Both                                                      NaN
#                2013       All               Both                                                35.285365
#                2014       All               Both                                                35.285365
#                2015       All               Both                                                35.285365
#                2016       All               Both                                                35.285365
#                2017       All               Both                                                35.285365
#                2018       All               Both                                                36.492221
#                2019       All               Both                                                36.492221
#                2020       All               Both                                                36.492221
#                2021       All               Both                                                36.492221
#                2022       All               Both                                                36.492221
#
#
# metric_label                                                 Transportation | Public Transportation Use
# geo_label_city date_label strata_race_label strata_sex_label
# U.S. Total     2010       All               Both                                               5.002862
#                2011       All               Both                                               5.002862
#                2012       All               Both                                               5.002862
#                2013       All               Both                                               5.125515
#                2014       All               Both                                               5.125515
#                2015       All               Both                                               5.125515
#                2016       All               Both                                               5.125515
#                2017       All               Both                                               5.125515
#                2018       All               Both                                               3.794247
#                2019       All               Both                                               3.794247
#                2020       All               Both                                               3.794247
#                2021       All               Both                                               3.794247
#                2022       All               Both                                               3.794247
#
# [13 rows x 110 columns]

# %%
file_names=[
    'pvtb_whole_entire_ver0.csv',
    'pvtb_city_entire_ver0.csv',
    'pvtb_US_entire_ver0.csv'
]

pvtb_dir = 'pvtb'

save_path=[
    os.path.join(RSLT_DIR,pvtb_dir,name)
    for name in file_names
]

pvtb_whole_entire.to_csv(save_path[0],index=True)
pvtb_city_entire.to_csv(save_path[1],index=True)
pvtb_US_entire.to_csv(save_path[2],index=True)

# %% [markdown]
# 3. only for each stratification

# %%
cond_total_race = (df_racesex[cols[0]] == 'All')
cond_total_sex = (df_racesex[cols[1]] == 'Both')
cond_total_area = (df_racesex[cols[3]] == 'U.S. Total')

cond_strat_any = (~cond_total_race) | (~cond_total_sex)
cond_strat_all = (~cond_total_race) & (~cond_total_sex)

df_strat_any = df_racesex[cond_strat_any]
df_strat_all = df_racesex[cond_strat_all]

print(len(df_strat_any))
print(len(df_strat_all))
# Out:
# 143230
# 46662

# %%
index_cols = ['geo_label_city','date_label','strata_race_label','strata_sex_label']

pvtb_strat_any = pd.pivot_table(df_strat_any, index = index_cols, columns=['metric_label'],values=['value'])
pvtb_strat_all = pd.pivot_table(df_strat_all, index = index_cols, columns=['metric_label'],values=['value'])

display(pvtb_strat_any)
display(pvtb_strat_all)
# Out:
#                                                                                                value  \
# metric_label                                                 Active Transportation | Walking to Work
# geo_label_city date_label strata_race_label strata_sex_label
# Austin         2010       All               Female                                               NaN
#                                             Male                                                 NaN
#                           Asian/PI          Both                                                 NaN
#                                             Female                                               NaN
#                                             Male                                                 NaN
# ...                                                                                              ...
# Washington     2022       Hispanic          Male                                                 NaN
#                           Natives           Both                                            8.766234
#                           White             Both                                           14.201808
#                                             Female                                               NaN
#                                             Male                                                 NaN
#
#                                                                                                  \
# metric_label                                                 Birth Control | Teen Birth Control
# geo_label_city date_label strata_race_label strata_sex_label
# Austin         2010       All               Female                                          NaN
#                                             Male                                            NaN
#                           Asian/PI          Both                                            NaN
#                                             Female                                          NaN
#                                             Male                                            NaN
# ...                                                                                         ...
# Washington     2022       Hispanic          Male                                            NaN
#                           Natives           Both                                            NaN
#                           White             Both                                            NaN
#                                             Female                                          NaN
#                                             Male                                            NaN
#
#                                                                                        \
# metric_label                                                 Births | Low Birthweight
# geo_label_city date_label strata_race_label strata_sex_label
# Austin         2010       All               Female                                NaN
#                                             Male                                  NaN
#                           Asian/PI          Both                             8.785406
#                                             Female                                NaN
#                                             Male                                  NaN
# ...                                                                               ...
# Washington     2022       Hispanic          Male                                  NaN
#                           Natives           Both                                  NaN
#                           White             Both                             5.574537
#                                             Female                                NaN
#                                             Male                                  NaN
#
#                                                                                      \
# metric_label                                                 Births | Prenatal Care
# geo_label_city date_label strata_race_label strata_sex_label
# Austin         2010       All               Female                              NaN
#                                             Male                                NaN
#                           Asian/PI          Both                          82.261962
#                                             Female                              NaN
#                                             Male                                NaN
# ...                                                                             ...
# Washington     2022       Hispanic          Male                                NaN
#                           Natives           Both                                NaN
#                           White             Both                          84.861290
#                                             Female                              NaN
#                                             Male                                NaN
#
#                                                                                       \
# metric_label                                                 Births | Preterm Births
# geo_label_city date_label strata_race_label strata_sex_label
# Austin         2010       All               Female                               NaN
#                                             Male                                 NaN
#                           Asian/PI          Both                                 NaN
#                                             Female                               NaN
#                                             Male                                 NaN
# ...                                                                              ...
# Washington     2022       Hispanic          Male                                 NaN
#                           Natives           Both                                 NaN
#                           White             Both                            6.550297
#                                             Female                               NaN
#                                             Male                                 NaN
#
#                                                                                    \
# metric_label                                                 Births | Teen Births
# geo_label_city date_label strata_race_label strata_sex_label
# Austin         2010       All               Female                            NaN
#                                             Male                              NaN
#                           Asian/PI          Both                         5.460005
#                                             Female                            NaN
#                                             Male                              NaN
# ...                                                                           ...
# Washington     2022       Hispanic          Male                              NaN
#                           Natives           Both                              NaN
#                           White             Both                         0.943990
#                                             Female                            NaN
#                                             Male                              NaN
#
#                                                                                          \
# metric_label                                                 Cancer | All Cancer Deaths
# geo_label_city date_label strata_race_label strata_sex_label
# Austin         2010       All               Female                           133.000095
#                                             Male                             189.760269
#                           Asian/PI          Both                             110.214905
#                                             Female                            79.076751
#                                             Male                             158.041310
# ...                                                                                 ...
# Washington     2022       Hispanic          Male                             106.913662
#                           Natives           Both                                    NaN
#                           White             Both                              91.848866
#                                             Female                                  NaN
#                                             Male                                    NaN
#
#                                                                                             \
# metric_label                                                 Cancer | Breast Cancer Deaths
# geo_label_city date_label strata_race_label strata_sex_label
# Austin         2010       All               Female                                     NaN
#                                             Male                                       NaN
#                           Asian/PI          Both                                       NaN
#                                             Female                                     NaN
#                                             Male                                       NaN
# ...                                                                                    ...
# Washington     2022       Hispanic          Male                                       NaN
#                           Natives           Both                                       NaN
#                           White             Both                                 13.439353
#                                             Female                                     NaN
#                                             Male                                       NaN
#
#                                                                                                 \
# metric_label                                                 Cancer | Colorectal Cancer Deaths
# geo_label_city date_label strata_race_label strata_sex_label
# Austin         2010       All               Female                                   11.843858
#                                             Male                                     13.697672
#                           Asian/PI          Both                                           NaN
#                                             Female                                         NaN
#                                             Male                                           NaN
# ...                                                                                        ...
# Washington     2022       Hispanic          Male                                           NaN
#                           Natives           Both                                           NaN
#                           White             Both                                      8.931509
#                                             Female                                    9.634692
#                                             Male                                           NaN
#
#                                                                                           \
# metric_label                                                 Cancer | Lung Cancer Deaths
# geo_label_city date_label strata_race_label strata_sex_label
# Austin         2010       All               Female                             27.782416
#                                             Male                               47.847709
#                           Asian/PI          Both                                     NaN
#                                             Female                                   NaN
#                                             Male                                     NaN
# ...                                                                                  ...
# Washington     2022       Hispanic          Male                                     NaN
#                           Natives           Both                                     NaN
#                           White             Both                               14.971475
#                                             Female                                   NaN
#                                             Male                                     NaN
#
#                                                               ...  \
# metric_label                                                  ...
# geo_label_city date_label strata_race_label strata_sex_label  ...
# Austin         2010       All               Female            ...
#                                             Male              ...
#                           Asian/PI          Both              ...
#                                             Female            ...
#                                             Male              ...
# ...                                                           ...
# Washington     2022       Hispanic          Male              ...
#                           Natives           Both              ...
#                           White             Both              ...
#                                             Female            ...
#                                             Male              ...
#
#                                                                                                   \
# metric_label                                                 School Violence | Weapons in School
# geo_label_city date_label strata_race_label strata_sex_label
# Austin         2010       All               Female                                           NaN
#                                             Male                                             NaN
#                           Asian/PI          Both                                             NaN
#                                             Female                                           NaN
#                                             Male                                             NaN
# ...                                                                                          ...
# Washington     2022       Hispanic          Male                                             NaN
#                           Natives           Both                                             NaN
#                           White             Both                                             NaN
#                                             Female                                           NaN
#                                             Male                                             NaN
#
#                                                                                                                 \
# metric_label                                                 Sexually Transmitted Disease | HIV-Related Deaths
# geo_label_city date_label strata_race_label strata_sex_label
# Austin         2010       All               Female                                                         NaN
#                                             Male                                                      3.998868
#                           Asian/PI          Both                                                           NaN
#                                             Female                                                         NaN
#                                             Male                                                           NaN
# ...                                                                                                        ...
# Washington     2022       Hispanic          Male                                                           NaN
#                           Natives           Both                                                           NaN
#                           White             Both                                                           NaN
#                                             Female                                                         NaN
#                                             Male                                                           NaN
#
#                                                                                                                  \
# metric_label                                                 Sexually Transmitted Disease | HIV/AIDS Prevalence
# geo_label_city date_label strata_race_label strata_sex_label
# Austin         2010       All               Female                                                        126.8
#                                             Male                                                          755.0
#                           Asian/PI          Both                                                           54.2
#                                             Female                                                          NaN
#                                             Male                                                            NaN
# ...                                                                                                         ...
# Washington     2022       Hispanic          Male                                                            NaN
#                           Natives           Both                                                            NaN
#                           White             Both                                                            NaN
#                                             Female                                                          NaN
#                                             Male                                                            NaN
#
#                                                                                                    \
# metric_label                                                 Substance Use | Drug Overdose Deaths
# geo_label_city date_label strata_race_label strata_sex_label
# Austin         2010       All               Female                                      12.110401
#                                             Male                                        17.451652
#                           Asian/PI          Both                                              NaN
#                                             Female                                            NaN
#                                             Male                                              NaN
# ...                                                                                           ...
# Washington     2022       Hispanic          Male                                        25.584642
#                           Natives           Both                                              NaN
#                           White             Both                                        13.498547
#                                             Female                                       6.485127
#                                             Male                                        20.246498
#
#                                                                                                      \
# metric_label                                                 Substance Use | Opioid Overdose Deaths
# geo_label_city date_label strata_race_label strata_sex_label
# Austin         2010       All               Female                                         4.224056
#                                             Male                                           6.417004
#                           Asian/PI          Both                                                NaN
#                                             Female                                              NaN
#                                             Male                                                NaN
# ...                                                                                             ...
# Washington     2022       Hispanic          Male                                          21.067009
#                           Natives           Both                                                NaN
#                           White             Both                                           8.887272
#                                             Female                                              NaN
#                                             Male                                          14.137920
#
#                                                                                            \
# metric_label                                                 Substance Use | Teen Alcohol
# geo_label_city date_label strata_race_label strata_sex_label
# Austin         2010       All               Female                                    NaN
#                                             Male                                      NaN
#                           Asian/PI          Both                                      NaN
#                                             Female                                    NaN
#                                             Male                                      NaN
# ...                                                                                   ...
# Washington     2022       Hispanic          Male                                      NaN
#                           Natives           Both                                      NaN
#                           White             Both                                      NaN
#                                             Female                                    NaN
#                                             Male                                      NaN
#
#                                                                                              \
# metric_label                                                 Substance Use | Teen Marijuana
# geo_label_city date_label strata_race_label strata_sex_label
# Austin         2010       All               Female                                      NaN
#                                             Male                                        NaN
#                           Asian/PI          Both                                        NaN
#                                             Female                                      NaN
#                                             Male                                        NaN
# ...                                                                                     ...
# Washington     2022       Hispanic          Male                                        NaN
#                           Natives           Both                                        NaN
#                           White             Both                                        NaN
#                                             Female                                      NaN
#                                             Male                                        NaN
#
#                                                                                            \
# metric_label                                                 Substance Use | Teen Smoking
# geo_label_city date_label strata_race_label strata_sex_label
# Austin         2010       All               Female                                    NaN
#                                             Male                                      NaN
#                           Asian/PI          Both                                      NaN
#                                             Female                                    NaN
#                                             Male                                      NaN
# ...                                                                                   ...
# Washington     2022       Hispanic          Male                                      NaN
#                           Natives           Both                                      NaN
#                           White             Both                                      NaN
#                                             Female                                    NaN
#                                             Male                                      NaN
#
#                                                                                                     \
# metric_label                                                 Transportation | Drives Alone to Work
# geo_label_city date_label strata_race_label strata_sex_label
# Austin         2010       All               Female                                             NaN
#                                             Male                                               NaN
#                           Asian/PI          Both                                               NaN
#                                             Female                                             NaN
#                                             Male                                               NaN
# ...                                                                                            ...
# Washington     2022       Hispanic          Male                                               NaN
#                           Natives           Both                                         19.237013
#                           White             Both                                         24.173919
#                                             Female                                             NaN
#                                             Male                                               NaN
#
#
# metric_label                                                 Transportation | Public Transportation Use
# geo_label_city date_label strata_race_label strata_sex_label
# Austin         2010       All               Female                                                  NaN
#                                             Male                                                    NaN
#                           Asian/PI          Both                                                    NaN
#                                             Female                                                  NaN
#                                             Male                                                    NaN
# ...                                                                                                 ...
# Washington     2022       Hispanic          Male                                                    NaN
#                           Natives           Both                                              38.879870
#                           White             Both                                              21.684225
#                                             Female                                                  NaN
#                                             Male                                                    NaN
#
# [6825 rows x 64 columns]
#                                                                                   value  \
# metric_label                                                 Cancer | All Cancer Deaths
# geo_label_city date_label strata_race_label strata_sex_label
# Austin         2010       Asian/PI          Female                            79.076751
#                                             Male                             158.041310
#                           Black             Female                           193.834961
#                                             Male                             305.996589
#                           Hispanic          Female                           103.754458
# ...                                                                                 ...
# Washington     2022       Black             Male                             243.855425
#                           Hispanic          Female                            70.502925
#                                             Male                             106.913662
#                           White             Female                                  NaN
#                                             Male                                    NaN
#
#                                                                                                 \
# metric_label                                                 Cancer | Colorectal Cancer Deaths
# geo_label_city date_label strata_race_label strata_sex_label
# Austin         2010       Asian/PI          Female                                         NaN
#                                             Male                                           NaN
#                           Black             Female                                   19.475668
#                                             Male                                     21.027801
#                           Hispanic          Female                                   12.224394
# ...                                                                                        ...
# Washington     2022       Black             Male                                     24.974548
#                           Hispanic          Female                                         NaN
#                                             Male                                           NaN
#                           White             Female                                    9.634692
#                                             Male                                           NaN
#
#                                                                                           \
# metric_label                                                 Cancer | Lung Cancer Deaths
# geo_label_city date_label strata_race_label strata_sex_label
# Austin         2010       Asian/PI          Female                                   NaN
#                                             Male                                     NaN
#                           Black             Female                             42.643078
#                                             Male                               66.930268
#                           Hispanic          Female                             17.241446
# ...                                                                                  ...
# Washington     2022       Black             Male                               46.656841
#                           Hispanic          Female                                   NaN
#                                             Male                                     NaN
#                           White             Female                                   NaN
#                                             Male                                     NaN
#
#                                                                                                                      \
# metric_label                                                 Cardiovascular Disease | Cardiovascular Disease Deaths
# geo_label_city date_label strata_race_label strata_sex_label
# Austin         2010       Asian/PI          Female                                                    71.389231
#                                             Male                                                     161.099229
#                           Black             Female                                                   228.135662
#                                             Male                                                     350.036490
#                           Hispanic          Female                                                   140.850670
# ...                                                                                                         ...
# Washington     2022       Black             Male                                                     483.953540
#                           Hispanic          Female                                                   103.589134
#                                             Male                                                     212.235330
#                           White             Female                                                          NaN
#                                             Male                                                            NaN
#
#                                                                                                             \
# metric_label                                                 Cardiovascular Disease | Heart Disease Deaths
# geo_label_city date_label strata_race_label strata_sex_label
# Austin         2010       Asian/PI          Female                                                     NaN
#                                             Male                                                111.112106
#                           Black             Female                                              165.969495
#                                             Male                                                263.876224
#                           Hispanic          Female                                               93.686912
# ...                                                                                                    ...
# Washington     2022       Black             Male                                                383.572691
#                           Hispanic          Female                                               64.133752
#                                             Male                                                147.377983
#                           White             Female                                                     NaN
#                                             Male                                                       NaN
#
#                                                                                           \
# metric_label                                                 Crime Incidents | Homicides
# geo_label_city date_label strata_race_label strata_sex_label
# Austin         2010       Asian/PI          Female                                   NaN
#                                             Male                                     NaN
#                           Black             Female                                   NaN
#                                             Male                               15.810016
#                           Hispanic          Female                              3.400617
# ...                                                                                  ...
# Washington     2022       Black             Male                              118.485673
#                           Hispanic          Female                                   NaN
#                                             Male                               12.826002
#                           White             Female                                   NaN
#                                             Male                                     NaN
#
#                                                                                               \
# metric_label                                                 Deaths | Deaths from All Causes
# geo_label_city date_label strata_race_label strata_sex_label
# Austin         2010       Asian/PI          Female                                304.999747
#                                             Male                                  591.412447
#                           Black             Female                                762.649424
#                                             Male                                 1153.246434
#                           Hispanic          Female                                534.714524
# ...                                                                                      ...
# Washington     2022       Black             Male                                 1663.309143
#                           Hispanic          Female                                372.909078
#                                             Male                                  666.886799
#                           White             Female                                       NaN
#                                             Male                                         NaN
#
#                                                                                              \
# metric_label                                                 Deaths | Gun Deaths (Firearms)
# geo_label_city date_label strata_race_label strata_sex_label
# Austin         2010       Asian/PI          Female                                      NaN
#                                             Male                                        NaN
#                           Black             Female                                      NaN
#                                             Male                                  19.614660
#                           Hispanic          Female                                      NaN
# ...                                                                                     ...
# Washington     2022       Black             Male                                 107.852814
#                           Hispanic          Female                                      NaN
#                                             Male                                  12.121014
#                           White             Female                                      NaN
#                                             Male                                        NaN
#
#                                                                                      \
# metric_label                                                 Deaths | Injury Deaths
# geo_label_city date_label strata_race_label strata_sex_label
# Austin         2010       Asian/PI          Female                              NaN
#                                             Male                          54.603382
#                           Black             Female                        36.727253
#                                             Male                         101.366223
#                           Hispanic          Female                        37.637649
# ...                                                                             ...
# Washington     2022       Black             Male                         391.912209
#                           Hispanic          Female                        22.704580
#                                             Male                         112.239270
#                           White             Female                        26.975543
#                                             Male                          55.150330
#
#                                                                                             \
# metric_label                                                 Deaths | Motor Vehicle Deaths
# geo_label_city date_label strata_race_label strata_sex_label
# Austin         2010       Asian/PI          Female                                     NaN
#                                             Male                                       NaN
#                           Black             Female                                     NaN
#                                             Male                                       NaN
#                           Hispanic          Female                                3.736869
# ...                                                                                    ...
# Washington     2022       Black             Male                                 25.273286
#                           Hispanic          Female                                     NaN
#                                             Male                                       NaN
#                           White             Female                                     NaN
#                                             Male                                       NaN
#
#                                                                                        \
# metric_label                                                 Deaths | Premature Death
# geo_label_city date_label strata_race_label strata_sex_label
# Austin         2010       Asian/PI          Female                        2025.151915
#                                             Male                          3244.603780
#                           Black             Female                        7672.368289
#                                             Male                         10945.542080
#                           Hispanic          Female                        3312.773042
# ...                                                                               ...
# Washington     2022       Black             Male                         21688.053640
#                           Hispanic          Female                        2692.047582
#                                             Male                          6300.589535
#                           White             Female                        1609.792900
#                                             Male                          2815.793085
#
#                                                                                                      \
# metric_label                                                 Diabetes and Obesity | Diabetes Deaths
# geo_label_city date_label strata_race_label strata_sex_label
# Austin         2010       Asian/PI          Female                                              NaN
#                                             Male                                                NaN
#                           Black             Female                                        44.611181
#                                             Male                                          25.543715
#                           Hispanic          Female                                        29.046072
# ...                                                                                             ...
# Washington     2022       Black             Male                                          48.441939
#                           Hispanic          Female                                              NaN
#                                             Male                                          25.165627
#                           White             Female                                              NaN
#                                             Male                                                NaN
#
#                                                                                                          \
# metric_label                                                 Life Expectancy at Birth | Life Expectancy
# geo_label_city date_label strata_race_label strata_sex_label
# Austin         2010       Asian/PI          Female                                                  NaN
#                                             Male                                                    NaN
#                           Black             Female                                                  NaN
#                                             Male                                                    NaN
#                           Hispanic          Female                                                  NaN
# ...                                                                                                 ...
# Washington     2022       Black             Male                                              64.546600
#                           Hispanic          Female                                                  NaN
#                                             Male                                                    NaN
#                           White             Female                                            89.768405
#                                             Male                                              85.053151
#
#                                                                                       \
# metric_label                                                 Mental Health | Suicide
# geo_label_city date_label strata_race_label strata_sex_label
# Austin         2010       Asian/PI          Female                               NaN
#                                             Male                                 NaN
#                           Black             Female                               NaN
#                                             Male                                 NaN
#                           Hispanic          Female                               NaN
# ...                                                                              ...
# Washington     2022       Black             Male                           15.256746
#                           Hispanic          Female                               NaN
#                                             Male                                 NaN
#                           White             Female                               NaN
#                                             Male                           10.754616
#
#                                                                                                       \
# metric_label                                                 Respiratory Infection | COVID-19 Deaths
# geo_label_city date_label strata_race_label strata_sex_label
# Austin         2010       Asian/PI          Female                                               NaN
#                                             Male                                                 NaN
#                           Black             Female                                               NaN
#                                             Male                                                 NaN
#                           Hispanic          Female                                               NaN
# ...                                                                                              ...
# Washington     2022       Black             Male                                           64.627596
#                           Hispanic          Female                                               NaN
#                                             Male                                                 NaN
#                           White             Female                                         10.736374
#                                             Male                                           11.435612
#
#                                                                                                                     \
# metric_label                                                 Respiratory Infection | Pneumonia or Influenza Deaths
# geo_label_city date_label strata_race_label strata_sex_label
# Austin         2010       Asian/PI          Female                                                          NaN
#                                             Male                                                            NaN
#                           Black             Female                                                          NaN
#                                             Male                                                            NaN
#                           Hispanic          Female                                                          NaN
# ...                                                                                                         ...
# Washington     2022       Black             Male                                                      21.330938
#                           Hispanic          Female                                                          NaN
#                                             Male                                                            NaN
#                           White             Female                                                          NaN
#                                             Male                                                            NaN
#
#                                                                                                                 \
# metric_label                                                 Sexually Transmitted Disease | HIV-Related Deaths
# geo_label_city date_label strata_race_label strata_sex_label
# Austin         2010       Asian/PI          Female                                                         NaN
#                                             Male                                                           NaN
#                           Black             Female                                                         NaN
#                                             Male                                                     18.502468
#                           Hispanic          Female                                                         NaN
# ...                                                                                                        ...
# Washington     2022       Black             Male                                                     17.255063
#                           Hispanic          Female                                                         NaN
#                                             Male                                                           NaN
#                           White             Female                                                         NaN
#                                             Male                                                           NaN
#
#                                                                                                    \
# metric_label                                                 Substance Use | Drug Overdose Deaths
# geo_label_city date_label strata_race_label strata_sex_label
# Austin         2010       Asian/PI          Female                                            NaN
#                                             Male                                              NaN
#                           Black             Female                                            NaN
#                                             Male                                        33.411726
#                           Hispanic          Female                                       6.193495
# ...                                                                                           ...
# Washington     2022       Black             Male                                       198.362588
#                           Hispanic          Female                                            NaN
#                                             Male                                        25.584642
#                           White             Female                                       6.485127
#                                             Male                                        20.246498
#
#
# metric_label                                                 Substance Use | Opioid Overdose Deaths
# geo_label_city date_label strata_race_label strata_sex_label
# Austin         2010       Asian/PI          Female                                              NaN
#                                             Male                                                NaN
#                           Black             Female                                              NaN
#                                             Male                                                NaN
#                           Hispanic          Female                                              NaN
# ...                                                                                             ...
# Washington     2022       Black             Male                                         148.837622
#                           Hispanic          Female                                              NaN
#                                             Male                                          21.067009
#                           White             Female                                              NaN
#                                             Male                                          14.137920
#
# [3640 rows x 19 columns]

# %%
file_names=[
    'pvtb_strat_any_ver0.csv',
    'pvtb_strat_all_ver0.csv',
]

pvtb_dir = 'pvtb'

save_path=[
    os.path.join(RSLT_DIR,pvtb_dir,name)
    for name in file_names
]

pvtb_strat_any.to_csv(save_path[0],index=True)
pvtb_strat_all.to_csv(save_path[1],index=True)

# %% [markdown]
# ### TODO
#
# 1. 결측치 확인
#     1. for entire data
#     2. only for whole race-sex
#     3. only for each stratification
# 2. 라벨별로 집계 주기 확인
#     1. for entire data
#     2. only for whole race-sex
#     3. only for each stratification
